# %% [markdown]
# # Compare

# %%
import sys,os
import numpy as np
import pandas as pd
import pylab as py
from  matplotlib import rc
from matplotlib.colors import LogNorm
from matplotlib.font_manager import FontProperties
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text',usetex=True)
# %matplotlib inline
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
font0=FontProperties()
font0.set_family('sans-serif')
font0.set_style('italic')
font0.set_variant('normal')

# %% [markdown]
# ## Compare Fit Results

# %% [markdown]
# ### E288

# %%
# E288 200

data={}
curve={}

data['E288 200 Q=4.5']=np.loadtxt("plots/data_E288_200_Q=4.5.dat",skiprows=0)
data['E288 200 Q=5.5']=np.loadtxt("plots/data_E288_200_Q=5.5.dat",skiprows=0)
data['E288 200 Q=6.5']=np.loadtxt("plots/data_E288_200_Q=6.5.dat",skiprows=0)
data['E288 200 Q=7.5']=np.loadtxt("plots/data_E288_200_Q=7.5.dat",skiprows=0)
data['E288 200 Q=8.5']=np.loadtxt("plots/data_E288_200_Q=8.5.dat",skiprows=0)

data['E288 300 Q=4.5']=np.loadtxt("plots/data_E288_300_Q=4.5.dat",skiprows=0)
data['E288 300 Q=5.5']=np.loadtxt("plots/data_E288_300_Q=5.5.dat",skiprows=0)
data['E288 300 Q=6.5']=np.loadtxt("plots/data_E288_300_Q=6.5.dat",skiprows=0)
data['E288 300 Q=7.5']=np.loadtxt("plots/data_E288_300_Q=7.5.dat",skiprows=0)
data['E288 300 Q=8.5']=np.loadtxt("plots/data_E288_300_Q=8.5.dat",skiprows=0)

data['E288 400 Q=5.5']=np.loadtxt("plots/data_E288_400_Q=5.5.dat",skiprows=0)
data['E288 400 Q=6.5']=np.loadtxt("plots/data_E288_400_Q=6.5.dat",skiprows=0)
data['E288 400 Q=7.5']=np.loadtxt("plots/data_E288_400_Q=7.5.dat",skiprows=0)
data['E288 400 Q=8.5']=np.loadtxt("plots/data_E288_400_Q=8.5.dat",skiprows=0)
data['E288 400 Q=11.5']=np.loadtxt("plots/data_E288_400_Q=11.5.dat",skiprows=0)
data['E288 400 Q=12.5']=np.loadtxt("plots/data_E288_400_Q=12.5.dat",skiprows=0)
data['E288 400 Q=13.5']=np.loadtxt("plots/data_E288_400_Q=13.5.dat",skiprows=0)

curve['E288 200 Q=4.5']=np.loadtxt("plots/curve_E288_200_Q=4.5.dat",skiprows=0)
curve['E288 200 Q=5.5']=np.loadtxt("plots/curve_E288_200_Q=5.5.dat",skiprows=0)
curve['E288 200 Q=6.5']=np.loadtxt("plots/curve_E288_200_Q=6.5.dat",skiprows=0)
curve['E288 200 Q=7.5']=np.loadtxt("plots/curve_E288_200_Q=7.5.dat",skiprows=0)
curve['E288 200 Q=8.5']=np.loadtxt("plots/curve_E288_200_Q=8.5.dat",skiprows=0)

curve['E288 300 Q=4.5']=np.loadtxt("plots/curve_E288_300_Q=4.5.dat",skiprows=0)
curve['E288 300 Q=5.5']=np.loadtxt("plots/curve_E288_300_Q=5.5.dat",skiprows=0)
curve['E288 300 Q=6.5']=np.loadtxt("plots/curve_E288_300_Q=6.5.dat",skiprows=0)
curve['E288 300 Q=7.5']=np.loadtxt("plots/curve_E288_300_Q=7.5.dat",skiprows=0)
curve['E288 300 Q=8.5']=np.loadtxt("plots/curve_E288_300_Q=8.5.dat",skiprows=0)

curve['E288 400 Q=5.5']=np.loadtxt("plots/curve_E288_400_Q=5.5.dat",skiprows=0)
curve['E288 400 Q=6.5']=np.loadtxt("plots/curve_E288_400_Q=6.5.dat",skiprows=0)
curve['E288 400 Q=7.5']=np.loadtxt("plots/curve_E288_400_Q=7.5.dat",skiprows=0)
curve['E288 400 Q=8.5']=np.loadtxt("plots/curve_E288_400_Q=8.5.dat",skiprows=0)
curve['E288 400 Q=11.5']=np.loadtxt("plots/curve_E288_400_Q=11.5.dat",skiprows=0)
curve['E288 400 Q=12.5']=np.loadtxt("plots/curve_E288_400_Q=12.5.dat",skiprows=0)
curve['E288 400 Q=13.5']=np.loadtxt("plots/curve_E288_400_Q=13.5.dat",skiprows=0)

# %%
nrows,ncols=1,3
py.figure(figsize=(ncols*7,nrows*8))

ax=py.subplot(nrows,ncols,1)
#Q=4.5
ncut=23
ax.plot(curve['E288 200 Q=4.5'][:ncut,0].T, curve['E288 200 Q=4.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E288 200 Q=4.5'][:ncut,0].T, (curve['E288 200 Q=4.5'][:ncut,1]-curve['E288 200 Q=4.5'][:ncut,2]).T, (curve['E288 200 Q=4.5'][:ncut,1]+curve['E288 200 Q=4.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E288 200 Q=4.5'][:,0].T, data['E288 200 Q=4.5'][:,1], yerr=((data['E288 200 Q=4.5'][:,2]**2+data['E288 200 Q=4.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#Q=5.5
ncut=28
ax.plot(curve['E288 200 Q=5.5'][:ncut,0].T, curve['E288 200 Q=5.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E288 200 Q=5.5'][:ncut,0].T, (curve['E288 200 Q=5.5'][:ncut,1]-curve['E288 200 Q=5.5'][:ncut,2]).T, (curve['E288 200 Q=5.5'][:ncut,1]+curve['E288 200 Q=5.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E288 200 Q=5.5'][:,0].T, data['E288 200 Q=5.5'][:,1], yerr=((data['E288 200 Q=5.5'][:,2]**2+data['E288 200 Q=5.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#Q=6.5
ncut=33
ax.plot(curve['E288 200 Q=6.5'][:ncut,0].T, curve['E288 200 Q=6.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E288 200 Q=6.5'][:ncut,0].T, (curve['E288 200 Q=6.5'][:ncut,1]-curve['E288 200 Q=6.5'][:ncut,2]).T, (curve['E288 200 Q=6.5'][:ncut,1]+curve['E288 200 Q=6.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E288 200 Q=6.5'][:,0].T, data['E288 200 Q=6.5'][:,1], yerr=((data['E288 200 Q=6.5'][:,2]**2+data['E288 200 Q=6.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#Q=7.5
ncut=38
ax.plot(curve['E288 200 Q=7.5'][:ncut,0].T, curve['E288 200 Q=7.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E288 200 Q=7.5'][:ncut,0].T, (curve['E288 200 Q=7.5'][:ncut,1]-curve['E288 200 Q=7.5'][:ncut,2]).T, (curve['E288 200 Q=7.5'][:ncut,1]+curve['E288 200 Q=7.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E288 200 Q=7.5'][:,0].T, data['E288 200 Q=7.5'][:,1], yerr=((data['E288 200 Q=7.5'][:,2]**2+data['E288 200 Q=7.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#Q=8.5
ncut=43
ax.plot(curve['E288 200 Q=8.5'][:ncut,0].T, curve['E288 200 Q=8.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E288 200 Q=8.5'][:ncut,0].T, (curve['E288 200 Q=8.5'][:ncut,1]-curve['E288 200 Q=8.5'][:ncut,2]).T, (curve['E288 200 Q=8.5'][:ncut,1]+curve['E288 200 Q=8.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E288 200 Q=8.5'][:,0].T, data['E288 200 Q=8.5'][:,1], yerr=((data['E288 200 Q=8.5'][:,2]**2+data['E288 200 Q=8.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
ax.set_xlabel(r'$q_T~\rm(GeV)$',size=30)
ax.set_ylabel(r'$Ed\sigma/d^3q~\rm(GeV^{-4})$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(1e-14,1e-6)
ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E288~200\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)

ax=py.subplot(nrows,ncols,2)
#Q=4.5
ncut=23
ax.plot(curve['E288 300 Q=4.5'][:ncut,0].T, curve['E288 300 Q=4.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E288 300 Q=4.5'][:ncut,0].T, (curve['E288 300 Q=4.5'][:ncut,1]-curve['E288 300 Q=4.5'][:ncut,2]).T, (curve['E288 300 Q=4.5'][:ncut,1]+curve['E288 300 Q=4.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E288 300 Q=4.5'][:,0].T, data['E288 300 Q=4.5'][:,1], yerr=((data['E288 300 Q=4.5'][:,2]**2+data['E288 300 Q=4.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#Q=5.5
ncut=28
ax.plot(curve['E288 300 Q=5.5'][:ncut,0].T, curve['E288 300 Q=5.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E288 300 Q=5.5'][:ncut,0].T, (curve['E288 300 Q=5.5'][:ncut,1]-curve['E288 300 Q=5.5'][:ncut,2]).T, (curve['E288 300 Q=5.5'][:ncut,1]+curve['E288 300 Q=5.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E288 300 Q=5.5'][:,0].T, data['E288 300 Q=5.5'][:,1], yerr=((data['E288 300 Q=5.5'][:,2]**2+data['E288 300 Q=5.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#Q=6.5
ncut=33
ax.plot(curve['E288 300 Q=6.5'][:ncut,0].T, curve['E288 300 Q=6.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E288 300 Q=6.5'][:ncut,0].T, (curve['E288 300 Q=6.5'][:ncut,1]-curve['E288 300 Q=6.5'][:ncut,2]).T, (curve['E288 300 Q=6.5'][:ncut,1]+curve['E288 300 Q=6.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E288 300 Q=6.5'][:,0].T, data['E288 300 Q=6.5'][:,1], yerr=((data['E288 300 Q=6.5'][:,2]**2+data['E288 300 Q=6.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#Q=7.5
ncut=38
ax.plot(curve['E288 300 Q=7.5'][:ncut,0].T, curve['E288 300 Q=7.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E288 300 Q=7.5'][:ncut,0].T, (curve['E288 300 Q=7.5'][:ncut,1]-curve['E288 300 Q=7.5'][:ncut,2]).T, (curve['E288 300 Q=7.5'][:ncut,1]+curve['E288 300 Q=7.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E288 300 Q=7.5'][:,0].T, data['E288 300 Q=7.5'][:,1], yerr=((data['E288 300 Q=7.5'][:,2]**2+data['E288 300 Q=7.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#Q=8.5
ncut=43
ax.plot(curve['E288 300 Q=8.5'][:ncut,0].T, curve['E288 300 Q=8.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E288 300 Q=8.5'][:ncut,0].T, (curve['E288 300 Q=8.5'][:ncut,1]-curve['E288 300 Q=8.5'][:ncut,2]).T, (curve['E288 300 Q=8.5'][:ncut,1]+curve['E288 300 Q=8.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E288 300 Q=8.5'][:,0].T, data['E288 300 Q=8.5'][:,1], yerr=((data['E288 300 Q=8.5'][:,2]**2+data['E288 300 Q=8.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
ax.set_xlabel(r'$q_T~\rm(GeV)$',size=30)
ax.set_ylabel(r'$Ed\sigma/d^3q~\rm(GeV^{-4})$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(1e-14,1e-6)
ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E288~300\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)

ax=py.subplot(nrows,ncols,3)
#Q=5.5
ncut=28
ax.plot(curve['E288 400 Q=5.5'][:ncut,0].T, curve['E288 400 Q=5.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E288 400 Q=5.5'][:ncut,0].T, (curve['E288 400 Q=5.5'][:ncut,1]-curve['E288 400 Q=5.5'][:ncut,2]).T, (curve['E288 400 Q=5.5'][:ncut,1]+curve['E288 400 Q=5.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E288 400 Q=5.5'][:,0].T, data['E288 400 Q=5.5'][:,1], yerr=((data['E288 400 Q=5.5'][:,2]**2+data['E288 400 Q=5.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#Q=6.5
ncut=33
ax.plot(curve['E288 400 Q=6.5'][:ncut,0].T, curve['E288 400 Q=6.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E288 400 Q=6.5'][:ncut,0].T, (curve['E288 400 Q=6.5'][:ncut,1]-curve['E288 400 Q=6.5'][:ncut,2]).T, (curve['E288 400 Q=6.5'][:ncut,1]+curve['E288 400 Q=6.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E288 400 Q=6.5'][:,0].T, data['E288 400 Q=6.5'][:,1], yerr=((data['E288 400 Q=6.5'][:,2]**2+data['E288 400 Q=6.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#Q=7.5
ncut=38
ax.plot(curve['E288 400 Q=7.5'][:ncut,0].T, curve['E288 400 Q=7.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E288 400 Q=7.5'][:ncut,0].T, (curve['E288 400 Q=7.5'][:ncut,1]-curve['E288 400 Q=7.5'][:ncut,2]).T, (curve['E288 400 Q=7.5'][:ncut,1]+curve['E288 400 Q=7.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E288 400 Q=7.5'][:,0].T, data['E288 400 Q=7.5'][:,1], yerr=((data['E288 400 Q=7.5'][:,2]**2+data['E288 400 Q=7.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#Q=8.5
ncut=43
ax.plot(curve['E288 400 Q=8.5'][:ncut,0].T, curve['E288 400 Q=8.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E288 400 Q=8.5'][:ncut,0].T, (curve['E288 400 Q=8.5'][:ncut,1]-curve['E288 400 Q=8.5'][:ncut,2]).T, (curve['E288 400 Q=8.5'][:ncut,1]+curve['E288 400 Q=8.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E288 400 Q=8.5'][:,0].T, data['E288 400 Q=8.5'][:,1], yerr=((data['E288 400 Q=8.5'][:,2]**2+data['E288 400 Q=8.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#Q=11.5
ncut=58
ax.plot(curve['E288 400 Q=11.5'][:ncut,0].T, curve['E288 400 Q=11.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E288 400 Q=11.5'][:ncut,0].T, (curve['E288 400 Q=11.5'][:ncut,1]-curve['E288 400 Q=11.5'][:ncut,2]).T, (curve['E288 400 Q=11.5'][:ncut,1]+curve['E288 400 Q=11.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E288 400 Q=11.5'][:,0].T, data['E288 400 Q=11.5'][:,1], yerr=((data['E288 400 Q=11.5'][:,2]**2+data['E288 400 Q=11.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#Q=12.5
ncut=63
ax.plot(curve['E288 400 Q=12.5'][:ncut,0].T, curve['E288 400 Q=12.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E288 400 Q=12.5'][:ncut,0].T, (curve['E288 400 Q=12.5'][:ncut,1]-curve['E288 400 Q=12.5'][:ncut,2]).T, (curve['E288 400 Q=12.5'][:ncut,1]+curve['E288 400 Q=12.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E288 400 Q=12.5'][:,0].T, data['E288 400 Q=12.5'][:,1], yerr=((data['E288 400 Q=12.5'][:,2]**2+data['E288 400 Q=12.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#Q=13.5
ncut=68
ax.plot(curve['E288 400 Q=13.5'][:ncut,0].T, curve['E288 400 Q=13.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E288 400 Q=13.5'][:ncut,0].T, (curve['E288 400 Q=13.5'][:ncut,1]-curve['E288 400 Q=13.5'][:ncut,2]).T, (curve['E288 400 Q=13.5'][:ncut,1]+curve['E288 400 Q=13.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E288 400 Q=13.5'][:,0].T, data['E288 400 Q=13.5'][:,1], yerr=((data['E288 400 Q=13.5'][:,2]**2+data['E288 400 Q=13.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
ax.set_xlabel(r'$q_T~\rm(GeV)$',size=30)
ax.set_ylabel(r'$Ed\sigma/d^3q~\rm(GeV^{-4})$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(1e-14,1e-6)
ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E288~400\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)



py.tight_layout()
#py.savefig('results/tmp.png')

# %% [markdown]
# ### E605

# %%
# E605

data['E605 Q=7.5']=np.loadtxt("plots/data_E605_Q=7.5.dat",skiprows=0)
data['E605 Q=8.5']=np.loadtxt("plots/data_E605_Q=8.5.dat",skiprows=0)
data['E605 Q=11.0']=np.loadtxt("plots/data_E605_Q=11.0.dat",skiprows=0)
data['E605 Q=12.5']=np.loadtxt("plots/data_E605_Q=12.5.dat",skiprows=0)
data['E605 Q=15.8']=np.loadtxt("plots/data_E605_Q=15.8.dat",skiprows=0)

curve['E605 Q=7.5']=np.loadtxt("plots/curve_E605_Q=7.5.dat",skiprows=0)
curve['E605 Q=8.5']=np.loadtxt("plots/curve_E605_Q=8.5.dat",skiprows=0)
curve['E605 Q=11.0']=np.loadtxt("plots/curve_E605_Q=11.0.dat",skiprows=0)
curve['E605 Q=12.5']=np.loadtxt("plots/curve_E605_Q=12.5.dat",skiprows=0)
curve['E605 Q=15.8']=np.loadtxt("plots/curve_E605_Q=15.8.dat",skiprows=0)

# %%
nrows,ncols=1,1
py.figure(figsize=(ncols*7,nrows*8))

ax=py.subplot(nrows,ncols,1)
#Q=7.5
ncut=23
ax.plot(curve['E605 Q=7.5'][:ncut,0].T, curve['E605 Q=7.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E605 Q=7.5'][:ncut,0].T, (curve['E605 Q=7.5'][:ncut,1]-curve['E605 Q=7.5'][:ncut,2]).T, (curve['E605 Q=7.5'][:ncut,1]+curve['E605 Q=7.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E605 Q=7.5'][:,0].T, data['E605 Q=7.5'][:,1], yerr=((data['E605 Q=7.5'][:,2]**2+data['E605 Q=7.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#Q=8.5
ncut=29
ax.plot(curve['E605 Q=8.5'][:ncut,0].T, curve['E605 Q=8.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E605 Q=8.5'][:ncut,0].T, (curve['E605 Q=8.5'][:ncut,1]-curve['E605 Q=8.5'][:ncut,2]).T, (curve['E605 Q=8.5'][:ncut,1]+curve['E605 Q=8.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E605 Q=8.5'][:,0].T, data['E605 Q=8.5'][:,1], yerr=((data['E605 Q=8.5'][:,2]**2+data['E605 Q=8.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#Q=11.0
ncut=40
ax.plot(curve['E605 Q=11.0'][:ncut,0].T, curve['E605 Q=11.0'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E605 Q=11.0'][:ncut,0].T, (curve['E605 Q=11.0'][:ncut,1]-curve['E605 Q=11.0'][:ncut,2]).T, (curve['E605 Q=11.0'][:ncut,1]+curve['E605 Q=11.0'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E605 Q=11.0'][:,0].T, data['E605 Q=11.0'][:,1], yerr=((data['E605 Q=11.0'][:,2]**2+data['E605 Q=11.0'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#Q=12.5
ncut=40
ax.plot(curve['E605 Q=12.5'][:ncut,0].T, curve['E605 Q=12.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E605 Q=12.5'][:ncut,0].T, (curve['E605 Q=12.5'][:ncut,1]-curve['E605 Q=12.5'][:ncut,2]).T, (curve['E605 Q=12.5'][:ncut,1]+curve['E605 Q=12.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E605 Q=12.5'][:,0].T, data['E605 Q=12.5'][:,1], yerr=((data['E605 Q=12.5'][:,2]**2+data['E605 Q=12.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#Q=15.8
ncut=40
ax.plot(curve['E605 Q=15.8'][:ncut,0].T, curve['E605 Q=15.8'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E605 Q=15.8'][:ncut,0].T, (curve['E605 Q=15.8'][:ncut,1]-curve['E605 Q=15.8'][:ncut,2]).T, (curve['E605 Q=15.8'][:ncut,1]+curve['E605 Q=15.8'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E605 Q=15.8'][:,0].T, data['E605 Q=15.8'][:,1], yerr=((data['E605 Q=15.8'][:,2]**2+data['E605 Q=15.8'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
ax.set_xlabel(r'$q_T~\rm(GeV)$',size=30)
ax.set_ylabel(r'$Ed\sigma/d^3q~\rm(GeV^{-4})$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(1e-14,1e-6)
ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E605 800\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)


py.tight_layout()
#py.savefig('results/tmp.png')

# %% [markdown]
# ### E772

# %%
# E772

data['E772 Q=5.5']=np.loadtxt("plots/data_E772_Q=5.5.dat",skiprows=0)
data['E772 Q=6.5']=np.loadtxt("plots/data_E772_Q=6.5.dat",skiprows=0)
data['E772 Q=7.5']=np.loadtxt("plots/data_E772_Q=7.5.dat",skiprows=0)
data['E772 Q=8.5']=np.loadtxt("plots/data_E772_Q=8.5.dat",skiprows=0)
data['E772 Q=11.5']=np.loadtxt("plots/data_E772_Q=11.5.dat",skiprows=0)
data['E772 Q=12.5']=np.loadtxt("plots/data_E772_Q=12.5.dat",skiprows=0)

curve['E772 Q=5.5']=np.loadtxt("plots/curve_E772_Q=5.5.dat",skiprows=0)
curve['E772 Q=6.5']=np.loadtxt("plots/curve_E772_Q=6.5.dat",skiprows=0)
curve['E772 Q=7.5']=np.loadtxt("plots/curve_E772_Q=7.5.dat",skiprows=0)
curve['E772 Q=8.5']=np.loadtxt("plots/curve_E772_Q=8.5.dat",skiprows=0)
curve['E772 Q=11.5']=np.loadtxt("plots/curve_E772_Q=11.5.dat",skiprows=0)
curve['E772 Q=12.5']=np.loadtxt("plots/curve_E772_Q=12.5.dat",skiprows=0)

# %%
nrows,ncols=1,1
py.figure(figsize=(ncols*7,nrows*8))

ax=py.subplot(nrows,ncols,1)
#Q=5.5
ncut=28
ax.plot(curve['E772 Q=5.5'][:ncut,0].T, curve['E772 Q=5.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E772 Q=5.5'][:ncut,0].T, (curve['E772 Q=5.5'][:ncut,1]-curve['E772 Q=5.5'][:ncut,2]).T, (curve['E772 Q=5.5'][:ncut,1]+curve['E772 Q=5.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E772 Q=5.5'][:,0].T, data['E772 Q=5.5'][:,1], yerr=((data['E772 Q=5.5'][:,2]**2+data['E772 Q=5.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#Q=6.5
ncut=33
ax.plot(curve['E772 Q=6.5'][:ncut,0].T, curve['E772 Q=6.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E772 Q=6.5'][:ncut,0].T, (curve['E772 Q=6.5'][:ncut,1]-curve['E772 Q=6.5'][:ncut,2]).T, (curve['E772 Q=6.5'][:ncut,1]+curve['E772 Q=6.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E772 Q=6.5'][:,0].T, data['E772 Q=6.5'][:,1], yerr=((data['E772 Q=6.5'][:,2]**2+data['E772 Q=6.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#Q=7.5
ncut=38
ax.plot(curve['E772 Q=7.5'][:ncut,0].T, curve['E772 Q=7.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E772 Q=7.5'][:ncut,0].T, (curve['E772 Q=7.5'][:ncut,1]-curve['E772 Q=7.5'][:ncut,2]).T, (curve['E772 Q=7.5'][:ncut,1]+curve['E772 Q=7.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E772 Q=7.5'][:,0].T, data['E772 Q=7.5'][:,1], yerr=((data['E772 Q=7.5'][:,2]**2+data['E772 Q=7.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#Q=8.5
ncut=43
ax.plot(curve['E772 Q=8.5'][:ncut,0].T, curve['E772 Q=8.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E772 Q=8.5'][:ncut,0].T, (curve['E772 Q=8.5'][:ncut,1]-curve['E772 Q=8.5'][:ncut,2]).T, (curve['E772 Q=8.5'][:ncut,1]+curve['E772 Q=8.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E772 Q=8.5'][:,0].T, data['E772 Q=8.5'][:,1], yerr=((data['E772 Q=8.5'][:,2]**2+data['E772 Q=8.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#Q=11.5
ncut=43
ax.plot(curve['E772 Q=11.5'][:ncut,0].T, curve['E772 Q=11.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E772 Q=11.5'][:ncut,0].T, (curve['E772 Q=11.5'][:ncut,1]-curve['E772 Q=11.5'][:ncut,2]).T, (curve['E772 Q=11.5'][:ncut,1]+curve['E772 Q=11.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E772 Q=11.5'][:,0].T, data['E772 Q=11.5'][:,1], yerr=((data['E772 Q=11.5'][:,2]**2+data['E772 Q=11.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#Q=12.5
ncut=43
ax.plot(curve['E772 Q=12.5'][:ncut,0].T, curve['E772 Q=12.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['E772 Q=12.5'][:ncut,0].T, (curve['E772 Q=12.5'][:ncut,1]-curve['E772 Q=12.5'][:ncut,2]).T, (curve['E772 Q=12.5'][:ncut,1]+curve['E772 Q=12.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['E772 Q=12.5'][:,0].T, data['E772 Q=12.5'][:,1], yerr=((data['E772 Q=12.5'][:,2]**2+data['E772 Q=12.5'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#setting
ax.set_xlabel(r'$q_T~\rm(GeV)$',size=30)
ax.set_ylabel(r'$Ed\sigma/d^3q~\rm(GeV^{-4})$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(1e-14,1e-6)
ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E772 800\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)

py.tight_layout()
#py.savefig('results/tmp.png')

# %% [markdown]
# ### D0 Run I

# %%
data['D0 RunI']=np.loadtxt("plots/data_D0I_Q=91.2.dat",skiprows=0)
curve['D0 RunI']=np.loadtxt("plots/curve_D0I_Q=91.2.dat",skiprows=0)

# %%
nrows,ncols=1,1
py.figure(figsize=(ncols*7,nrows*8))

ax=py.subplot(nrows,ncols,1)
#Q=5.5
ncut=250
ax.plot(curve['D0 RunI'][:ncut,0].T, curve['D0 RunI'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['D0 RunI'][:ncut,0].T, (curve['D0 RunI'][:ncut,1]-curve['D0 RunI'][:ncut,2]).T, (curve['D0 RunI'][:ncut,1]+curve['D0 RunI'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['D0 RunI'][:,0].T, data['D0 RunI'][:,1], yerr=((data['D0 RunI'][:,2]**2+data['D0 RunI'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#setting
ax.set_xlabel(r'$q_T~\rm(GeV)$',size=30)
ax.set_ylabel(r'$d\sigma/dq_T~\rm(GeV^{-3})$',size=30)
ax.set_xlim(0,25)
ax.set_ylim(0,1e-7)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'D0 Run-I',horizontalalignment='center',transform=ax.transAxes,size=20)

py.tight_layout()
#py.savefig('results/tmp.png')

# %% [markdown]
# ### D0 Run II

# %%
data['D0 RunII']=np.loadtxt("plots/data_D0II_Q=91.2.dat",skiprows=0)
curve['D0 RunII']=np.loadtxt("plots/curve_D0II_Q=91.2.dat",skiprows=0)

# %%
nrows,ncols=1,1
py.figure(figsize=(ncols*7,nrows*8))

ax=py.subplot(nrows,ncols,1)
#Q=5.5
ncut=250
ax.plot(curve['D0 RunII'][:ncut,0].T, curve['D0 RunII'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['D0 RunII'][:ncut,0].T, (curve['D0 RunII'][:ncut,1]-curve['D0 RunII'][:ncut,2]).T, (curve['D0 RunII'][:ncut,1]+curve['D0 RunII'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['D0 RunII'][:,0].T, data['D0 RunII'][:,1], yerr=((data['D0 RunII'][:,2]**2+data['D0 RunII'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#setting
ax.set_xlabel(r'$q_T~\rm(GeV)$',size=30)
ax.set_ylabel(r'$d\sigma/dq_T~\rm(GeV^{-3})$',size=30)
ax.set_xlim(0,25)
ax.set_ylim(0,1e-7)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'D0 Run-II',horizontalalignment='center',transform=ax.transAxes,size=20)

py.tight_layout()
#py.savefig('results/tmp.png')

# %% [markdown]
# ### CDF Run I

# %%
data['CDF RunI']=np.loadtxt("plots/data_CDFI_Q=91.2.dat",skiprows=0)
curve['CDF RunI']=np.loadtxt("plots/curve_CDFI_Q=91.2.dat",skiprows=0)

# %%
nrows,ncols=1,1
py.figure(figsize=(ncols*7,nrows*8))

ax=py.subplot(nrows,ncols,1)
#Q=5.5
ncut=250
ax.plot(curve['CDF RunI'][:ncut,0].T, curve['CDF RunI'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['CDF RunI'][:ncut,0].T, (curve['CDF RunI'][:ncut,1]-curve['CDF RunI'][:ncut,2]).T, (curve['CDF RunI'][:ncut,1]+curve['CDF RunI'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['CDF RunI'][:,0].T, data['CDF RunI'][:,1], yerr=((data['CDF RunI'][:,2]**2+data['CDF RunI'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#setting
ax.set_xlabel(r'$q_T~\rm(GeV)$',size=30)
ax.set_ylabel(r'$d\sigma/dq_T~\rm(GeV^{-3})$',size=30)
ax.set_xlim(0,25)
ax.set_ylim(0,1e-7)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'CDF Run-I',horizontalalignment='center',transform=ax.transAxes,size=20)

py.tight_layout()
#py.savefig('results/tmp.png')

# %% [markdown]
# ### CDF Run II

# %%
data['CDF RunII']=np.loadtxt("plots/data_CDFII_Q=91.2.dat",skiprows=0)
curve['CDF RunII']=np.loadtxt("plots/curve_CDFII_Q=91.2.dat",skiprows=0)

# %%
nrows,ncols=1,1
py.figure(figsize=(ncols*7,nrows*8))

ax=py.subplot(nrows,ncols,1)
#Q=5.5
ncut=250
ax.plot(curve['CDF RunII'][:ncut,0].T, curve['CDF RunII'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(curve['CDF RunII'][:ncut,0].T, (curve['CDF RunII'][:ncut,1]-curve['CDF RunII'][:ncut,2]).T, (curve['CDF RunII'][:ncut,1]+curve['CDF RunII'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
ax.errorbar(data['CDF RunII'][:,0].T, data['CDF RunII'][:,1], yerr=((data['CDF RunII'][:,2]**2+data['CDF RunII'][:,3]**2)**0.5).T, marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#setting
ax.set_xlabel(r'$q_T~\rm(GeV)$',size=30)
ax.set_ylabel(r'$d\sigma/dq_T~\rm(GeV^{-3})$',size=30)
ax.set_xlim(0,25)
ax.set_ylim(0,1e-7)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'CDF Run-II',horizontalalignment='center',transform=ax.transAxes,size=20)

py.tight_layout()
#py.savefig('results/tmp.png')

# %% [markdown]
# ## Alpha
