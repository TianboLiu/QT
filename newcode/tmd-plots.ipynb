# %% [markdown]
# # Compare

# %%
import sys,os
import numpy as np
import pandas as pd
import pylab as py
from  matplotlib import rc
from matplotlib.colors import LogNorm
from matplotlib.font_manager import FontProperties
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text',usetex=True)
# %matplotlib inline
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %% [markdown]
# ## Fit curves

# %%
fu = {}

# %% [markdown]
# ### E288 200GeV

# %%
# E288 200

fu['E288 200 x=0.2 Q0=4.5']=np.loadtxt("tmdplots/f_E288_200_x=0.2_Q0=4.5.dat",skiprows=0)
fu['E288 200 x=0.2 Q0=5.5']=np.loadtxt("tmdplots/f_E288_200_x=0.2_Q0=5.5.dat",skiprows=0)
fu['E288 200 x=0.2 Q0=6.5']=np.loadtxt("tmdplots/f_E288_200_x=0.2_Q0=6.5.dat",skiprows=0)
fu['E288 200 x=0.2 Q0=7.5']=np.loadtxt("tmdplots/f_E288_200_x=0.2_Q0=7.5.dat",skiprows=0)
fu['E288 200 x=0.2 Q0=8.5']=np.loadtxt("tmdplots/f_E288_200_x=0.2_Q0=8.5.dat",skiprows=0)

fu['E288 200 x=0.1 Q0=4.5']=np.loadtxt("tmdplots/f_E288_200_x=0.1_Q0=4.5.dat",skiprows=0)
fu['E288 200 x=0.1 Q0=5.5']=np.loadtxt("tmdplots/f_E288_200_x=0.1_Q0=5.5.dat",skiprows=0)
fu['E288 200 x=0.1 Q0=6.5']=np.loadtxt("tmdplots/f_E288_200_x=0.1_Q0=6.5.dat",skiprows=0)
fu['E288 200 x=0.1 Q0=7.5']=np.loadtxt("tmdplots/f_E288_200_x=0.1_Q0=7.5.dat",skiprows=0)
fu['E288 200 x=0.1 Q0=8.5']=np.loadtxt("tmdplots/f_E288_200_x=0.1_Q0=8.5.dat",skiprows=0)

# %%
nrows,ncols=2,2
py.figure(figsize=(ncols*7,nrows*8))

ax=py.subplot(nrows,ncols,1)
#Q=4.5
ncut=2300
ax.plot(fu['E288 200 x=0.2 Q0=4.5'][:ncut,0].T, fu['E288 200 x=0.2 Q0=4.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(fu['E288 200 x=0.2 Q0=4.5'][:ncut,0].T,\
                (fu['E288 200 x=0.2 Q0=4.5'][:ncut,1]-fu['E288 200 x=0.2 Q0=4.5'][:ncut,2]).T,\
                (fu['E288 200 x=0.2 Q0=4.5'][:ncut,1]+fu['E288 200 x=0.2 Q0=4.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
#Q=5.5
ncut=2300
ax.plot(fu['E288 200 x=0.2 Q0=5.5'][:ncut,0].T, fu['E288 200 x=0.2 Q0=5.5'][:ncut,1].T,color='red',ls='-')
ax.fill_between(fu['E288 200 x=0.2 Q0=5.5'][:ncut,0].T,\
                (fu['E288 200 x=0.2 Q0=5.5'][:ncut,1]-fu['E288 200 x=0.2 Q0=5.5'][:ncut,2]).T,\
                (fu['E288 200 x=0.2 Q0=5.5'][:ncut,1]+fu['E288 200 x=0.2 Q0=5.5'][:ncut,2]).T,\
                linewidth=0, color="red", alpha=0.5)
#Q=6.5
ncut=2300
ax.plot(fu['E288 200 x=0.2 Q0=6.5'][:ncut,0].T, fu['E288 200 x=0.2 Q0=6.5'][:ncut,1].T,color='green',ls='-')
ax.fill_between(fu['E288 200 x=0.2 Q0=6.5'][:ncut,0].T,\
                (fu['E288 200 x=0.2 Q0=6.5'][:ncut,1]-fu['E288 200 x=0.2 Q0=6.5'][:ncut,2]).T,\
                (fu['E288 200 x=0.2 Q0=6.5'][:ncut,1]+fu['E288 200 x=0.2 Q0=6.5'][:ncut,2]).T,\
                linewidth=0, color="green", alpha=0.5)
#Q=7.5
ncut=2300
ax.plot(fu['E288 200 x=0.2 Q0=7.5'][:ncut,0].T, fu['E288 200 x=0.2 Q0=7.5'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(fu['E288 200 x=0.2 Q0=7.5'][:ncut,0].T,\
                (fu['E288 200 x=0.2 Q0=7.5'][:ncut,1]-fu['E288 200 x=0.2 Q0=7.5'][:ncut,2]).T,\
                (fu['E288 200 x=0.2 Q0=7.5'][:ncut,1]+fu['E288 200 x=0.2 Q0=7.5'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)
#Q=8.5
ncut=2300
ax.plot(fu['E288 200 x=0.2 Q0=8.5'][:ncut,0].T, fu['E288 200 x=0.2 Q0=8.5'][:ncut,1].T,color='orange',ls='-')
ax.fill_between(fu['E288 200 x=0.2 Q0=8.5'][:ncut,0].T,\
                (fu['E288 200 x=0.2 Q0=8.5'][:ncut,1]-fu['E288 200 x=0.2 Q0=8.5'][:ncut,2]).T,\
                (fu['E288 200 x=0.2 Q0=8.5'][:ncut,1]+fu['E288 200 x=0.2 Q0=8.5'][:ncut,2]).T,\
                linewidth=0, color="orange", alpha=0.5)
#setting
ax.set_xlabel(r'$b_T~\rm(GeV^{-1})$',size=30)
ax.set_ylabel(r'$f(x,b)$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(0,5)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E288~200\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.85,r'x=0.2',horizontalalignment='center',transform=ax.transAxes,size=20)

ax=py.subplot(nrows,ncols,2)
#Q=4.5
ncut=2300
ax.plot(fu['E288 200 x=0.2 Q0=4.5'][:ncut,0].T, fu['E288 200 x=0.2 Q0=4.5'][:ncut,0].T*fu['E288 200 x=0.2 Q0=4.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(fu['E288 200 x=0.2 Q0=4.5'][:ncut,0].T,\
                fu['E288 200 x=0.2 Q0=4.5'][:ncut,0].T*(fu['E288 200 x=0.2 Q0=4.5'][:ncut,1]-fu['E288 200 x=0.2 Q0=4.5'][:ncut,2]).T,\
                fu['E288 200 x=0.2 Q0=4.5'][:ncut,0].T*(fu['E288 200 x=0.2 Q0=4.5'][:ncut,1]+fu['E288 200 x=0.2 Q0=4.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
#Q=5.5
ncut=2300
ax.plot(fu['E288 200 x=0.2 Q0=5.5'][:ncut,0].T, fu['E288 200 x=0.2 Q0=5.5'][:ncut,0].T*fu['E288 200 x=0.2 Q0=5.5'][:ncut,1].T,color='red',ls='-')
ax.fill_between(fu['E288 200 x=0.2 Q0=5.5'][:ncut,0].T,\
                fu['E288 200 x=0.2 Q0=5.5'][:ncut,0].T*(fu['E288 200 x=0.2 Q0=5.5'][:ncut,1]-fu['E288 200 x=0.2 Q0=5.5'][:ncut,2]).T,\
                fu['E288 200 x=0.2 Q0=5.5'][:ncut,0].T*(fu['E288 200 x=0.2 Q0=5.5'][:ncut,1]+fu['E288 200 x=0.2 Q0=5.5'][:ncut,2]).T,\
                linewidth=0, color="red", alpha=0.5)
#Q=6.5
ncut=2300
ax.plot(fu['E288 200 x=0.2 Q0=6.5'][:ncut,0].T, fu['E288 200 x=0.2 Q0=6.5'][:ncut,0].T*fu['E288 200 x=0.2 Q0=6.5'][:ncut,1].T,color='green',ls='-')
ax.fill_between(fu['E288 200 x=0.2 Q0=6.5'][:ncut,0].T,\
                fu['E288 200 x=0.2 Q0=6.5'][:ncut,0].T*(fu['E288 200 x=0.2 Q0=6.5'][:ncut,1]-fu['E288 200 x=0.2 Q0=6.5'][:ncut,2]).T,\
                fu['E288 200 x=0.2 Q0=6.5'][:ncut,0].T*(fu['E288 200 x=0.2 Q0=6.5'][:ncut,1]+fu['E288 200 x=0.2 Q0=6.5'][:ncut,2]).T,\
                linewidth=0, color="green", alpha=0.5)
#Q=7.5
ncut=2300
ax.plot(fu['E288 200 x=0.2 Q0=7.5'][:ncut,0].T, fu['E288 200 x=0.2 Q0=7.5'][:ncut,0].T*fu['E288 200 x=0.2 Q0=7.5'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(fu['E288 200 x=0.2 Q0=7.5'][:ncut,0].T,\
                fu['E288 200 x=0.2 Q0=7.5'][:ncut,0].T*(fu['E288 200 x=0.2 Q0=7.5'][:ncut,1]-fu['E288 200 x=0.2 Q0=7.5'][:ncut,2]).T,\
                fu['E288 200 x=0.2 Q0=7.5'][:ncut,0].T*(fu['E288 200 x=0.2 Q0=7.5'][:ncut,1]+fu['E288 200 x=0.2 Q0=7.5'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)
#Q=8.5
ncut=2300
ax.plot(fu['E288 200 x=0.2 Q0=8.5'][:ncut,0].T, fu['E288 200 x=0.2 Q0=8.5'][:ncut,0].T*fu['E288 200 x=0.2 Q0=8.5'][:ncut,1].T,color='orange',ls='-')
ax.fill_between(fu['E288 200 x=0.2 Q0=8.5'][:ncut,0].T,\
                fu['E288 200 x=0.2 Q0=8.5'][:ncut,0].T*(fu['E288 200 x=0.2 Q0=8.5'][:ncut,1]-fu['E288 200 x=0.2 Q0=8.5'][:ncut,2]).T,\
                fu['E288 200 x=0.2 Q0=8.5'][:ncut,0].T*(fu['E288 200 x=0.2 Q0=8.5'][:ncut,1]+fu['E288 200 x=0.2 Q0=8.5'][:ncut,2]).T,\
                linewidth=0, color="orange", alpha=0.5)
#setting
ax.set_xlabel(r'$b_T~\rm(GeV^{-1})$',size=30)
ax.set_ylabel(r'$bf(x,b)~\rm(GeV^{-1})$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(0,7)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E288~200\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.85,r'x=0.2',horizontalalignment='center',transform=ax.transAxes,size=20)

ax=py.subplot(nrows,ncols,3)
#Q=4.5
ncut=2300
ax.plot(fu['E288 200 x=0.1 Q0=4.5'][:ncut,0].T, fu['E288 200 x=0.1 Q0=4.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(fu['E288 200 x=0.1 Q0=4.5'][:ncut,0].T,\
                (fu['E288 200 x=0.1 Q0=4.5'][:ncut,1]-fu['E288 200 x=0.1 Q0=4.5'][:ncut,2]).T,\
                (fu['E288 200 x=0.1 Q0=4.5'][:ncut,1]+fu['E288 200 x=0.1 Q0=4.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
#Q=5.5
ncut=2300
ax.plot(fu['E288 200 x=0.1 Q0=5.5'][:ncut,0].T, fu['E288 200 x=0.1 Q0=5.5'][:ncut,1].T,color='red',ls='-')
ax.fill_between(fu['E288 200 x=0.1 Q0=5.5'][:ncut,0].T,\
                (fu['E288 200 x=0.1 Q0=5.5'][:ncut,1]-fu['E288 200 x=0.1 Q0=5.5'][:ncut,2]).T,\
                (fu['E288 200 x=0.1 Q0=5.5'][:ncut,1]+fu['E288 200 x=0.1 Q0=5.5'][:ncut,2]).T,\
                linewidth=0, color="red", alpha=0.5)
#Q=6.5
ncut=2300
ax.plot(fu['E288 200 x=0.1 Q0=6.5'][:ncut,0].T, fu['E288 200 x=0.1 Q0=6.5'][:ncut,1].T,color='green',ls='-')
ax.fill_between(fu['E288 200 x=0.1 Q0=6.5'][:ncut,0].T,\
                (fu['E288 200 x=0.1 Q0=6.5'][:ncut,1]-fu['E288 200 x=0.1 Q0=6.5'][:ncut,2]).T,\
                (fu['E288 200 x=0.1 Q0=6.5'][:ncut,1]+fu['E288 200 x=0.1 Q0=6.5'][:ncut,2]).T,\
                linewidth=0, color="green", alpha=0.5)
#Q=7.5
ncut=2300
ax.plot(fu['E288 200 x=0.1 Q0=7.5'][:ncut,0].T, fu['E288 200 x=0.1 Q0=7.5'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(fu['E288 200 x=0.1 Q0=7.5'][:ncut,0].T,\
                (fu['E288 200 x=0.1 Q0=7.5'][:ncut,1]-fu['E288 200 x=0.1 Q0=7.5'][:ncut,2]).T,\
                (fu['E288 200 x=0.1 Q0=7.5'][:ncut,1]+fu['E288 200 x=0.1 Q0=7.5'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)
#Q=8.5
ncut=2300
ax.plot(fu['E288 200 x=0.1 Q0=8.5'][:ncut,0].T, fu['E288 200 x=0.1 Q0=8.5'][:ncut,1].T,color='orange',ls='-')
ax.fill_between(fu['E288 200 x=0.1 Q0=8.5'][:ncut,0].T,\
                (fu['E288 200 x=0.1 Q0=8.5'][:ncut,1]-fu['E288 200 x=0.1 Q0=8.5'][:ncut,2]).T,\
                (fu['E288 200 x=0.1 Q0=8.5'][:ncut,1]+fu['E288 200 x=0.1 Q0=8.5'][:ncut,2]).T,\
                linewidth=0, color="orange", alpha=0.5)
#setting
ax.set_xlabel(r'$b_T~\rm(GeV^{-1})$',size=30)
ax.set_ylabel(r'$f(x,b)$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(0,10)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E288~200\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.85,r'x=0.1',horizontalalignment='center',transform=ax.transAxes,size=20)

ax=py.subplot(nrows,ncols,4)
#Q=4.5
ncut=2300
ax.plot(fu['E288 200 x=0.1 Q0=4.5'][:ncut,0].T, fu['E288 200 x=0.1 Q0=4.5'][:ncut,0].T*fu['E288 200 x=0.1 Q0=4.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(fu['E288 200 x=0.1 Q0=4.5'][:ncut,0].T,\
                fu['E288 200 x=0.1 Q0=4.5'][:ncut,0].T*(fu['E288 200 x=0.1 Q0=4.5'][:ncut,1]-fu['E288 200 x=0.1 Q0=4.5'][:ncut,2]).T,\
                fu['E288 200 x=0.1 Q0=4.5'][:ncut,0].T*(fu['E288 200 x=0.1 Q0=4.5'][:ncut,1]+fu['E288 200 x=0.1 Q0=4.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
#Q=5.5
ncut=2300
ax.plot(fu['E288 200 x=0.1 Q0=5.5'][:ncut,0].T, fu['E288 200 x=0.1 Q0=5.5'][:ncut,0].T*fu['E288 200 x=0.1 Q0=5.5'][:ncut,1].T,color='red',ls='-')
ax.fill_between(fu['E288 200 x=0.1 Q0=5.5'][:ncut,0].T,\
                fu['E288 200 x=0.1 Q0=5.5'][:ncut,0].T*(fu['E288 200 x=0.1 Q0=5.5'][:ncut,1]-fu['E288 200 x=0.1 Q0=5.5'][:ncut,2]).T,\
                fu['E288 200 x=0.1 Q0=5.5'][:ncut,0].T*(fu['E288 200 x=0.1 Q0=5.5'][:ncut,1]+fu['E288 200 x=0.1 Q0=5.5'][:ncut,2]).T,\
                linewidth=0, color="red", alpha=0.5)
#Q=6.5
ncut=2300
ax.plot(fu['E288 200 x=0.1 Q0=6.5'][:ncut,0].T, fu['E288 200 x=0.1 Q0=6.5'][:ncut,0].T*fu['E288 200 x=0.1 Q0=6.5'][:ncut,1].T,color='green',ls='-')
ax.fill_between(fu['E288 200 x=0.1 Q0=6.5'][:ncut,0].T,\
                fu['E288 200 x=0.1 Q0=6.5'][:ncut,0].T*(fu['E288 200 x=0.1 Q0=6.5'][:ncut,1]-fu['E288 200 x=0.1 Q0=6.5'][:ncut,2]).T,\
                fu['E288 200 x=0.1 Q0=6.5'][:ncut,0].T*(fu['E288 200 x=0.1 Q0=6.5'][:ncut,1]+fu['E288 200 x=0.1 Q0=6.5'][:ncut,2]).T,\
                linewidth=0, color="green", alpha=0.5)
#Q=7.5
ncut=2300
ax.plot(fu['E288 200 x=0.1 Q0=7.5'][:ncut,0].T, fu['E288 200 x=0.1 Q0=7.5'][:ncut,0].T*fu['E288 200 x=0.1 Q0=7.5'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(fu['E288 200 x=0.1 Q0=7.5'][:ncut,0].T,\
                fu['E288 200 x=0.1 Q0=7.5'][:ncut,0].T*(fu['E288 200 x=0.1 Q0=7.5'][:ncut,1]-fu['E288 200 x=0.1 Q0=7.5'][:ncut,2]).T,\
                fu['E288 200 x=0.1 Q0=7.5'][:ncut,0].T*(fu['E288 200 x=0.1 Q0=7.5'][:ncut,1]+fu['E288 200 x=0.1 Q0=7.5'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)
#Q=8.5
ncut=2300
ax.plot(fu['E288 200 x=0.1 Q0=8.5'][:ncut,0].T, fu['E288 200 x=0.1 Q0=8.5'][:ncut,0].T*fu['E288 200 x=0.1 Q0=8.5'][:ncut,1].T,color='orange',ls='-')
ax.fill_between(fu['E288 200 x=0.1 Q0=8.5'][:ncut,0].T,\
                fu['E288 200 x=0.1 Q0=8.5'][:ncut,0].T*(fu['E288 200 x=0.1 Q0=8.5'][:ncut,1]-fu['E288 200 x=0.1 Q0=8.5'][:ncut,2]).T,\
                fu['E288 200 x=0.1 Q0=8.5'][:ncut,0].T*(fu['E288 200 x=0.1 Q0=8.5'][:ncut,1]+fu['E288 200 x=0.1 Q0=8.5'][:ncut,2]).T,\
                linewidth=0, color="orange", alpha=0.5)
#setting
ax.set_xlabel(r'$b_T~\rm(GeV^{-1})$',size=30)
ax.set_ylabel(r'$bf(x,b)~\rm(GeV^{-1})$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(0,14)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E288~200\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.85,r'x=0.1',horizontalalignment='center',transform=ax.transAxes,size=20)
py.tight_layout()

#py.savefig('results/tmp.png')

# %% [markdown]
# ### E288 300GeV

# %%
# E288 300

fu['E288 300 x=0.2 Q0=4.5']=np.loadtxt("tmdplots/f_E288_300_x=0.2_Q0=4.5.dat",skiprows=0)
fu['E288 300 x=0.2 Q0=5.5']=np.loadtxt("tmdplots/f_E288_300_x=0.2_Q0=5.5.dat",skiprows=0)
fu['E288 300 x=0.2 Q0=6.5']=np.loadtxt("tmdplots/f_E288_300_x=0.2_Q0=6.5.dat",skiprows=0)
fu['E288 300 x=0.2 Q0=7.5']=np.loadtxt("tmdplots/f_E288_300_x=0.2_Q0=7.5.dat",skiprows=0)
fu['E288 300 x=0.2 Q0=8.5']=np.loadtxt("tmdplots/f_E288_300_x=0.2_Q0=8.5.dat",skiprows=0)

fu['E288 300 x=0.1 Q0=4.5']=np.loadtxt("tmdplots/f_E288_300_x=0.1_Q0=4.5.dat",skiprows=0)
fu['E288 300 x=0.1 Q0=5.5']=np.loadtxt("tmdplots/f_E288_300_x=0.1_Q0=5.5.dat",skiprows=0)
fu['E288 300 x=0.1 Q0=6.5']=np.loadtxt("tmdplots/f_E288_300_x=0.1_Q0=6.5.dat",skiprows=0)
fu['E288 300 x=0.1 Q0=7.5']=np.loadtxt("tmdplots/f_E288_300_x=0.1_Q0=7.5.dat",skiprows=0)
fu['E288 300 x=0.1 Q0=8.5']=np.loadtxt("tmdplots/f_E288_300_x=0.1_Q0=8.5.dat",skiprows=0)

# %%
nrows,ncols=2,2
py.figure(figsize=(ncols*7,nrows*8))

ax=py.subplot(nrows,ncols,1)
#Q=4.5
ncut=2300
ax.plot(fu['E288 300 x=0.2 Q0=4.5'][:ncut,0].T, fu['E288 300 x=0.2 Q0=4.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(fu['E288 300 x=0.2 Q0=4.5'][:ncut,0].T,\
                (fu['E288 300 x=0.2 Q0=4.5'][:ncut,1]-fu['E288 300 x=0.2 Q0=4.5'][:ncut,2]).T,\
                (fu['E288 300 x=0.2 Q0=4.5'][:ncut,1]+fu['E288 300 x=0.2 Q0=4.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
#Q=5.5
ncut=2300
ax.plot(fu['E288 300 x=0.2 Q0=5.5'][:ncut,0].T, fu['E288 300 x=0.2 Q0=5.5'][:ncut,1].T,color='red',ls='-')
ax.fill_between(fu['E288 300 x=0.2 Q0=5.5'][:ncut,0].T,\
                (fu['E288 300 x=0.2 Q0=5.5'][:ncut,1]-fu['E288 300 x=0.2 Q0=5.5'][:ncut,2]).T,\
                (fu['E288 300 x=0.2 Q0=5.5'][:ncut,1]+fu['E288 300 x=0.2 Q0=5.5'][:ncut,2]).T,\
                linewidth=0, color="red", alpha=0.5)
#Q=6.5
ncut=2300
ax.plot(fu['E288 300 x=0.2 Q0=6.5'][:ncut,0].T, fu['E288 300 x=0.2 Q0=6.5'][:ncut,1].T,color='green',ls='-')
ax.fill_between(fu['E288 300 x=0.2 Q0=6.5'][:ncut,0].T,\
                (fu['E288 300 x=0.2 Q0=6.5'][:ncut,1]-fu['E288 300 x=0.2 Q0=6.5'][:ncut,2]).T,\
                (fu['E288 300 x=0.2 Q0=6.5'][:ncut,1]+fu['E288 300 x=0.2 Q0=6.5'][:ncut,2]).T,\
                linewidth=0, color="green", alpha=0.5)
#Q=7.5
ncut=2300
ax.plot(fu['E288 300 x=0.2 Q0=7.5'][:ncut,0].T, fu['E288 300 x=0.2 Q0=7.5'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(fu['E288 300 x=0.2 Q0=7.5'][:ncut,0].T,\
                (fu['E288 300 x=0.2 Q0=7.5'][:ncut,1]-fu['E288 300 x=0.2 Q0=7.5'][:ncut,2]).T,\
                (fu['E288 300 x=0.2 Q0=7.5'][:ncut,1]+fu['E288 300 x=0.2 Q0=7.5'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)
#Q=8.5
ncut=2300
ax.plot(fu['E288 300 x=0.2 Q0=8.5'][:ncut,0].T, fu['E288 300 x=0.2 Q0=8.5'][:ncut,1].T,color='orange',ls='-')
ax.fill_between(fu['E288 300 x=0.2 Q0=8.5'][:ncut,0].T,\
                (fu['E288 300 x=0.2 Q0=8.5'][:ncut,1]-fu['E288 300 x=0.2 Q0=8.5'][:ncut,2]).T,\
                (fu['E288 300 x=0.2 Q0=8.5'][:ncut,1]+fu['E288 300 x=0.2 Q0=8.5'][:ncut,2]).T,\
                linewidth=0, color="orange", alpha=0.5)
#setting
ax.set_xlabel(r'$b_T~\rm(GeV^{-1})$',size=30)
ax.set_ylabel(r'$f(x,b)$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(0,5)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E288~300\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.85,r'x=0.2',horizontalalignment='center',transform=ax.transAxes,size=20)

ax=py.subplot(nrows,ncols,2)
#Q=4.5
ncut=2300
ax.plot(fu['E288 300 x=0.2 Q0=4.5'][:ncut,0].T, fu['E288 300 x=0.2 Q0=4.5'][:ncut,0].T*fu['E288 300 x=0.2 Q0=4.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(fu['E288 300 x=0.2 Q0=4.5'][:ncut,0].T,\
                fu['E288 300 x=0.2 Q0=4.5'][:ncut,0].T*(fu['E288 300 x=0.2 Q0=4.5'][:ncut,1]-fu['E288 300 x=0.2 Q0=4.5'][:ncut,2]).T,\
                fu['E288 300 x=0.2 Q0=4.5'][:ncut,0].T*(fu['E288 300 x=0.2 Q0=4.5'][:ncut,1]+fu['E288 300 x=0.2 Q0=4.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
#Q=5.5
ncut=2300
ax.plot(fu['E288 300 x=0.2 Q0=5.5'][:ncut,0].T, fu['E288 300 x=0.2 Q0=5.5'][:ncut,0].T*fu['E288 300 x=0.2 Q0=5.5'][:ncut,1].T,color='red',ls='-')
ax.fill_between(fu['E288 300 x=0.2 Q0=5.5'][:ncut,0].T,\
                fu['E288 300 x=0.2 Q0=5.5'][:ncut,0].T*(fu['E288 300 x=0.2 Q0=5.5'][:ncut,1]-fu['E288 300 x=0.2 Q0=5.5'][:ncut,2]).T,\
                fu['E288 300 x=0.2 Q0=5.5'][:ncut,0].T*(fu['E288 300 x=0.2 Q0=5.5'][:ncut,1]+fu['E288 300 x=0.2 Q0=5.5'][:ncut,2]).T,\
                linewidth=0, color="red", alpha=0.5)
#Q=6.5
ncut=2300
ax.plot(fu['E288 300 x=0.2 Q0=6.5'][:ncut,0].T, fu['E288 300 x=0.2 Q0=6.5'][:ncut,0].T*fu['E288 300 x=0.2 Q0=6.5'][:ncut,1].T,color='green',ls='-')
ax.fill_between(fu['E288 300 x=0.2 Q0=6.5'][:ncut,0].T,\
                fu['E288 300 x=0.2 Q0=6.5'][:ncut,0].T*(fu['E288 300 x=0.2 Q0=6.5'][:ncut,1]-fu['E288 300 x=0.2 Q0=6.5'][:ncut,2]).T,\
                fu['E288 300 x=0.2 Q0=6.5'][:ncut,0].T*(fu['E288 300 x=0.2 Q0=6.5'][:ncut,1]+fu['E288 300 x=0.2 Q0=6.5'][:ncut,2]).T,\
                linewidth=0, color="green", alpha=0.5)
#Q=7.5
ncut=2300
ax.plot(fu['E288 300 x=0.2 Q0=7.5'][:ncut,0].T, fu['E288 300 x=0.2 Q0=7.5'][:ncut,0].T*fu['E288 300 x=0.2 Q0=7.5'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(fu['E288 300 x=0.2 Q0=7.5'][:ncut,0].T,\
                fu['E288 300 x=0.2 Q0=7.5'][:ncut,0].T*(fu['E288 300 x=0.2 Q0=7.5'][:ncut,1]-fu['E288 300 x=0.2 Q0=7.5'][:ncut,2]).T,\
                fu['E288 300 x=0.2 Q0=7.5'][:ncut,0].T*(fu['E288 300 x=0.2 Q0=7.5'][:ncut,1]+fu['E288 300 x=0.2 Q0=7.5'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)
#Q=8.5
ncut=2300
ax.plot(fu['E288 300 x=0.2 Q0=8.5'][:ncut,0].T, fu['E288 300 x=0.2 Q0=8.5'][:ncut,0].T*fu['E288 300 x=0.2 Q0=8.5'][:ncut,1].T,color='orange',ls='-')
ax.fill_between(fu['E288 300 x=0.2 Q0=8.5'][:ncut,0].T,\
                fu['E288 300 x=0.2 Q0=8.5'][:ncut,0].T*(fu['E288 300 x=0.2 Q0=8.5'][:ncut,1]-fu['E288 300 x=0.2 Q0=8.5'][:ncut,2]).T,\
                fu['E288 300 x=0.2 Q0=8.5'][:ncut,0].T*(fu['E288 300 x=0.2 Q0=8.5'][:ncut,1]+fu['E288 300 x=0.2 Q0=8.5'][:ncut,2]).T,\
                linewidth=0, color="orange", alpha=0.5)
#setting
ax.set_xlabel(r'$b_T~\rm(GeV^{-1})$',size=30)
ax.set_ylabel(r'$bf(x,b)~\rm(GeV^{-1})$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(0,7)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E288~300\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.85,r'x=0.2',horizontalalignment='center',transform=ax.transAxes,size=20)

ax=py.subplot(nrows,ncols,3)
#Q=4.5
ncut=2300
ax.plot(fu['E288 300 x=0.1 Q0=4.5'][:ncut,0].T, fu['E288 300 x=0.1 Q0=4.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(fu['E288 300 x=0.1 Q0=4.5'][:ncut,0].T,\
                (fu['E288 300 x=0.1 Q0=4.5'][:ncut,1]-fu['E288 300 x=0.1 Q0=4.5'][:ncut,2]).T,\
                (fu['E288 300 x=0.1 Q0=4.5'][:ncut,1]+fu['E288 300 x=0.1 Q0=4.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
#Q=5.5
ncut=2300
ax.plot(fu['E288 300 x=0.1 Q0=5.5'][:ncut,0].T, fu['E288 300 x=0.1 Q0=5.5'][:ncut,1].T,color='red',ls='-')
ax.fill_between(fu['E288 300 x=0.1 Q0=5.5'][:ncut,0].T,\
                (fu['E288 300 x=0.1 Q0=5.5'][:ncut,1]-fu['E288 300 x=0.1 Q0=5.5'][:ncut,2]).T,\
                (fu['E288 300 x=0.1 Q0=5.5'][:ncut,1]+fu['E288 300 x=0.1 Q0=5.5'][:ncut,2]).T,\
                linewidth=0, color="red", alpha=0.5)
#Q=6.5
ncut=2300
ax.plot(fu['E288 300 x=0.1 Q0=6.5'][:ncut,0].T, fu['E288 300 x=0.1 Q0=6.5'][:ncut,1].T,color='green',ls='-')
ax.fill_between(fu['E288 300 x=0.1 Q0=6.5'][:ncut,0].T,\
                (fu['E288 300 x=0.1 Q0=6.5'][:ncut,1]-fu['E288 300 x=0.1 Q0=6.5'][:ncut,2]).T,\
                (fu['E288 300 x=0.1 Q0=6.5'][:ncut,1]+fu['E288 300 x=0.1 Q0=6.5'][:ncut,2]).T,\
                linewidth=0, color="green", alpha=0.5)
#Q=7.5
ncut=2300
ax.plot(fu['E288 300 x=0.1 Q0=7.5'][:ncut,0].T, fu['E288 300 x=0.1 Q0=7.5'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(fu['E288 300 x=0.1 Q0=7.5'][:ncut,0].T,\
                (fu['E288 300 x=0.1 Q0=7.5'][:ncut,1]-fu['E288 300 x=0.1 Q0=7.5'][:ncut,2]).T,\
                (fu['E288 300 x=0.1 Q0=7.5'][:ncut,1]+fu['E288 300 x=0.1 Q0=7.5'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)
#Q=8.5
ncut=2300
ax.plot(fu['E288 300 x=0.1 Q0=8.5'][:ncut,0].T, fu['E288 300 x=0.1 Q0=8.5'][:ncut,1].T,color='orange',ls='-')
ax.fill_between(fu['E288 300 x=0.1 Q0=8.5'][:ncut,0].T,\
                (fu['E288 300 x=0.1 Q0=8.5'][:ncut,1]-fu['E288 300 x=0.1 Q0=8.5'][:ncut,2]).T,\
                (fu['E288 300 x=0.1 Q0=8.5'][:ncut,1]+fu['E288 300 x=0.1 Q0=8.5'][:ncut,2]).T,\
                linewidth=0, color="orange", alpha=0.5)
#setting
ax.set_xlabel(r'$b_T~\rm(GeV^{-1})$',size=30)
ax.set_ylabel(r'$f(x,b)$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(0,10)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E288~300\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.85,r'x=0.1',horizontalalignment='center',transform=ax.transAxes,size=20)

ax=py.subplot(nrows,ncols,4)
#Q=4.5
ncut=2300
ax.plot(fu['E288 300 x=0.1 Q0=4.5'][:ncut,0].T, fu['E288 300 x=0.1 Q0=4.5'][:ncut,0].T*fu['E288 300 x=0.1 Q0=4.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(fu['E288 300 x=0.1 Q0=4.5'][:ncut,0].T,\
                fu['E288 300 x=0.1 Q0=4.5'][:ncut,0].T*(fu['E288 300 x=0.1 Q0=4.5'][:ncut,1]-fu['E288 300 x=0.1 Q0=4.5'][:ncut,2]).T,\
                fu['E288 300 x=0.1 Q0=4.5'][:ncut,0].T*(fu['E288 300 x=0.1 Q0=4.5'][:ncut,1]+fu['E288 300 x=0.1 Q0=4.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
#Q=5.5
ncut=2300
ax.plot(fu['E288 300 x=0.1 Q0=5.5'][:ncut,0].T, fu['E288 300 x=0.1 Q0=5.5'][:ncut,0].T*fu['E288 300 x=0.1 Q0=5.5'][:ncut,1].T,color='red',ls='-')
ax.fill_between(fu['E288 300 x=0.1 Q0=5.5'][:ncut,0].T,\
                fu['E288 300 x=0.1 Q0=5.5'][:ncut,0].T*(fu['E288 300 x=0.1 Q0=5.5'][:ncut,1]-fu['E288 300 x=0.1 Q0=5.5'][:ncut,2]).T,\
                fu['E288 300 x=0.1 Q0=5.5'][:ncut,0].T*(fu['E288 300 x=0.1 Q0=5.5'][:ncut,1]+fu['E288 300 x=0.1 Q0=5.5'][:ncut,2]).T,\
                linewidth=0, color="red", alpha=0.5)
#Q=6.5
ncut=2300
ax.plot(fu['E288 300 x=0.1 Q0=6.5'][:ncut,0].T, fu['E288 300 x=0.1 Q0=6.5'][:ncut,0].T*fu['E288 300 x=0.1 Q0=6.5'][:ncut,1].T,color='green',ls='-')
ax.fill_between(fu['E288 300 x=0.1 Q0=6.5'][:ncut,0].T,\
                fu['E288 300 x=0.1 Q0=6.5'][:ncut,0].T*(fu['E288 300 x=0.1 Q0=6.5'][:ncut,1]-fu['E288 300 x=0.1 Q0=6.5'][:ncut,2]).T,\
                fu['E288 300 x=0.1 Q0=6.5'][:ncut,0].T*(fu['E288 300 x=0.1 Q0=6.5'][:ncut,1]+fu['E288 300 x=0.1 Q0=6.5'][:ncut,2]).T,\
                linewidth=0, color="green", alpha=0.5)
#Q=7.5
ncut=2300
ax.plot(fu['E288 300 x=0.1 Q0=7.5'][:ncut,0].T, fu['E288 300 x=0.1 Q0=7.5'][:ncut,0].T*fu['E288 300 x=0.1 Q0=7.5'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(fu['E288 300 x=0.1 Q0=7.5'][:ncut,0].T,\
                fu['E288 300 x=0.1 Q0=7.5'][:ncut,0].T*(fu['E288 300 x=0.1 Q0=7.5'][:ncut,1]-fu['E288 300 x=0.1 Q0=7.5'][:ncut,2]).T,\
                fu['E288 300 x=0.1 Q0=7.5'][:ncut,0].T*(fu['E288 300 x=0.1 Q0=7.5'][:ncut,1]+fu['E288 300 x=0.1 Q0=7.5'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)
#Q=8.5
ncut=2300
ax.plot(fu['E288 300 x=0.1 Q0=8.5'][:ncut,0].T, fu['E288 300 x=0.1 Q0=8.5'][:ncut,0].T*fu['E288 300 x=0.1 Q0=8.5'][:ncut,1].T,color='orange',ls='-')
ax.fill_between(fu['E288 300 x=0.1 Q0=8.5'][:ncut,0].T,\
                fu['E288 300 x=0.1 Q0=8.5'][:ncut,0].T*(fu['E288 300 x=0.1 Q0=8.5'][:ncut,1]-fu['E288 300 x=0.1 Q0=8.5'][:ncut,2]).T,\
                fu['E288 300 x=0.1 Q0=8.5'][:ncut,0].T*(fu['E288 300 x=0.1 Q0=8.5'][:ncut,1]+fu['E288 300 x=0.1 Q0=8.5'][:ncut,2]).T,\
                linewidth=0, color="orange", alpha=0.5)
#setting
ax.set_xlabel(r'$b_T~\rm(GeV^{-1})$',size=30)
ax.set_ylabel(r'$bf(x,b)~\rm(GeV^{-1})$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(0,14)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E288~300\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.85,r'x=0.1',horizontalalignment='center',transform=ax.transAxes,size=20)
py.tight_layout()

#py.savefig('results/tmp.png')

# %% [markdown]
# ### E288 400 GeV

# %%
# E288 400

fu['E288 400 x=0.2 Q0=5.5']=np.loadtxt("tmdplots/f_E288_400_x=0.2_Q0=5.5.dat",skiprows=0)
fu['E288 400 x=0.2 Q0=6.5']=np.loadtxt("tmdplots/f_E288_400_x=0.2_Q0=6.5.dat",skiprows=0)
fu['E288 400 x=0.2 Q0=7.5']=np.loadtxt("tmdplots/f_E288_400_x=0.2_Q0=7.5.dat",skiprows=0)
fu['E288 400 x=0.2 Q0=8.5']=np.loadtxt("tmdplots/f_E288_400_x=0.2_Q0=8.5.dat",skiprows=0)
fu['E288 400 x=0.2 Q0=11.5']=np.loadtxt("tmdplots/f_E288_400_x=0.2_Q0=11.5.dat",skiprows=0)
fu['E288 400 x=0.2 Q0=12.5']=np.loadtxt("tmdplots/f_E288_400_x=0.2_Q0=12.5.dat",skiprows=0)
fu['E288 400 x=0.2 Q0=13.5']=np.loadtxt("tmdplots/f_E288_400_x=0.2_Q0=13.5.dat",skiprows=0)

fu['E288 400 x=0.1 Q0=5.5']=np.loadtxt("tmdplots/f_E288_400_x=0.1_Q0=5.5.dat",skiprows=0)
fu['E288 400 x=0.1 Q0=6.5']=np.loadtxt("tmdplots/f_E288_400_x=0.1_Q0=6.5.dat",skiprows=0)
fu['E288 400 x=0.1 Q0=7.5']=np.loadtxt("tmdplots/f_E288_400_x=0.1_Q0=7.5.dat",skiprows=0)
fu['E288 400 x=0.1 Q0=8.5']=np.loadtxt("tmdplots/f_E288_400_x=0.1_Q0=8.5.dat",skiprows=0)
fu['E288 400 x=0.1 Q0=11.5']=np.loadtxt("tmdplots/f_E288_400_x=0.1_Q0=11.5.dat",skiprows=0)
fu['E288 400 x=0.1 Q0=12.5']=np.loadtxt("tmdplots/f_E288_400_x=0.1_Q0=12.5.dat",skiprows=0)
fu['E288 400 x=0.1 Q0=13.5']=np.loadtxt("tmdplots/f_E288_400_x=0.1_Q0=13.5.dat",skiprows=0)

# %%
nrows,ncols=2,2
py.figure(figsize=(ncols*7,nrows*8))

ax=py.subplot(nrows,ncols,1)
#Q=5.5
ncut=2400
ax.plot(fu['E288 400 x=0.2 Q0=5.5'][:ncut,0].T, fu['E288 400 x=0.2 Q0=5.5'][:ncut,1].T,color='red',ls='-')
ax.fill_between(fu['E288 400 x=0.2 Q0=5.5'][:ncut,0].T,\
                (fu['E288 400 x=0.2 Q0=5.5'][:ncut,1]-fu['E288 400 x=0.2 Q0=5.5'][:ncut,2]).T,\
                (fu['E288 400 x=0.2 Q0=5.5'][:ncut,1]+fu['E288 400 x=0.2 Q0=5.5'][:ncut,2]).T,\
                linewidth=0, color="red", alpha=0.5)
#Q=6.5
ncut=2400
ax.plot(fu['E288 400 x=0.2 Q0=6.5'][:ncut,0].T, fu['E288 400 x=0.2 Q0=6.5'][:ncut,1].T,color='green',ls='-')
ax.fill_between(fu['E288 400 x=0.2 Q0=6.5'][:ncut,0].T,\
                (fu['E288 400 x=0.2 Q0=6.5'][:ncut,1]-fu['E288 400 x=0.2 Q0=6.5'][:ncut,2]).T,\
                (fu['E288 400 x=0.2 Q0=6.5'][:ncut,1]+fu['E288 400 x=0.2 Q0=6.5'][:ncut,2]).T,\
                linewidth=0, color="green", alpha=0.5)
#Q=7.5
ncut=2400
ax.plot(fu['E288 400 x=0.2 Q0=7.5'][:ncut,0].T, fu['E288 400 x=0.2 Q0=7.5'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(fu['E288 400 x=0.2 Q0=7.5'][:ncut,0].T,\
                (fu['E288 400 x=0.2 Q0=7.5'][:ncut,1]-fu['E288 400 x=0.2 Q0=7.5'][:ncut,2]).T,\
                (fu['E288 400 x=0.2 Q0=7.5'][:ncut,1]+fu['E288 400 x=0.2 Q0=7.5'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)
#Q=8.5
ncut=2400
ax.plot(fu['E288 400 x=0.2 Q0=8.5'][:ncut,0].T, fu['E288 400 x=0.2 Q0=8.5'][:ncut,1].T,color='orange',ls='-')
ax.fill_between(fu['E288 400 x=0.2 Q0=8.5'][:ncut,0].T,\
                (fu['E288 400 x=0.2 Q0=8.5'][:ncut,1]-fu['E288 400 x=0.2 Q0=8.5'][:ncut,2]).T,\
                (fu['E288 400 x=0.2 Q0=8.5'][:ncut,1]+fu['E288 400 x=0.2 Q0=8.5'][:ncut,2]).T,\
                linewidth=0, color="orange", alpha=0.5)
#Q=11.5
ncut=2400
ax.plot(fu['E288 400 x=0.2 Q0=11.5'][:ncut,0].T, fu['E288 400 x=0.2 Q0=11.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(fu['E288 400 x=0.2 Q0=11.5'][:ncut,0].T,\
                (fu['E288 400 x=0.2 Q0=11.5'][:ncut,1]-fu['E288 400 x=0.2 Q0=11.5'][:ncut,2]).T,\
                (fu['E288 400 x=0.2 Q0=11.5'][:ncut,1]+fu['E288 400 x=0.2 Q0=11.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
#Q=12.5
ncut=2400
ax.plot(fu['E288 400 x=0.2 Q0=12.5'][:ncut,0].T, fu['E288 400 x=0.2 Q0=12.5'][:ncut,1].T,color='forestgreen',ls='-')
ax.fill_between(fu['E288 400 x=0.2 Q0=12.5'][:ncut,0].T,\
                (fu['E288 400 x=0.2 Q0=12.5'][:ncut,1]-fu['E288 400 x=0.2 Q0=12.5'][:ncut,2]).T,\
                (fu['E288 400 x=0.2 Q0=12.5'][:ncut,1]+fu['E288 400 x=0.2 Q0=12.5'][:ncut,2]).T,\
                linewidth=0, color="forestgreen", alpha=0.5)
#Q=13.5
ncut=2400
ax.plot(fu['E288 400 x=0.2 Q0=13.5'][:ncut,0].T, fu['E288 400 x=0.2 Q0=13.5'][:ncut,1].T,color='black',ls='-')
ax.fill_between(fu['E288 400 x=0.2 Q0=13.5'][:ncut,0].T,\
                (fu['E288 400 x=0.2 Q0=13.5'][:ncut,1]-fu['E288 400 x=0.2 Q0=13.5'][:ncut,2]).T,\
                (fu['E288 400 x=0.2 Q0=13.5'][:ncut,1]+fu['E288 400 x=0.2 Q0=13.5'][:ncut,2]).T,\
                linewidth=0, color="black", alpha=0.5)
#setting
ax.set_xlabel(r'$b_T~\rm(GeV^{-1})$',size=30)
ax.set_ylabel(r'$f(x,b)$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(0,5)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E288~400\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.85,r'x=0.2',horizontalalignment='center',transform=ax.transAxes,size=20)

ax=py.subplot(nrows,ncols,2)
#Q=5.5
ncut=2400
ax.plot(fu['E288 400 x=0.2 Q0=5.5'][:ncut,0].T, fu['E288 400 x=0.2 Q0=5.5'][:ncut,0].T*fu['E288 400 x=0.2 Q0=5.5'][:ncut,1].T,color='red',ls='-')
ax.fill_between(fu['E288 400 x=0.2 Q0=5.5'][:ncut,0].T,\
                fu['E288 400 x=0.2 Q0=5.5'][:ncut,0].T*(fu['E288 400 x=0.2 Q0=5.5'][:ncut,1]-fu['E288 400 x=0.2 Q0=5.5'][:ncut,2]).T,\
                fu['E288 400 x=0.2 Q0=5.5'][:ncut,0].T*(fu['E288 400 x=0.2 Q0=5.5'][:ncut,1]+fu['E288 400 x=0.2 Q0=5.5'][:ncut,2]).T,\
                linewidth=0, color="red", alpha=0.5)
#Q=6.5
ncut=2400
ax.plot(fu['E288 400 x=0.2 Q0=6.5'][:ncut,0].T, fu['E288 400 x=0.2 Q0=6.5'][:ncut,0].T*fu['E288 400 x=0.2 Q0=6.5'][:ncut,1].T,color='green',ls='-')
ax.fill_between(fu['E288 400 x=0.2 Q0=6.5'][:ncut,0].T,\
                fu['E288 400 x=0.2 Q0=6.5'][:ncut,0].T*(fu['E288 400 x=0.2 Q0=6.5'][:ncut,1]-fu['E288 400 x=0.2 Q0=6.5'][:ncut,2]).T,\
                fu['E288 400 x=0.2 Q0=6.5'][:ncut,0].T*(fu['E288 400 x=0.2 Q0=6.5'][:ncut,1]+fu['E288 400 x=0.2 Q0=6.5'][:ncut,2]).T,\
                linewidth=0, color="green", alpha=0.5)
#Q=7.5
ncut=2400
ax.plot(fu['E288 400 x=0.2 Q0=7.5'][:ncut,0].T, fu['E288 400 x=0.2 Q0=7.5'][:ncut,0].T*fu['E288 400 x=0.2 Q0=7.5'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(fu['E288 400 x=0.2 Q0=7.5'][:ncut,0].T,\
                fu['E288 400 x=0.2 Q0=7.5'][:ncut,0].T*(fu['E288 400 x=0.2 Q0=7.5'][:ncut,1]-fu['E288 400 x=0.2 Q0=7.5'][:ncut,2]).T,\
                fu['E288 400 x=0.2 Q0=7.5'][:ncut,0].T*(fu['E288 400 x=0.2 Q0=7.5'][:ncut,1]+fu['E288 400 x=0.2 Q0=7.5'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)
#Q=8.5
ncut=2400
ax.plot(fu['E288 400 x=0.2 Q0=8.5'][:ncut,0].T, fu['E288 400 x=0.2 Q0=8.5'][:ncut,0].T*fu['E288 400 x=0.2 Q0=8.5'][:ncut,1].T,color='orange',ls='-')
ax.fill_between(fu['E288 400 x=0.2 Q0=8.5'][:ncut,0].T,\
                fu['E288 400 x=0.2 Q0=8.5'][:ncut,0].T*(fu['E288 400 x=0.2 Q0=8.5'][:ncut,1]-fu['E288 400 x=0.2 Q0=8.5'][:ncut,2]).T,\
                fu['E288 400 x=0.2 Q0=8.5'][:ncut,0].T*(fu['E288 400 x=0.2 Q0=8.5'][:ncut,1]+fu['E288 400 x=0.2 Q0=8.5'][:ncut,2]).T,\
                linewidth=0, color="orange", alpha=0.5)
#Q=11.5
ncut=2400
ax.plot(fu['E288 400 x=0.2 Q0=11.5'][:ncut,0].T, fu['E288 400 x=0.2 Q0=11.5'][:ncut,0].T*fu['E288 400 x=0.2 Q0=11.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(fu['E288 400 x=0.2 Q0=11.5'][:ncut,0].T,\
                fu['E288 400 x=0.2 Q0=11.5'][:ncut,0].T*(fu['E288 400 x=0.2 Q0=11.5'][:ncut,1]-fu['E288 400 x=0.2 Q0=11.5'][:ncut,2]).T,\
                fu['E288 400 x=0.2 Q0=11.5'][:ncut,0].T*(fu['E288 400 x=0.2 Q0=11.5'][:ncut,1]+fu['E288 400 x=0.2 Q0=11.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
#Q=12.5
ncut=2400
ax.plot(fu['E288 400 x=0.2 Q0=12.5'][:ncut,0].T, fu['E288 400 x=0.2 Q0=12.5'][:ncut,0].T*fu['E288 400 x=0.2 Q0=12.5'][:ncut,1].T,color='forestgreen',ls='-')
ax.fill_between(fu['E288 400 x=0.2 Q0=12.5'][:ncut,0].T,\
                fu['E288 400 x=0.2 Q0=12.5'][:ncut,0].T*(fu['E288 400 x=0.2 Q0=12.5'][:ncut,1]-fu['E288 400 x=0.2 Q0=12.5'][:ncut,2]).T,\
                fu['E288 400 x=0.2 Q0=12.5'][:ncut,0].T*(fu['E288 400 x=0.2 Q0=12.5'][:ncut,1]+fu['E288 400 x=0.2 Q0=12.5'][:ncut,2]).T,\
                linewidth=0, color="forestgreen", alpha=0.5)
#Q=13.5
ncut=2400
ax.plot(fu['E288 400 x=0.2 Q0=13.5'][:ncut,0].T, fu['E288 400 x=0.2 Q0=13.5'][:ncut,0].T*fu['E288 400 x=0.2 Q0=13.5'][:ncut,1].T,color='black',ls='-')
ax.fill_between(fu['E288 400 x=0.2 Q0=13.5'][:ncut,0].T,\
                fu['E288 400 x=0.2 Q0=13.5'][:ncut,0].T*(fu['E288 400 x=0.2 Q0=13.5'][:ncut,1]-fu['E288 400 x=0.2 Q0=13.5'][:ncut,2]).T,\
                fu['E288 400 x=0.2 Q0=13.5'][:ncut,0].T*(fu['E288 400 x=0.2 Q0=13.5'][:ncut,1]+fu['E288 400 x=0.2 Q0=13.5'][:ncut,2]).T,\
                linewidth=0, color="black", alpha=0.5)
#setting
ax.set_xlabel(r'$b_T~\rm(GeV^{-1})$',size=30)
ax.set_ylabel(r'$bf(x,b)~\rm(GeV^{-1})$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(0,7)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E288~400\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.85,r'x=0.2',horizontalalignment='center',transform=ax.transAxes,size=20)

ax=py.subplot(nrows,ncols,3)
#Q=5.5
ncut=2400
ax.plot(fu['E288 400 x=0.1 Q0=5.5'][:ncut,0].T, fu['E288 400 x=0.1 Q0=5.5'][:ncut,1].T,color='red',ls='-')
ax.fill_between(fu['E288 400 x=0.1 Q0=5.5'][:ncut,0].T,\
                (fu['E288 400 x=0.1 Q0=5.5'][:ncut,1]-fu['E288 400 x=0.1 Q0=5.5'][:ncut,2]).T,\
                (fu['E288 400 x=0.1 Q0=5.5'][:ncut,1]+fu['E288 400 x=0.1 Q0=5.5'][:ncut,2]).T,\
                linewidth=0, color="red", alpha=0.5)
#Q=6.5
ncut=2400
ax.plot(fu['E288 400 x=0.1 Q0=6.5'][:ncut,0].T, fu['E288 400 x=0.1 Q0=6.5'][:ncut,1].T,color='green',ls='-')
ax.fill_between(fu['E288 400 x=0.1 Q0=6.5'][:ncut,0].T,\
                (fu['E288 400 x=0.1 Q0=6.5'][:ncut,1]-fu['E288 400 x=0.1 Q0=6.5'][:ncut,2]).T,\
                (fu['E288 400 x=0.1 Q0=6.5'][:ncut,1]+fu['E288 400 x=0.1 Q0=6.5'][:ncut,2]).T,\
                linewidth=0, color="green", alpha=0.5)
#Q=7.5
ncut=2400
ax.plot(fu['E288 400 x=0.1 Q0=7.5'][:ncut,0].T, fu['E288 400 x=0.1 Q0=7.5'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(fu['E288 400 x=0.1 Q0=7.5'][:ncut,0].T,\
                (fu['E288 400 x=0.1 Q0=7.5'][:ncut,1]-fu['E288 400 x=0.1 Q0=7.5'][:ncut,2]).T,\
                (fu['E288 400 x=0.1 Q0=7.5'][:ncut,1]+fu['E288 400 x=0.1 Q0=7.5'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)
#Q=8.5
ncut=2400
ax.plot(fu['E288 400 x=0.1 Q0=8.5'][:ncut,0].T, fu['E288 400 x=0.1 Q0=8.5'][:ncut,1].T,color='orange',ls='-')
ax.fill_between(fu['E288 400 x=0.1 Q0=8.5'][:ncut,0].T,\
                (fu['E288 400 x=0.1 Q0=8.5'][:ncut,1]-fu['E288 400 x=0.1 Q0=8.5'][:ncut,2]).T,\
                (fu['E288 400 x=0.1 Q0=8.5'][:ncut,1]+fu['E288 400 x=0.1 Q0=8.5'][:ncut,2]).T,\
                linewidth=0, color="orange", alpha=0.5)
#Q=11.5
ncut=2400
ax.plot(fu['E288 400 x=0.1 Q0=11.5'][:ncut,0].T, fu['E288 400 x=0.1 Q0=11.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(fu['E288 400 x=0.1 Q0=11.5'][:ncut,0].T,\
                (fu['E288 400 x=0.1 Q0=11.5'][:ncut,1]-fu['E288 400 x=0.1 Q0=11.5'][:ncut,2]).T,\
                (fu['E288 400 x=0.1 Q0=11.5'][:ncut,1]+fu['E288 400 x=0.1 Q0=11.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
#Q=12.5
ncut=2400
ax.plot(fu['E288 400 x=0.1 Q0=12.5'][:ncut,0].T, fu['E288 400 x=0.1 Q0=12.5'][:ncut,1].T,color='forestgreen',ls='-')
ax.fill_between(fu['E288 400 x=0.1 Q0=12.5'][:ncut,0].T,\
                (fu['E288 400 x=0.1 Q0=12.5'][:ncut,1]-fu['E288 400 x=0.1 Q0=12.5'][:ncut,2]).T,\
                (fu['E288 400 x=0.1 Q0=12.5'][:ncut,1]+fu['E288 400 x=0.1 Q0=12.5'][:ncut,2]).T,\
                linewidth=0, color="forestgreen", alpha=0.5)
#Q=13.5
ncut=2400
ax.plot(fu['E288 400 x=0.1 Q0=13.5'][:ncut,0].T, fu['E288 400 x=0.1 Q0=13.5'][:ncut,1].T,color='black',ls='-')
ax.fill_between(fu['E288 400 x=0.1 Q0=13.5'][:ncut,0].T,\
                (fu['E288 400 x=0.1 Q0=13.5'][:ncut,1]-fu['E288 400 x=0.1 Q0=13.5'][:ncut,2]).T,\
                (fu['E288 400 x=0.1 Q0=13.5'][:ncut,1]+fu['E288 400 x=0.1 Q0=13.5'][:ncut,2]).T,\
                linewidth=0, color="black", alpha=0.5)
#setting
ax.set_xlabel(r'$b_T~\rm(GeV^{-1})$',size=30)
ax.set_ylabel(r'$f(x,b)$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(0,10)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E288~400\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.85,r'x=0.1',horizontalalignment='center',transform=ax.transAxes,size=20)

ax=py.subplot(nrows,ncols,4)
#Q=5.5
ncut=2400
ax.plot(fu['E288 400 x=0.1 Q0=5.5'][:ncut,0].T, fu['E288 400 x=0.1 Q0=5.5'][:ncut,0].T*fu['E288 400 x=0.1 Q0=5.5'][:ncut,1].T,color='red',ls='-')
ax.fill_between(fu['E288 400 x=0.1 Q0=5.5'][:ncut,0].T,\
                fu['E288 400 x=0.1 Q0=5.5'][:ncut,0].T*(fu['E288 400 x=0.1 Q0=5.5'][:ncut,1]-fu['E288 400 x=0.1 Q0=5.5'][:ncut,2]).T,\
                fu['E288 400 x=0.1 Q0=5.5'][:ncut,0].T*(fu['E288 400 x=0.1 Q0=5.5'][:ncut,1]+fu['E288 400 x=0.1 Q0=5.5'][:ncut,2]).T,\
                linewidth=0, color="red", alpha=0.5)
#Q=6.5
ncut=2400
ax.plot(fu['E288 400 x=0.1 Q0=6.5'][:ncut,0].T, fu['E288 400 x=0.1 Q0=6.5'][:ncut,0].T*fu['E288 400 x=0.1 Q0=6.5'][:ncut,1].T,color='green',ls='-')
ax.fill_between(fu['E288 400 x=0.1 Q0=6.5'][:ncut,0].T,\
                fu['E288 400 x=0.1 Q0=6.5'][:ncut,0].T*(fu['E288 400 x=0.1 Q0=6.5'][:ncut,1]-fu['E288 400 x=0.1 Q0=6.5'][:ncut,2]).T,\
                fu['E288 400 x=0.1 Q0=6.5'][:ncut,0].T*(fu['E288 400 x=0.1 Q0=6.5'][:ncut,1]+fu['E288 400 x=0.1 Q0=6.5'][:ncut,2]).T,\
                linewidth=0, color="green", alpha=0.5)
#Q=7.5
ncut=2400
ax.plot(fu['E288 400 x=0.1 Q0=7.5'][:ncut,0].T, fu['E288 400 x=0.1 Q0=7.5'][:ncut,0].T*fu['E288 400 x=0.1 Q0=7.5'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(fu['E288 400 x=0.1 Q0=7.5'][:ncut,0].T,\
                fu['E288 400 x=0.1 Q0=7.5'][:ncut,0].T*(fu['E288 400 x=0.1 Q0=7.5'][:ncut,1]-fu['E288 400 x=0.1 Q0=7.5'][:ncut,2]).T,\
                fu['E288 400 x=0.1 Q0=7.5'][:ncut,0].T*(fu['E288 400 x=0.1 Q0=7.5'][:ncut,1]+fu['E288 400 x=0.1 Q0=7.5'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)
#Q=8.5
ncut=2400
ax.plot(fu['E288 400 x=0.1 Q0=8.5'][:ncut,0].T, fu['E288 400 x=0.1 Q0=8.5'][:ncut,0].T*fu['E288 400 x=0.1 Q0=8.5'][:ncut,1].T,color='orange',ls='-')
ax.fill_between(fu['E288 400 x=0.1 Q0=8.5'][:ncut,0].T,\
                fu['E288 400 x=0.1 Q0=8.5'][:ncut,0].T*(fu['E288 400 x=0.1 Q0=8.5'][:ncut,1]-fu['E288 400 x=0.1 Q0=8.5'][:ncut,2]).T,\
                fu['E288 400 x=0.1 Q0=8.5'][:ncut,0].T*(fu['E288 400 x=0.1 Q0=8.5'][:ncut,1]+fu['E288 400 x=0.1 Q0=8.5'][:ncut,2]).T,\
                linewidth=0, color="orange", alpha=0.5)
#Q=11.5
ncut=2400
ax.plot(fu['E288 400 x=0.1 Q0=11.5'][:ncut,0].T, fu['E288 400 x=0.1 Q0=11.5'][:ncut,0].T*fu['E288 400 x=0.1 Q0=11.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(fu['E288 400 x=0.1 Q0=11.5'][:ncut,0].T,\
                fu['E288 400 x=0.1 Q0=11.5'][:ncut,0].T*(fu['E288 400 x=0.1 Q0=11.5'][:ncut,1]-fu['E288 400 x=0.1 Q0=11.5'][:ncut,2]).T,\
                fu['E288 400 x=0.1 Q0=11.5'][:ncut,0].T*(fu['E288 400 x=0.1 Q0=11.5'][:ncut,1]+fu['E288 400 x=0.1 Q0=11.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
#Q=12.5
ncut=2400
ax.plot(fu['E288 400 x=0.1 Q0=12.5'][:ncut,0].T, fu['E288 400 x=0.1 Q0=12.5'][:ncut,0].T*fu['E288 400 x=0.1 Q0=12.5'][:ncut,1].T,color='forestgreen',ls='-')
ax.fill_between(fu['E288 400 x=0.1 Q0=12.5'][:ncut,0].T,\
                fu['E288 400 x=0.1 Q0=12.5'][:ncut,0].T*(fu['E288 400 x=0.1 Q0=12.5'][:ncut,1]-fu['E288 400 x=0.1 Q0=12.5'][:ncut,2]).T,\
                fu['E288 400 x=0.1 Q0=12.5'][:ncut,0].T*(fu['E288 400 x=0.1 Q0=12.5'][:ncut,1]+fu['E288 400 x=0.1 Q0=12.5'][:ncut,2]).T,\
                linewidth=0, color="forestgreen", alpha=0.5)
#Q=13.5
ncut=2400
ax.plot(fu['E288 400 x=0.1 Q0=13.5'][:ncut,0].T, fu['E288 400 x=0.1 Q0=13.5'][:ncut,0].T*fu['E288 400 x=0.1 Q0=13.5'][:ncut,1].T,color='black',ls='-')
ax.fill_between(fu['E288 400 x=0.1 Q0=13.5'][:ncut,0].T,\
                fu['E288 400 x=0.1 Q0=13.5'][:ncut,0].T*(fu['E288 400 x=0.1 Q0=13.5'][:ncut,1]-fu['E288 400 x=0.1 Q0=13.5'][:ncut,2]).T,\
                fu['E288 400 x=0.1 Q0=13.5'][:ncut,0].T*(fu['E288 400 x=0.1 Q0=13.5'][:ncut,1]+fu['E288 400 x=0.1 Q0=13.5'][:ncut,2]).T,\
                linewidth=0, color="black", alpha=0.5)
#setting
ax.set_xlabel(r'$b_T~\rm(GeV^{-1})$',size=30)
ax.set_ylabel(r'$bf(x,b)~\rm(GeV^{-1})$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(0,14)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E288~400\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.85,r'x=0.1',horizontalalignment='center',transform=ax.transAxes,size=20)
py.tight_layout()

#py.savefig('results/tmp.png')

# %% [markdown]
# ### E605 800 GeV

# %%
# E605

fu['E605 x=0.2 Q0=7.5']=np.loadtxt("tmdplots/f_E605_x=0.2_Q0=7.5.dat",skiprows=0)
fu['E605 x=0.2 Q0=8.5']=np.loadtxt("tmdplots/f_E605_x=0.2_Q0=8.5.dat",skiprows=0)
fu['E605 x=0.2 Q0=11.0']=np.loadtxt("tmdplots/f_E605_x=0.2_Q0=11.0.dat",skiprows=0)
fu['E605 x=0.2 Q0=12.5']=np.loadtxt("tmdplots/f_E605_x=0.2_Q0=12.5.dat",skiprows=0)
fu['E605 x=0.2 Q0=15.8']=np.loadtxt("tmdplots/f_E605_x=0.2_Q0=15.8.dat",skiprows=0)

fu['E605 x=0.1 Q0=7.5']=np.loadtxt("tmdplots/f_E605_x=0.1_Q0=7.5.dat",skiprows=0)
fu['E605 x=0.1 Q0=8.5']=np.loadtxt("tmdplots/f_E605_x=0.1_Q0=8.5.dat",skiprows=0)
fu['E605 x=0.1 Q0=11.0']=np.loadtxt("tmdplots/f_E605_x=0.1_Q0=11.0.dat",skiprows=0)
fu['E605 x=0.1 Q0=12.5']=np.loadtxt("tmdplots/f_E605_x=0.1_Q0=12.5.dat",skiprows=0)
fu['E605 x=0.1 Q0=15.8']=np.loadtxt("tmdplots/f_E605_x=0.1_Q0=15.8.dat",skiprows=0)

# %%
nrows,ncols=2,2
py.figure(figsize=(ncols*7,nrows*8))

ax=py.subplot(nrows,ncols,1)
#Q=7.5
ncut=2300
ax.plot(fu['E605 x=0.2 Q0=7.5'][:ncut,0].T, fu['E605 x=0.2 Q0=7.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(fu['E605 x=0.2 Q0=7.5'][:ncut,0].T,\
                (fu['E605 x=0.2 Q0=7.5'][:ncut,1]-fu['E605 x=0.2 Q0=7.5'][:ncut,2]).T,\
                (fu['E605 x=0.2 Q0=7.5'][:ncut,1]+fu['E605 x=0.2 Q0=7.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
#Q=8.5
ncut=2300
ax.plot(fu['E605 x=0.2 Q0=8.5'][:ncut,0].T, fu['E605 x=0.2 Q0=8.5'][:ncut,1].T,color='red',ls='-')
ax.fill_between(fu['E605 x=0.2 Q0=8.5'][:ncut,0].T,\
                (fu['E605 x=0.2 Q0=8.5'][:ncut,1]-fu['E605 x=0.2 Q0=8.5'][:ncut,2]).T,\
                (fu['E605 x=0.2 Q0=8.5'][:ncut,1]+fu['E605 x=0.2 Q0=8.5'][:ncut,2]).T,\
                linewidth=0, color="red", alpha=0.5)
#Q=11.0
ncut=2300
ax.plot(fu['E605 x=0.2 Q0=11.0'][:ncut,0].T, fu['E605 x=0.2 Q0=11.0'][:ncut,1].T,color='green',ls='-')
ax.fill_between(fu['E605 x=0.2 Q0=11.0'][:ncut,0].T,\
                (fu['E605 x=0.2 Q0=11.0'][:ncut,1]-fu['E605 x=0.2 Q0=11.0'][:ncut,2]).T,\
                (fu['E605 x=0.2 Q0=11.0'][:ncut,1]+fu['E605 x=0.2 Q0=11.0'][:ncut,2]).T,\
                linewidth=0, color="green", alpha=0.5)
#Q=12.5
ncut=2300
ax.plot(fu['E605 x=0.2 Q0=12.5'][:ncut,0].T, fu['E605 x=0.2 Q0=12.5'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(fu['E605 x=0.2 Q0=12.5'][:ncut,0].T,\
                (fu['E605 x=0.2 Q0=12.5'][:ncut,1]-fu['E605 x=0.2 Q0=12.5'][:ncut,2]).T,\
                (fu['E605 x=0.2 Q0=12.5'][:ncut,1]+fu['E605 x=0.2 Q0=12.5'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)
#Q=15.8
ncut=2300
ax.plot(fu['E605 x=0.2 Q0=15.8'][:ncut,0].T, fu['E605 x=0.2 Q0=15.8'][:ncut,1].T,color='orange',ls='-')
ax.fill_between(fu['E605 x=0.2 Q0=15.8'][:ncut,0].T,\
                (fu['E605 x=0.2 Q0=15.8'][:ncut,1]-fu['E605 x=0.2 Q0=15.8'][:ncut,2]).T,\
                (fu['E605 x=0.2 Q0=15.8'][:ncut,1]+fu['E605 x=0.2 Q0=15.8'][:ncut,2]).T,\
                linewidth=0, color="orange", alpha=0.5)
#setting
ax.set_xlabel(r'$b_T~\rm(GeV^{-1})$',size=30)
ax.set_ylabel(r'$f(x,b)$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(0,5)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E605~800\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.85,r'x=0.2',horizontalalignment='center',transform=ax.transAxes,size=20)

ax=py.subplot(nrows,ncols,2)
#Q=7.5
ncut=2300
ax.plot(fu['E605 x=0.2 Q0=7.5'][:ncut,0].T, fu['E605 x=0.2 Q0=7.5'][:ncut,0].T*fu['E605 x=0.2 Q0=7.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(fu['E605 x=0.2 Q0=7.5'][:ncut,0].T,\
                fu['E605 x=0.2 Q0=7.5'][:ncut,0].T*(fu['E605 x=0.2 Q0=7.5'][:ncut,1]-fu['E605 x=0.2 Q0=7.5'][:ncut,2]).T,\
                fu['E605 x=0.2 Q0=7.5'][:ncut,0].T*(fu['E605 x=0.2 Q0=7.5'][:ncut,1]+fu['E605 x=0.2 Q0=7.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
#Q=8.5
ncut=2300
ax.plot(fu['E605 x=0.2 Q0=8.5'][:ncut,0].T, fu['E605 x=0.2 Q0=8.5'][:ncut,0].T*fu['E605 x=0.2 Q0=8.5'][:ncut,1].T,color='red',ls='-')
ax.fill_between(fu['E605 x=0.2 Q0=8.5'][:ncut,0].T,\
                fu['E605 x=0.2 Q0=8.5'][:ncut,0].T*(fu['E605 x=0.2 Q0=8.5'][:ncut,1]-fu['E605 x=0.2 Q0=8.5'][:ncut,2]).T,\
                fu['E605 x=0.2 Q0=8.5'][:ncut,0].T*(fu['E605 x=0.2 Q0=8.5'][:ncut,1]+fu['E605 x=0.2 Q0=8.5'][:ncut,2]).T,\
                linewidth=0, color="red", alpha=0.5)
#Q=11.0
ncut=2300
ax.plot(fu['E605 x=0.2 Q0=11.0'][:ncut,0].T, fu['E605 x=0.2 Q0=11.0'][:ncut,0].T*fu['E605 x=0.2 Q0=11.0'][:ncut,1].T,color='green',ls='-')
ax.fill_between(fu['E605 x=0.2 Q0=11.0'][:ncut,0].T,\
                fu['E605 x=0.2 Q0=11.0'][:ncut,0].T*(fu['E605 x=0.2 Q0=11.0'][:ncut,1]-fu['E605 x=0.2 Q0=11.0'][:ncut,2]).T,\
                fu['E605 x=0.2 Q0=11.0'][:ncut,0].T*(fu['E605 x=0.2 Q0=11.0'][:ncut,1]+fu['E605 x=0.2 Q0=11.0'][:ncut,2]).T,\
                linewidth=0, color="green", alpha=0.5)
#Q=12.5
ncut=2300
ax.plot(fu['E605 x=0.2 Q0=12.5'][:ncut,0].T, fu['E605 x=0.2 Q0=12.5'][:ncut,0].T*fu['E605 x=0.2 Q0=12.5'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(fu['E605 x=0.2 Q0=12.5'][:ncut,0].T,\
                fu['E605 x=0.2 Q0=12.5'][:ncut,0].T*(fu['E605 x=0.2 Q0=12.5'][:ncut,1]-fu['E605 x=0.2 Q0=12.5'][:ncut,2]).T,\
                fu['E605 x=0.2 Q0=12.5'][:ncut,0].T*(fu['E605 x=0.2 Q0=12.5'][:ncut,1]+fu['E605 x=0.2 Q0=12.5'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)
#Q=15.8
ncut=2300
ax.plot(fu['E605 x=0.2 Q0=15.8'][:ncut,0].T, fu['E605 x=0.2 Q0=15.8'][:ncut,0].T*fu['E605 x=0.2 Q0=15.8'][:ncut,1].T,color='orange',ls='-')
ax.fill_between(fu['E605 x=0.2 Q0=15.8'][:ncut,0].T,\
                fu['E605 x=0.2 Q0=15.8'][:ncut,0].T*(fu['E605 x=0.2 Q0=15.8'][:ncut,1]-fu['E605 x=0.2 Q0=15.8'][:ncut,2]).T,\
                fu['E605 x=0.2 Q0=15.8'][:ncut,0].T*(fu['E605 x=0.2 Q0=15.8'][:ncut,1]+fu['E605 x=0.2 Q0=15.8'][:ncut,2]).T,\
                linewidth=0, color="orange", alpha=0.5)
#setting
ax.set_xlabel(r'$b_T~\rm(GeV^{-1})$',size=30)
ax.set_ylabel(r'$bf(x,b)~\rm(GeV^{-1})$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(0,7)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E605~800\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.85,r'x=0.2',horizontalalignment='center',transform=ax.transAxes,size=20)

ax=py.subplot(nrows,ncols,3)
#Q=7.5
ncut=2300
ax.plot(fu['E605 x=0.1 Q0=7.5'][:ncut,0].T, fu['E605 x=0.1 Q0=7.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(fu['E605 x=0.1 Q0=7.5'][:ncut,0].T,\
                (fu['E605 x=0.1 Q0=7.5'][:ncut,1]-fu['E605 x=0.1 Q0=7.5'][:ncut,2]).T,\
                (fu['E605 x=0.1 Q0=7.5'][:ncut,1]+fu['E605 x=0.1 Q0=7.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
#Q=8.5
ncut=2300
ax.plot(fu['E605 x=0.1 Q0=8.5'][:ncut,0].T, fu['E605 x=0.1 Q0=8.5'][:ncut,1].T,color='red',ls='-')
ax.fill_between(fu['E605 x=0.1 Q0=8.5'][:ncut,0].T,\
                (fu['E605 x=0.1 Q0=8.5'][:ncut,1]-fu['E605 x=0.1 Q0=8.5'][:ncut,2]).T,\
                (fu['E605 x=0.1 Q0=8.5'][:ncut,1]+fu['E605 x=0.1 Q0=8.5'][:ncut,2]).T,\
                linewidth=0, color="red", alpha=0.5)
#Q=11.0
ncut=2300
ax.plot(fu['E605 x=0.1 Q0=11.0'][:ncut,0].T, fu['E605 x=0.1 Q0=11.0'][:ncut,1].T,color='green',ls='-')
ax.fill_between(fu['E605 x=0.1 Q0=11.0'][:ncut,0].T,\
                (fu['E605 x=0.1 Q0=11.0'][:ncut,1]-fu['E605 x=0.1 Q0=11.0'][:ncut,2]).T,\
                (fu['E605 x=0.1 Q0=11.0'][:ncut,1]+fu['E605 x=0.1 Q0=11.0'][:ncut,2]).T,\
                linewidth=0, color="green", alpha=0.5)
#Q=12.0
ncut=2300
ax.plot(fu['E605 x=0.1 Q0=12.5'][:ncut,0].T, fu['E605 x=0.1 Q0=12.5'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(fu['E605 x=0.1 Q0=12.5'][:ncut,0].T,\
                (fu['E605 x=0.1 Q0=12.5'][:ncut,1]-fu['E605 x=0.1 Q0=12.5'][:ncut,2]).T,\
                (fu['E605 x=0.1 Q0=12.5'][:ncut,1]+fu['E605 x=0.1 Q0=12.5'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)
#Q=15.8
ncut=2300
ax.plot(fu['E605 x=0.1 Q0=15.8'][:ncut,0].T, fu['E605 x=0.1 Q0=15.8'][:ncut,1].T,color='orange',ls='-')
ax.fill_between(fu['E605 x=0.1 Q0=15.8'][:ncut,0].T,\
                (fu['E605 x=0.1 Q0=15.8'][:ncut,1]-fu['E605 x=0.1 Q0=15.8'][:ncut,2]).T,\
                (fu['E605 x=0.1 Q0=15.8'][:ncut,1]+fu['E605 x=0.1 Q0=15.8'][:ncut,2]).T,\
                linewidth=0, color="orange", alpha=0.5)
#setting
ax.set_xlabel(r'$b_T~\rm(GeV^{-1})$',size=30)
ax.set_ylabel(r'$f(x,b)$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(0,10)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E605~800\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.85,r'x=0.1',horizontalalignment='center',transform=ax.transAxes,size=20)

ax=py.subplot(nrows,ncols,4)
#Q=7.5
ncut=2300
ax.plot(fu['E605 x=0.1 Q0=7.5'][:ncut,0].T, fu['E605 x=0.1 Q0=7.5'][:ncut,0].T*fu['E605 x=0.1 Q0=7.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(fu['E605 x=0.1 Q0=7.5'][:ncut,0].T,\
                fu['E605 x=0.1 Q0=7.5'][:ncut,0].T*(fu['E605 x=0.1 Q0=7.5'][:ncut,1]-fu['E605 x=0.1 Q0=7.5'][:ncut,2]).T,\
                fu['E605 x=0.1 Q0=7.5'][:ncut,0].T*(fu['E605 x=0.1 Q0=7.5'][:ncut,1]+fu['E605 x=0.1 Q0=7.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
#Q=8.5
ncut=2300
ax.plot(fu['E605 x=0.1 Q0=8.5'][:ncut,0].T, fu['E605 x=0.1 Q0=8.5'][:ncut,0].T*fu['E605 x=0.1 Q0=8.5'][:ncut,1].T,color='red',ls='-')
ax.fill_between(fu['E605 x=0.1 Q0=8.5'][:ncut,0].T,\
                fu['E605 x=0.1 Q0=8.5'][:ncut,0].T*(fu['E605 x=0.1 Q0=8.5'][:ncut,1]-fu['E605 x=0.1 Q0=8.5'][:ncut,2]).T,\
                fu['E605 x=0.1 Q0=8.5'][:ncut,0].T*(fu['E605 x=0.1 Q0=8.5'][:ncut,1]+fu['E605 x=0.1 Q0=8.5'][:ncut,2]).T,\
                linewidth=0, color="red", alpha=0.5)
#Q=11.0
ncut=2300
ax.plot(fu['E605 x=0.1 Q0=11.0'][:ncut,0].T, fu['E605 x=0.1 Q0=11.0'][:ncut,0].T*fu['E605 x=0.1 Q0=11.0'][:ncut,1].T,color='green',ls='-')
ax.fill_between(fu['E605 x=0.1 Q0=11.0'][:ncut,0].T,\
                fu['E605 x=0.1 Q0=11.0'][:ncut,0].T*(fu['E605 x=0.1 Q0=11.0'][:ncut,1]-fu['E605 x=0.1 Q0=11.0'][:ncut,2]).T,\
                fu['E605 x=0.1 Q0=11.0'][:ncut,0].T*(fu['E605 x=0.1 Q0=11.0'][:ncut,1]+fu['E605 x=0.1 Q0=11.0'][:ncut,2]).T,\
                linewidth=0, color="green", alpha=0.5)
#Q=12.5
ncut=2300
ax.plot(fu['E605 x=0.1 Q0=12.5'][:ncut,0].T, fu['E605 x=0.1 Q0=12.5'][:ncut,0].T*fu['E605 x=0.1 Q0=12.5'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(fu['E605 x=0.1 Q0=12.5'][:ncut,0].T,\
                fu['E605 x=0.1 Q0=12.5'][:ncut,0].T*(fu['E605 x=0.1 Q0=12.5'][:ncut,1]-fu['E605 x=0.1 Q0=12.5'][:ncut,2]).T,\
                fu['E605 x=0.1 Q0=12.5'][:ncut,0].T*(fu['E605 x=0.1 Q0=12.5'][:ncut,1]+fu['E605 x=0.1 Q0=12.5'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)
#Q=15.8
ncut=2300
ax.plot(fu['E605 x=0.1 Q0=15.8'][:ncut,0].T, fu['E605 x=0.1 Q0=15.8'][:ncut,0].T*fu['E605 x=0.1 Q0=15.8'][:ncut,1].T,color='orange',ls='-')
ax.fill_between(fu['E605 x=0.1 Q0=15.8'][:ncut,0].T,\
                fu['E605 x=0.1 Q0=15.8'][:ncut,0].T*(fu['E605 x=0.1 Q0=15.8'][:ncut,1]-fu['E605 x=0.1 Q0=15.8'][:ncut,2]).T,\
                fu['E605 x=0.1 Q0=15.8'][:ncut,0].T*(fu['E605 x=0.1 Q0=15.8'][:ncut,1]+fu['E605 x=0.1 Q0=15.8'][:ncut,2]).T,\
                linewidth=0, color="orange", alpha=0.5)
#setting
ax.set_xlabel(r'$b_T~\rm(GeV^{-1})$',size=30)
ax.set_ylabel(r'$bf(x,b)~\rm(GeV^{-1})$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(0,14)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E605~800\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.85,r'x=0.1',horizontalalignment='center',transform=ax.transAxes,size=20)
py.tight_layout()

#py.savefig('results/tmp.png')

# %% [markdown]
# ### E772 800 GeV

# %%
# E772 800

fu['E772 x=0.2 Q0=5.5']=np.loadtxt("tmdplots/f_E772_x=0.2_Q0=5.5.dat",skiprows=0)
fu['E772 x=0.2 Q0=6.5']=np.loadtxt("tmdplots/f_E772_x=0.2_Q0=6.5.dat",skiprows=0)
fu['E772 x=0.2 Q0=7.5']=np.loadtxt("tmdplots/f_E772_x=0.2_Q0=7.5.dat",skiprows=0)
fu['E772 x=0.2 Q0=8.5']=np.loadtxt("tmdplots/f_E772_x=0.2_Q0=8.5.dat",skiprows=0)
fu['E772 x=0.2 Q0=11.5']=np.loadtxt("tmdplots/f_E772_x=0.2_Q0=11.5.dat",skiprows=0)
fu['E772 x=0.2 Q0=12.5']=np.loadtxt("tmdplots/f_E772_x=0.2_Q0=12.5.dat",skiprows=0)

fu['E772 x=0.1 Q0=5.5']=np.loadtxt("tmdplots/f_E772_x=0.1_Q0=5.5.dat",skiprows=0)
fu['E772 x=0.1 Q0=6.5']=np.loadtxt("tmdplots/f_E772_x=0.1_Q0=6.5.dat",skiprows=0)
fu['E772 x=0.1 Q0=7.5']=np.loadtxt("tmdplots/f_E772_x=0.1_Q0=7.5.dat",skiprows=0)
fu['E772 x=0.1 Q0=8.5']=np.loadtxt("tmdplots/f_E772_x=0.1_Q0=8.5.dat",skiprows=0)
fu['E772 x=0.1 Q0=11.5']=np.loadtxt("tmdplots/f_E772_x=0.1_Q0=11.5.dat",skiprows=0)
fu['E772 x=0.1 Q0=12.5']=np.loadtxt("tmdplots/f_E772_x=0.1_Q0=12.5.dat",skiprows=0)

# %%
nrows,ncols=2,2
py.figure(figsize=(ncols*7,nrows*8))

ax=py.subplot(nrows,ncols,1)
#Q=5.5
ncut=2400
ax.plot(fu['E772 x=0.2 Q0=5.5'][:ncut,0].T, fu['E772 x=0.2 Q0=5.5'][:ncut,1].T,color='red',ls='-')
ax.fill_between(fu['E772 x=0.2 Q0=5.5'][:ncut,0].T,\
                (fu['E772 x=0.2 Q0=5.5'][:ncut,1]-fu['E772 x=0.2 Q0=5.5'][:ncut,2]).T,\
                (fu['E772 x=0.2 Q0=5.5'][:ncut,1]+fu['E772 x=0.2 Q0=5.5'][:ncut,2]).T,\
                linewidth=0, color="red", alpha=0.5)
#Q=6.5
ncut=2400
ax.plot(fu['E772 x=0.2 Q0=6.5'][:ncut,0].T, fu['E772 x=0.2 Q0=6.5'][:ncut,1].T,color='green',ls='-')
ax.fill_between(fu['E772 x=0.2 Q0=6.5'][:ncut,0].T,\
                (fu['E772 x=0.2 Q0=6.5'][:ncut,1]-fu['E772 x=0.2 Q0=6.5'][:ncut,2]).T,\
                (fu['E772 x=0.2 Q0=6.5'][:ncut,1]+fu['E772 x=0.2 Q0=6.5'][:ncut,2]).T,\
                linewidth=0, color="green", alpha=0.5)
#Q=7.5
ncut=2400
ax.plot(fu['E772 x=0.2 Q0=7.5'][:ncut,0].T, fu['E772 x=0.2 Q0=7.5'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(fu['E772 x=0.2 Q0=7.5'][:ncut,0].T,\
                (fu['E772 x=0.2 Q0=7.5'][:ncut,1]-fu['E772 x=0.2 Q0=7.5'][:ncut,2]).T,\
                (fu['E772 x=0.2 Q0=7.5'][:ncut,1]+fu['E772 x=0.2 Q0=7.5'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)
#Q=8.5
ncut=2400
ax.plot(fu['E772 x=0.2 Q0=8.5'][:ncut,0].T, fu['E772 x=0.2 Q0=8.5'][:ncut,1].T,color='orange',ls='-')
ax.fill_between(fu['E772 x=0.2 Q0=8.5'][:ncut,0].T,\
                (fu['E772 x=0.2 Q0=8.5'][:ncut,1]-fu['E772 x=0.2 Q0=8.5'][:ncut,2]).T,\
                (fu['E772 x=0.2 Q0=8.5'][:ncut,1]+fu['E772 x=0.2 Q0=8.5'][:ncut,2]).T,\
                linewidth=0, color="orange", alpha=0.5)
#Q=11.5
ncut=2400
ax.plot(fu['E772 x=0.2 Q0=11.5'][:ncut,0].T, fu['E772 x=0.2 Q0=11.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(fu['E772 x=0.2 Q0=11.5'][:ncut,0].T,\
                (fu['E772 x=0.2 Q0=11.5'][:ncut,1]-fu['E772 x=0.2 Q0=11.5'][:ncut,2]).T,\
                (fu['E772 x=0.2 Q0=11.5'][:ncut,1]+fu['E772 x=0.2 Q0=11.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
#Q=12.5
ncut=2400
ax.plot(fu['E772 x=0.2 Q0=12.5'][:ncut,0].T, fu['E772 x=0.2 Q0=12.5'][:ncut,1].T,color='forestgreen',ls='-')
ax.fill_between(fu['E772 x=0.2 Q0=12.5'][:ncut,0].T,\
                (fu['E772 x=0.2 Q0=12.5'][:ncut,1]-fu['E772 x=0.2 Q0=12.5'][:ncut,2]).T,\
                (fu['E772 x=0.2 Q0=12.5'][:ncut,1]+fu['E772 x=0.2 Q0=12.5'][:ncut,2]).T,\
                linewidth=0, color="forestgreen", alpha=0.5)
#setting
ax.set_xlabel(r'$b_T~\rm(GeV^{-1})$',size=30)
ax.set_ylabel(r'$f(x,b)$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(0,5)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E772~800\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.85,r'x=0.2',horizontalalignment='center',transform=ax.transAxes,size=20)

ax=py.subplot(nrows,ncols,2)
#Q=5.5
ncut=2400
ax.plot(fu['E772 x=0.2 Q0=5.5'][:ncut,0].T, fu['E772 x=0.2 Q0=5.5'][:ncut,0].T*fu['E772 x=0.2 Q0=5.5'][:ncut,1].T,color='red',ls='-')
ax.fill_between(fu['E772 x=0.2 Q0=5.5'][:ncut,0].T,\
                fu['E772 x=0.2 Q0=5.5'][:ncut,0].T*(fu['E772 x=0.2 Q0=5.5'][:ncut,1]-fu['E772 x=0.2 Q0=5.5'][:ncut,2]).T,\
                fu['E772 x=0.2 Q0=5.5'][:ncut,0].T*(fu['E772 x=0.2 Q0=5.5'][:ncut,1]+fu['E772 x=0.2 Q0=5.5'][:ncut,2]).T,\
                linewidth=0, color="red", alpha=0.5)
#Q=6.5
ncut=2400
ax.plot(fu['E772 x=0.2 Q0=6.5'][:ncut,0].T, fu['E772 x=0.2 Q0=6.5'][:ncut,0].T*fu['E772 x=0.2 Q0=6.5'][:ncut,1].T,color='green',ls='-')
ax.fill_between(fu['E772 x=0.2 Q0=6.5'][:ncut,0].T,\
                fu['E772 x=0.2 Q0=6.5'][:ncut,0].T*(fu['E772 x=0.2 Q0=6.5'][:ncut,1]-fu['E772 x=0.2 Q0=6.5'][:ncut,2]).T,\
                fu['E772 x=0.2 Q0=6.5'][:ncut,0].T*(fu['E772 x=0.2 Q0=6.5'][:ncut,1]+fu['E772 x=0.2 Q0=6.5'][:ncut,2]).T,\
                linewidth=0, color="green", alpha=0.5)
#Q=7.5
ncut=2400
ax.plot(fu['E772 x=0.2 Q0=7.5'][:ncut,0].T, fu['E772 x=0.2 Q0=7.5'][:ncut,0].T*fu['E772 x=0.2 Q0=7.5'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(fu['E772 x=0.2 Q0=7.5'][:ncut,0].T,\
                fu['E772 x=0.2 Q0=7.5'][:ncut,0].T*(fu['E772 x=0.2 Q0=7.5'][:ncut,1]-fu['E772 x=0.2 Q0=7.5'][:ncut,2]).T,\
                fu['E772 x=0.2 Q0=7.5'][:ncut,0].T*(fu['E772 x=0.2 Q0=7.5'][:ncut,1]+fu['E772 x=0.2 Q0=7.5'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)
#Q=8.5
ncut=2400
ax.plot(fu['E772 x=0.2 Q0=8.5'][:ncut,0].T, fu['E772 x=0.2 Q0=8.5'][:ncut,0].T*fu['E772 x=0.2 Q0=8.5'][:ncut,1].T,color='orange',ls='-')
ax.fill_between(fu['E772 x=0.2 Q0=8.5'][:ncut,0].T,\
                fu['E772 x=0.2 Q0=8.5'][:ncut,0].T*(fu['E772 x=0.2 Q0=8.5'][:ncut,1]-fu['E772 x=0.2 Q0=8.5'][:ncut,2]).T,\
                fu['E772 x=0.2 Q0=8.5'][:ncut,0].T*(fu['E772 x=0.2 Q0=8.5'][:ncut,1]+fu['E772 x=0.2 Q0=8.5'][:ncut,2]).T,\
                linewidth=0, color="orange", alpha=0.5)
#Q=11.5
ncut=2400
ax.plot(fu['E772 x=0.2 Q0=11.5'][:ncut,0].T, fu['E772 x=0.2 Q0=11.5'][:ncut,0].T*fu['E772 x=0.2 Q0=11.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(fu['E772 x=0.2 Q0=11.5'][:ncut,0].T,\
                fu['E772 x=0.2 Q0=11.5'][:ncut,0].T*(fu['E772 x=0.2 Q0=11.5'][:ncut,1]-fu['E772 x=0.2 Q0=11.5'][:ncut,2]).T,\
                fu['E772 x=0.2 Q0=11.5'][:ncut,0].T*(fu['E772 x=0.2 Q0=11.5'][:ncut,1]+fu['E772 x=0.2 Q0=11.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
#Q=12.5
ncut=2400
ax.plot(fu['E772 x=0.2 Q0=12.5'][:ncut,0].T, fu['E772 x=0.2 Q0=12.5'][:ncut,0].T*fu['E772 x=0.2 Q0=12.5'][:ncut,1].T,color='forestgreen',ls='-')
ax.fill_between(fu['E772 x=0.2 Q0=12.5'][:ncut,0].T,\
                fu['E772 x=0.2 Q0=12.5'][:ncut,0].T*(fu['E772 x=0.2 Q0=12.5'][:ncut,1]-fu['E772 x=0.2 Q0=12.5'][:ncut,2]).T,\
                fu['E772 x=0.2 Q0=12.5'][:ncut,0].T*(fu['E772 x=0.2 Q0=12.5'][:ncut,1]+fu['E772 x=0.2 Q0=12.5'][:ncut,2]).T,\
                linewidth=0, color="forestgreen", alpha=0.5)
#setting
ax.set_xlabel(r'$b_T~\rm(GeV^{-1})$',size=30)
ax.set_ylabel(r'$bf(x,b)~\rm(GeV^{-1})$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(0,7)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E772~800\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.85,r'x=0.2',horizontalalignment='center',transform=ax.transAxes,size=20)

ax=py.subplot(nrows,ncols,3)
#Q=5.5
ncut=2400
ax.plot(fu['E772 x=0.1 Q0=5.5'][:ncut,0].T, fu['E772 x=0.1 Q0=5.5'][:ncut,1].T,color='red',ls='-')
ax.fill_between(fu['E772 x=0.1 Q0=5.5'][:ncut,0].T,\
                (fu['E772 x=0.1 Q0=5.5'][:ncut,1]-fu['E772 x=0.1 Q0=5.5'][:ncut,2]).T,\
                (fu['E772 x=0.1 Q0=5.5'][:ncut,1]+fu['E772 x=0.1 Q0=5.5'][:ncut,2]).T,\
                linewidth=0, color="red", alpha=0.5)
#Q=6.5
ncut=2400
ax.plot(fu['E772 x=0.1 Q0=6.5'][:ncut,0].T, fu['E772 x=0.1 Q0=6.5'][:ncut,1].T,color='green',ls='-')
ax.fill_between(fu['E772 x=0.1 Q0=6.5'][:ncut,0].T,\
                (fu['E772 x=0.1 Q0=6.5'][:ncut,1]-fu['E772 x=0.1 Q0=6.5'][:ncut,2]).T,\
                (fu['E772 x=0.1 Q0=6.5'][:ncut,1]+fu['E772 x=0.1 Q0=6.5'][:ncut,2]).T,\
                linewidth=0, color="green", alpha=0.5)
#Q=7.5
ncut=2400
ax.plot(fu['E772 x=0.1 Q0=7.5'][:ncut,0].T, fu['E772 x=0.1 Q0=7.5'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(fu['E772 x=0.1 Q0=7.5'][:ncut,0].T,\
                (fu['E772 x=0.1 Q0=7.5'][:ncut,1]-fu['E772 x=0.1 Q0=7.5'][:ncut,2]).T,\
                (fu['E772 x=0.1 Q0=7.5'][:ncut,1]+fu['E772 x=0.1 Q0=7.5'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)
#Q=8.5
ncut=2400
ax.plot(fu['E772 x=0.1 Q0=8.5'][:ncut,0].T, fu['E772 x=0.1 Q0=8.5'][:ncut,1].T,color='orange',ls='-')
ax.fill_between(fu['E772 x=0.1 Q0=8.5'][:ncut,0].T,\
                (fu['E772 x=0.1 Q0=8.5'][:ncut,1]-fu['E772 x=0.1 Q0=8.5'][:ncut,2]).T,\
                (fu['E772 x=0.1 Q0=8.5'][:ncut,1]+fu['E772 x=0.1 Q0=8.5'][:ncut,2]).T,\
                linewidth=0, color="orange", alpha=0.5)
#Q=11.5
ncut=2400
ax.plot(fu['E772 x=0.1 Q0=11.5'][:ncut,0].T, fu['E772 x=0.1 Q0=11.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(fu['E772 x=0.1 Q0=11.5'][:ncut,0].T,\
                (fu['E772 x=0.1 Q0=11.5'][:ncut,1]-fu['E772 x=0.1 Q0=11.5'][:ncut,2]).T,\
                (fu['E772 x=0.1 Q0=11.5'][:ncut,1]+fu['E772 x=0.1 Q0=11.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
#Q=12.5
ncut=2400
ax.plot(fu['E772 x=0.1 Q0=12.5'][:ncut,0].T, fu['E772 x=0.1 Q0=12.5'][:ncut,1].T,color='forestgreen',ls='-')
ax.fill_between(fu['E772 x=0.1 Q0=12.5'][:ncut,0].T,\
                (fu['E772 x=0.1 Q0=12.5'][:ncut,1]-fu['E772 x=0.1 Q0=12.5'][:ncut,2]).T,\
                (fu['E772 x=0.1 Q0=12.5'][:ncut,1]+fu['E772 x=0.1 Q0=12.5'][:ncut,2]).T,\
                linewidth=0, color="forestgreen", alpha=0.5)
#setting
ax.set_xlabel(r'$b_T~\rm(GeV^{-1})$',size=30)
ax.set_ylabel(r'$f(x,b)$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(0,10)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E772~800\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.85,r'x=0.1',horizontalalignment='center',transform=ax.transAxes,size=20)

ax=py.subplot(nrows,ncols,4)
#Q=5.5
ncut=2400
ax.plot(fu['E772 x=0.1 Q0=5.5'][:ncut,0].T, fu['E772 x=0.1 Q0=5.5'][:ncut,0].T*fu['E772 x=0.1 Q0=5.5'][:ncut,1].T,color='red',ls='-')
ax.fill_between(fu['E772 x=0.1 Q0=5.5'][:ncut,0].T,\
                fu['E772 x=0.1 Q0=5.5'][:ncut,0].T*(fu['E772 x=0.1 Q0=5.5'][:ncut,1]-fu['E772 x=0.1 Q0=5.5'][:ncut,2]).T,\
                fu['E772 x=0.1 Q0=5.5'][:ncut,0].T*(fu['E772 x=0.1 Q0=5.5'][:ncut,1]+fu['E772 x=0.1 Q0=5.5'][:ncut,2]).T,\
                linewidth=0, color="red", alpha=0.5)
#Q=6.5
ncut=2400
ax.plot(fu['E772 x=0.1 Q0=6.5'][:ncut,0].T, fu['E772 x=0.1 Q0=6.5'][:ncut,0].T*fu['E772 x=0.1 Q0=6.5'][:ncut,1].T,color='green',ls='-')
ax.fill_between(fu['E772 x=0.1 Q0=6.5'][:ncut,0].T,\
                fu['E772 x=0.1 Q0=6.5'][:ncut,0].T*(fu['E772 x=0.1 Q0=6.5'][:ncut,1]-fu['E772 x=0.1 Q0=6.5'][:ncut,2]).T,\
                fu['E772 x=0.1 Q0=6.5'][:ncut,0].T*(fu['E772 x=0.1 Q0=6.5'][:ncut,1]+fu['E772 x=0.1 Q0=6.5'][:ncut,2]).T,\
                linewidth=0, color="green", alpha=0.5)
#Q=7.5
ncut=2400
ax.plot(fu['E772 x=0.1 Q0=7.5'][:ncut,0].T, fu['E772 x=0.1 Q0=7.5'][:ncut,0].T*fu['E772 x=0.1 Q0=7.5'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(fu['E772 x=0.1 Q0=7.5'][:ncut,0].T,\
                fu['E772 x=0.1 Q0=7.5'][:ncut,0].T*(fu['E772 x=0.1 Q0=7.5'][:ncut,1]-fu['E772 x=0.1 Q0=7.5'][:ncut,2]).T,\
                fu['E772 x=0.1 Q0=7.5'][:ncut,0].T*(fu['E772 x=0.1 Q0=7.5'][:ncut,1]+fu['E772 x=0.1 Q0=7.5'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)
#Q=8.5
ncut=2400
ax.plot(fu['E772 x=0.1 Q0=8.5'][:ncut,0].T, fu['E772 x=0.1 Q0=8.5'][:ncut,0].T*fu['E772 x=0.1 Q0=8.5'][:ncut,1].T,color='orange',ls='-')
ax.fill_between(fu['E772 x=0.1 Q0=8.5'][:ncut,0].T,\
                fu['E772 x=0.1 Q0=8.5'][:ncut,0].T*(fu['E772 x=0.1 Q0=8.5'][:ncut,1]-fu['E772 x=0.1 Q0=8.5'][:ncut,2]).T,\
                fu['E772 x=0.1 Q0=8.5'][:ncut,0].T*(fu['E772 x=0.1 Q0=8.5'][:ncut,1]+fu['E772 x=0.1 Q0=8.5'][:ncut,2]).T,\
                linewidth=0, color="orange", alpha=0.5)
#Q=11.5
ncut=2400
ax.plot(fu['E772 x=0.1 Q0=11.5'][:ncut,0].T, fu['E772 x=0.1 Q0=11.5'][:ncut,0].T*fu['E772 x=0.1 Q0=11.5'][:ncut,1].T,color='blue',ls='-')
ax.fill_between(fu['E772 x=0.1 Q0=11.5'][:ncut,0].T,\
                fu['E772 x=0.1 Q0=11.5'][:ncut,0].T*(fu['E772 x=0.1 Q0=11.5'][:ncut,1]-fu['E772 x=0.1 Q0=11.5'][:ncut,2]).T,\
                fu['E772 x=0.1 Q0=11.5'][:ncut,0].T*(fu['E772 x=0.1 Q0=11.5'][:ncut,1]+fu['E772 x=0.1 Q0=11.5'][:ncut,2]).T,\
                linewidth=0, color="blue", alpha=0.5)
#Q=12.5
ncut=2400
ax.plot(fu['E772 x=0.1 Q0=12.5'][:ncut,0].T, fu['E772 x=0.1 Q0=12.5'][:ncut,0].T*fu['E772 x=0.1 Q0=12.5'][:ncut,1].T,color='forestgreen',ls='-')
ax.fill_between(fu['E772 x=0.1 Q0=12.5'][:ncut,0].T,\
                fu['E772 x=0.1 Q0=12.5'][:ncut,0].T*(fu['E772 x=0.1 Q0=12.5'][:ncut,1]-fu['E772 x=0.1 Q0=12.5'][:ncut,2]).T,\
                fu['E772 x=0.1 Q0=12.5'][:ncut,0].T*(fu['E772 x=0.1 Q0=12.5'][:ncut,1]+fu['E772 x=0.1 Q0=12.5'][:ncut,2]).T,\
                linewidth=0, color="forestgreen", alpha=0.5)
#setting
ax.set_xlabel(r'$b_T~\rm(GeV^{-1})$',size=30)
ax.set_ylabel(r'$bf(x,b)~\rm(GeV^{-1})$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(0,14)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'E772~800\,GeV',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.85,r'x=0.1',horizontalalignment='center',transform=ax.transAxes,size=20)
py.tight_layout()

#py.savefig('results/tmp.png')

# %% [markdown]
# ### CDF / D0

# %%
fu['D0 RunI x=0.05 Q0=91.2']=np.loadtxt("tmdplots/f_D0I_x=0.05_Q0=91.2.dat",skiprows=0)
fu['D0 RunII x=0.05 Q0=91.2']=np.loadtxt("tmdplots/f_D0II_x=0.05_Q0=91.2.dat",skiprows=0)
fu['CDF RunI x=0.05 Q0=91.2']=np.loadtxt("tmdplots/f_CDFI_x=0.05_Q0=91.2.dat",skiprows=0)
fu['CDF RunII x=0.05 Q0=91.2']=np.loadtxt("tmdplots/f_CDFII_x=0.05_Q0=91.2.dat",skiprows=0)

fu['D0 RunI x=0.1 Q0=91.2']=np.loadtxt("tmdplots/f_D0I_x=0.1_Q0=91.2.dat",skiprows=0)
fu['D0 RunII x=0.1 Q0=91.2']=np.loadtxt("tmdplots/f_D0II_x=0.1_Q0=91.2.dat",skiprows=0)
fu['CDF RunI x=0.1 Q0=91.2']=np.loadtxt("tmdplots/f_CDFI_x=0.1_Q0=91.2.dat",skiprows=0)
fu['CDF RunII x=0.1 Q0=91.2']=np.loadtxt("tmdplots/f_CDFII_x=0.1_Q0=91.2.dat",skiprows=0)

# %%
nrows,ncols=2,2
py.figure(figsize=(ncols*7,nrows*8))

ax=py.subplot(nrows,ncols,1)
#Q=5.5
ncut=2400
ax.plot(fu['D0 RunI x=0.05 Q0=91.2'][:ncut,0].T, fu['D0 RunI x=0.05 Q0=91.2'][:ncut,1].T,color='red',ls='-')
ax.fill_between(fu['D0 RunI x=0.05 Q0=91.2'][:ncut,0].T,\
                (fu['D0 RunI x=0.05 Q0=91.2'][:ncut,1]-fu['D0 RunI x=0.05 Q0=91.2'][:ncut,2]).T,\
                (fu['D0 RunI x=0.05 Q0=91.2'][:ncut,1]+fu['D0 RunI x=0.05 Q0=91.2'][:ncut,2]).T,\
                linewidth=0, color="red", alpha=0.5)
#Q=6.5
ncut=2400
ax.plot(fu['D0 RunII x=0.05 Q0=91.2'][:ncut,0].T, fu['D0 RunII x=0.05 Q0=91.2'][:ncut,1].T,color='green',ls='-')
ax.fill_between(fu['D0 RunII x=0.05 Q0=91.2'][:ncut,0].T,\
                (fu['D0 RunII x=0.05 Q0=91.2'][:ncut,1]-fu['D0 RunII x=0.05 Q0=91.2'][:ncut,2]).T,\
                (fu['D0 RunII x=0.05 Q0=91.2'][:ncut,1]+fu['D0 RunII x=0.05 Q0=91.2'][:ncut,2]).T,\
                linewidth=0, color="green", alpha=0.5)
#Q=7.5
ncut=2400
ax.plot(fu['CDF RunI x=0.05 Q0=91.2'][:ncut,0].T, fu['CDF RunI x=0.05 Q0=91.2'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(fu['CDF RunI x=0.05 Q0=91.2'][:ncut,0].T,\
                (fu['CDF RunI x=0.05 Q0=91.2'][:ncut,1]-fu['CDF RunI x=0.05 Q0=91.2'][:ncut,2]).T,\
                (fu['CDF RunI x=0.05 Q0=91.2'][:ncut,1]+fu['CDF RunI x=0.05 Q0=91.2'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)
#Q=8.5
ncut=2400
ax.plot(fu['CDF RunII x=0.05 Q0=91.2'][:ncut,0].T, fu['CDF RunII x=0.05 Q0=91.2'][:ncut,1].T,color='orange',ls='-')
ax.fill_between(fu['CDF RunII x=0.05 Q0=91.2'][:ncut,0].T,\
                (fu['CDF RunII x=0.05 Q0=91.2'][:ncut,1]-fu['CDF RunII x=0.05 Q0=91.2'][:ncut,2]).T,\
                (fu['CDF RunII x=0.05 Q0=91.2'][:ncut,1]+fu['CDF RunII x=0.05 Q0=91.2'][:ncut,2]).T,\
                linewidth=0, color="orange", alpha=0.5)
#setting
ax.set_xlabel(r'$b_T~\rm(GeV^{-1})$',size=30)
ax.set_ylabel(r'$f(x,b)$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(0,20)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'D0~\&~CDF',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.85,r'x=0.2',horizontalalignment='center',transform=ax.transAxes,size=20)

ax=py.subplot(nrows,ncols,2)
#Q=5.5
ncut=2400
ax.plot(fu['D0 RunI x=0.05 Q0=91.2'][:ncut,0].T, fu['D0 RunI x=0.05 Q0=91.2'][:ncut,0].T*fu['D0 RunI x=0.05 Q0=91.2'][:ncut,1].T,color='red',ls='-')
ax.fill_between(fu['D0 RunI x=0.05 Q0=91.2'][:ncut,0].T,\
                fu['D0 RunI x=0.05 Q0=91.2'][:ncut,0].T*(fu['D0 RunI x=0.05 Q0=91.2'][:ncut,1]-fu['D0 RunI x=0.05 Q0=91.2'][:ncut,2]).T,\
                fu['D0 RunI x=0.05 Q0=91.2'][:ncut,0].T*(fu['D0 RunI x=0.05 Q0=91.2'][:ncut,1]+fu['D0 RunI x=0.05 Q0=91.2'][:ncut,2]).T,\
                linewidth=0, color="red", alpha=0.5)
#Q=6.5
ncut=2400
ax.plot(fu['D0 RunII x=0.05 Q0=91.2'][:ncut,0].T, fu['D0 RunII x=0.05 Q0=91.2'][:ncut,0].T*fu['D0 RunII x=0.05 Q0=91.2'][:ncut,1].T,color='green',ls='-')
ax.fill_between(fu['D0 RunII x=0.05 Q0=91.2'][:ncut,0].T,\
                fu['D0 RunII x=0.05 Q0=91.2'][:ncut,0].T*(fu['D0 RunII x=0.05 Q0=91.2'][:ncut,1]-fu['D0 RunII x=0.05 Q0=91.2'][:ncut,2]).T,\
                fu['D0 RunII x=0.05 Q0=91.2'][:ncut,0].T*(fu['D0 RunII x=0.05 Q0=91.2'][:ncut,1]+fu['D0 RunII x=0.05 Q0=91.2'][:ncut,2]).T,\
                linewidth=0, color="green", alpha=0.5)
#Q=7.5
ncut=2400
ax.plot(fu['CDF RunI x=0.05 Q0=91.2'][:ncut,0].T, fu['CDF RunI x=0.05 Q0=91.2'][:ncut,0].T*fu['CDF RunI x=0.05 Q0=91.2'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(fu['CDF RunI x=0.05 Q0=91.2'][:ncut,0].T,\
                fu['CDF RunI x=0.05 Q0=91.2'][:ncut,0].T*(fu['CDF RunI x=0.05 Q0=91.2'][:ncut,1]-fu['CDF RunI x=0.05 Q0=91.2'][:ncut,2]).T,\
                fu['CDF RunI x=0.05 Q0=91.2'][:ncut,0].T*(fu['CDF RunI x=0.05 Q0=91.2'][:ncut,1]+fu['CDF RunI x=0.05 Q0=91.2'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)
#Q=8.5
ncut=2400
ax.plot(fu['CDF RunII x=0.05 Q0=91.2'][:ncut,0].T, fu['CDF RunII x=0.05 Q0=91.2'][:ncut,0].T*fu['CDF RunII x=0.05 Q0=91.2'][:ncut,1].T,color='orange',ls='-')
ax.fill_between(fu['CDF RunII x=0.05 Q0=91.2'][:ncut,0].T,\
                fu['CDF RunII x=0.05 Q0=91.2'][:ncut,0].T*(fu['CDF RunII x=0.05 Q0=91.2'][:ncut,1]-fu['CDF RunII x=0.05 Q0=91.2'][:ncut,2]).T,\
                fu['CDF RunII x=0.05 Q0=91.2'][:ncut,0].T*(fu['CDF RunII x=0.05 Q0=91.2'][:ncut,1]+fu['CDF RunII x=0.05 Q0=91.2'][:ncut,2]).T,\
                linewidth=0, color="orange", alpha=0.5)
#setting
ax.set_xlabel(r'$b_T~\rm(GeV^{-1})$',size=30)
ax.set_ylabel(r'$bf(x,b)~\rm(GeV^{-1})$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(0,4)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'D0~\&~CDF',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.85,r'x=0.2',horizontalalignment='center',transform=ax.transAxes,size=20)

ax=py.subplot(nrows,ncols,3)
#Q=5.5
ncut=2400
ax.plot(fu['D0 RunI x=0.1 Q0=91.2'][:ncut,0].T, fu['D0 RunI x=0.1 Q0=91.2'][:ncut,1].T,color='red',ls='-')
ax.fill_between(fu['D0 RunI x=0.1 Q0=91.2'][:ncut,0].T,\
                (fu['D0 RunI x=0.1 Q0=91.2'][:ncut,1]-fu['D0 RunI x=0.1 Q0=91.2'][:ncut,2]).T,\
                (fu['D0 RunI x=0.1 Q0=91.2'][:ncut,1]+fu['D0 RunI x=0.1 Q0=91.2'][:ncut,2]).T,\
                linewidth=0, color="red", alpha=0.5)
#Q=6.5
ncut=2400
ax.plot(fu['D0 RunII x=0.1 Q0=91.2'][:ncut,0].T, fu['D0 RunII x=0.1 Q0=91.2'][:ncut,1].T,color='green',ls='-')
ax.fill_between(fu['D0 RunII x=0.1 Q0=91.2'][:ncut,0].T,\
                (fu['D0 RunII x=0.1 Q0=91.2'][:ncut,1]-fu['D0 RunII x=0.1 Q0=91.2'][:ncut,2]).T,\
                (fu['D0 RunII x=0.1 Q0=91.2'][:ncut,1]+fu['D0 RunII x=0.1 Q0=91.2'][:ncut,2]).T,\
                linewidth=0, color="green", alpha=0.5)
#Q=7.5
ncut=2400
ax.plot(fu['CDF RunI x=0.1 Q0=91.2'][:ncut,0].T, fu['CDF RunI x=0.1 Q0=91.2'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(fu['CDF RunI x=0.1 Q0=91.2'][:ncut,0].T,\
                (fu['CDF RunI x=0.1 Q0=91.2'][:ncut,1]-fu['CDF RunI x=0.1 Q0=91.2'][:ncut,2]).T,\
                (fu['CDF RunI x=0.1 Q0=91.2'][:ncut,1]+fu['CDF RunI x=0.1 Q0=91.2'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)
#Q=8.5
ncut=2400
ax.plot(fu['CDF RunII x=0.1 Q0=91.2'][:ncut,0].T, fu['CDF RunII x=0.1 Q0=91.2'][:ncut,1].T,color='orange',ls='-')
ax.fill_between(fu['CDF RunII x=0.1 Q0=91.2'][:ncut,0].T,\
                (fu['CDF RunII x=0.1 Q0=91.2'][:ncut,1]-fu['CDF RunII x=0.1 Q0=91.2'][:ncut,2]).T,\
                (fu['CDF RunII x=0.1 Q0=91.2'][:ncut,1]+fu['CDF RunII x=0.1 Q0=91.2'][:ncut,2]).T,\
                linewidth=0, color="orange", alpha=0.5)
#setting
ax.set_xlabel(r'$b_T~\rm(GeV^{-1})$',size=30)
ax.set_ylabel(r'$f(x,b)$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(0,10)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'D0~\&~CDF',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.85,r'x=0.1',horizontalalignment='center',transform=ax.transAxes,size=20)

ax=py.subplot(nrows,ncols,4)
#Q=5.5
ncut=2400
ax.plot(fu['D0 RunI x=0.1 Q0=91.2'][:ncut,0].T, fu['D0 RunI x=0.1 Q0=91.2'][:ncut,0].T*fu['D0 RunI x=0.1 Q0=91.2'][:ncut,1].T,color='red',ls='-')
ax.fill_between(fu['D0 RunI x=0.1 Q0=91.2'][:ncut,0].T,\
                fu['D0 RunI x=0.1 Q0=91.2'][:ncut,0].T*(fu['D0 RunI x=0.1 Q0=91.2'][:ncut,1]-fu['D0 RunI x=0.1 Q0=91.2'][:ncut,2]).T,\
                fu['D0 RunI x=0.1 Q0=91.2'][:ncut,0].T*(fu['D0 RunI x=0.1 Q0=91.2'][:ncut,1]+fu['D0 RunI x=0.1 Q0=91.2'][:ncut,2]).T,\
                linewidth=0, color="red", alpha=0.5)
#Q=6.5
ncut=2400
ax.plot(fu['D0 RunII x=0.1 Q0=91.2'][:ncut,0].T, fu['D0 RunII x=0.1 Q0=91.2'][:ncut,0].T*fu['D0 RunII x=0.1 Q0=91.2'][:ncut,1].T,color='green',ls='-')
ax.fill_between(fu['D0 RunII x=0.1 Q0=91.2'][:ncut,0].T,\
                fu['D0 RunII x=0.1 Q0=91.2'][:ncut,0].T*(fu['D0 RunII x=0.1 Q0=91.2'][:ncut,1]-fu['D0 RunII x=0.1 Q0=91.2'][:ncut,2]).T,\
                fu['D0 RunII x=0.1 Q0=91.2'][:ncut,0].T*(fu['D0 RunII x=0.1 Q0=91.2'][:ncut,1]+fu['D0 RunII x=0.1 Q0=91.2'][:ncut,2]).T,\
                linewidth=0, color="green", alpha=0.5)
#Q=7.5
ncut=2400
ax.plot(fu['CDF RunI x=0.1 Q0=91.2'][:ncut,0].T, fu['CDF RunI x=0.1 Q0=91.2'][:ncut,0].T*fu['CDF RunI x=0.1 Q0=91.2'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(fu['CDF RunI x=0.1 Q0=91.2'][:ncut,0].T,\
                fu['CDF RunI x=0.1 Q0=91.2'][:ncut,0].T*(fu['CDF RunI x=0.1 Q0=91.2'][:ncut,1]-fu['CDF RunI x=0.1 Q0=91.2'][:ncut,2]).T,\
                fu['CDF RunI x=0.1 Q0=91.2'][:ncut,0].T*(fu['CDF RunI x=0.1 Q0=91.2'][:ncut,1]+fu['CDF RunI x=0.1 Q0=91.2'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)
#Q=8.5
ncut=2400
ax.plot(fu['CDF RunII x=0.1 Q0=91.2'][:ncut,0].T, fu['CDF RunII x=0.1 Q0=91.2'][:ncut,0].T*fu['CDF RunII x=0.1 Q0=91.2'][:ncut,1].T,color='orange',ls='-')
ax.fill_between(fu['CDF RunII x=0.1 Q0=91.2'][:ncut,0].T,\
                fu['CDF RunII x=0.1 Q0=91.2'][:ncut,0].T*(fu['CDF RunII x=0.1 Q0=91.2'][:ncut,1]-fu['CDF RunII x=0.1 Q0=91.2'][:ncut,2]).T,\
                fu['CDF RunII x=0.1 Q0=91.2'][:ncut,0].T*(fu['CDF RunII x=0.1 Q0=91.2'][:ncut,1]+fu['CDF RunII x=0.1 Q0=91.2'][:ncut,2]).T,\
                linewidth=0, color="orange", alpha=0.5)
#setting
ax.set_xlabel(r'$b_T~\rm(GeV^{-1})$',size=30)
ax.set_ylabel(r'$bf(x,b)~\rm(GeV^{-1})$',size=30)
ax.set_xlim(0,5)
ax.set_ylim(0,2)
#ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'D0~\&~CDF',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.85,r'x=0.1',horizontalalignment='center',transform=ax.transAxes,size=20)

py.tight_layout()

#py.savefig('results/tmp.png')

# %%
### ATLAS

# %%
fu['ATLAS8 x=0.1 Q0=56.0']=np.loadtxt("tmdplots/f_ATLAS8_x=0.1_Q0=56.0.dat",skiprows=0)
fu['ATLAS8 x=0.1 Q0=91.2']=np.loadtxt("tmdplots/f_ATLAS8_x=0.1_Q0=91.2.dat",skiprows=0)

# %% [markdown]
# ## Evolution

# %%
evol={}
evol['CDF RunI x=0.1 b=0.45']=np.loadtxt("tmdplots/evol_CDFI_x=0.1_b=0.45.dat",skiprows=0)

# %%
nrows,ncols=2,2
py.figure(figsize=(ncols*7,nrows*8))

nb=4

ax=py.subplot(nrows,ncols,1)
#E288 200
ax.errorbar(4.5, fu['E288 200 x=0.1 Q0=4.5'][nb,1],\
            yerr=fu['E288 200 x=0.1 Q0=4.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
ax.errorbar(5.5, fu['E288 200 x=0.1 Q0=5.5'][nb,1],\
            yerr=fu['E288 200 x=0.1 Q0=5.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
ax.errorbar(6.5, fu['E288 200 x=0.1 Q0=6.5'][nb,1],\
            yerr=fu['E288 200 x=0.1 Q0=6.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
ax.errorbar(7.5, fu['E288 200 x=0.1 Q0=7.5'][nb,1],\
            yerr=fu['E288 200 x=0.1 Q0=7.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
ax.errorbar(8.5, fu['E288 200 x=0.1 Q0=8.5'][nb,1],\
            yerr=fu['E288 200 x=0.1 Q0=8.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='black')
#E288 300
ax.errorbar(4.5, fu['E288 300 x=0.1 Q0=4.5'][nb,1],\
            yerr=fu['E288 300 x=0.1 Q0=4.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='blue')
ax.errorbar(5.5, fu['E288 300 x=0.1 Q0=5.5'][nb,1],\
            yerr=fu['E288 300 x=0.1 Q0=5.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='blue')
ax.errorbar(6.5, fu['E288 300 x=0.1 Q0=6.5'][nb,1],\
            yerr=fu['E288 300 x=0.1 Q0=6.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='blue')
ax.errorbar(7.5, fu['E288 300 x=0.1 Q0=7.5'][nb,1],\
            yerr=fu['E288 300 x=0.1 Q0=7.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='blue')
ax.errorbar(8.5, fu['E288 300 x=0.1 Q0=8.5'][nb,1],\
            yerr=fu['E288 300 x=0.1 Q0=8.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='blue')
#E288 400
ax.errorbar(5.5, fu['E288 400 x=0.1 Q0=5.5'][nb,1],\
            yerr=fu['E288 400 x=0.1 Q0=5.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='red')
ax.errorbar(6.5, fu['E288 400 x=0.1 Q0=6.5'][nb,1],\
            yerr=fu['E288 400 x=0.1 Q0=6.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='red')
ax.errorbar(7.5, fu['E288 400 x=0.1 Q0=7.5'][nb,1],\
            yerr=fu['E288 400 x=0.1 Q0=7.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='red')
ax.errorbar(8.5, fu['E288 400 x=0.1 Q0=8.5'][nb,1],\
            yerr=fu['E288 400 x=0.1 Q0=8.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='red')
ax.errorbar(11.5, fu['E288 400 x=0.1 Q0=11.5'][nb,1],\
            yerr=fu['E288 400 x=0.1 Q0=11.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='red')
ax.errorbar(12.5, fu['E288 400 x=0.1 Q0=12.5'][nb,1],\
            yerr=fu['E288 400 x=0.1 Q0=12.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='red')
ax.errorbar(13.5, fu['E288 400 x=0.1 Q0=13.5'][nb,1],\
            yerr=fu['E288 400 x=0.1 Q0=13.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='red')
#E605
ax.errorbar(7.5, fu['E605 x=0.1 Q0=7.5'][nb,1],\
            yerr=fu['E605 x=0.1 Q0=7.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='green')
ax.errorbar(8.5, fu['E605 x=0.1 Q0=8.5'][nb,1],\
            yerr=fu['E605 x=0.1 Q0=8.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='green')
ax.errorbar(11.0, fu['E605 x=0.1 Q0=11.0'][nb,1],\
            yerr=fu['E605 x=0.1 Q0=11.0'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='green')
ax.errorbar(12.5, fu['E605 x=0.1 Q0=12.5'][nb,1],\
            yerr=fu['E605 x=0.1 Q0=12.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='green')
ax.errorbar(15.8, fu['E605 x=0.1 Q0=15.8'][nb,1],\
            yerr=fu['E605 x=0.1 Q0=15.8'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='green')
#E772
ax.errorbar(5.5, fu['E772 x=0.1 Q0=5.5'][nb,1],\
            yerr=fu['E772 x=0.1 Q0=5.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='orange')
ax.errorbar(6.5, fu['E772 x=0.1 Q0=6.5'][nb,1],\
            yerr=fu['E772 x=0.1 Q0=6.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='orange')
ax.errorbar(7.5, fu['E772 x=0.1 Q0=7.5'][nb,1],\
            yerr=fu['E772 x=0.1 Q0=7.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='orange')
ax.errorbar(8.5, fu['E772 x=0.1 Q0=8.5'][nb,1],\
            yerr=fu['E772 x=0.1 Q0=8.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='orange')
ax.errorbar(11.5, fu['E772 x=0.1 Q0=11.5'][nb,1],\
            yerr=fu['E772 x=0.1 Q0=11.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='orange')
ax.errorbar(12.5, fu['E772 x=0.1 Q0=12.5'][nb,1],\
            yerr=fu['E772 x=0.1 Q0=12.5'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='orange')
#ATLAS
ax.errorbar(56.0, fu['ATLAS8 x=0.1 Q0=56.0'][nb,1],\
            yerr=fu['ATLAS8 x=0.1 Q0=56.0'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='cyan')
ax.errorbar(91.2, fu['ATLAS8 x=0.1 Q0=91.2'][nb,1],\
            yerr=fu['ATLAS8 x=0.1 Q0=91.2'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='cyan')
#CDF
ax.errorbar(91.2, fu['CDF RunI x=0.1 Q0=91.2'][nb,1],\
            yerr=fu['CDF RunI x=0.1 Q0=91.2'][nb,2], marker='o', capsize=2, linewidth=0, elinewidth=1, color='magenta')
#evol CDF I
ncut=2400
ax.plot(evol['CDF RunI x=0.1 b=0.45'][:ncut,0].T, evol['CDF RunI x=0.1 b=0.45'][:ncut,1].T,color='magenta',ls='-')
ax.fill_between(evol['CDF RunI x=0.1 b=0.45'][:ncut,0].T,\
                (evol['CDF RunI x=0.1 b=0.45'][:ncut,1]-evol['CDF RunI x=0.1 b=0.45'][:ncut,2]).T,\
                (evol['CDF RunI x=0.1 b=0.45'][:ncut,1]+evol['CDF RunI x=0.1 b=0.45'][:ncut,2]).T,\
                linewidth=0, color="magenta", alpha=0.5)




#setting
ax.set_xlabel(r'$Q~\rm(GeV)$',size=30)
ax.set_ylabel(r'$f(x,b)$',size=30)
ax.set_xlim(4,105)
ax.set_ylim(0,10)
ax.set_xscale('log')
ax.tick_params(axis='both', which='major', labelsize=25)
ax.text(0.20,0.95,r'$x=0.1$',horizontalalignment='center',transform=ax.transAxes,size=20)
ax.text(0.20,0.90,r'$b=0.45\,\rm GeV^{-1}$',horizontalalignment='center',transform=ax.transAxes,size=20)


py.tight_layout()
