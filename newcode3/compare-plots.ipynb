# %% [markdown]
# # Compare

# %%
import sys,os
import numpy as np
import pandas as pd
import pylab as py
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import rc
from matplotlib.colors import LogNorm
from matplotlib.font_manager import FontProperties
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text',usetex=True)
# %matplotlib inline
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
font0=FontProperties()
font0.set_family('sans-serif')
font0.set_style('italic')
font0.set_variant('normal')

# %% [markdown]
# ## qTmax

# %%
fitresult={}

# %% [markdown]
# ### E288-200

# %%
d1=fitresult['E288-200 Q=4.5']=np.loadtxt('fit_results/E288_200_Q=4.5.dat', skiprows=6)
d2=fitresult['E288-200 Q=5.5']=np.loadtxt('fit_results/E288_200_Q=5.5.dat', skiprows=6)
d3=fitresult['E288-200 Q=6.5']=np.loadtxt('fit_results/E288_200_Q=6.5.dat', skiprows=6)
d4=fitresult['E288-200 Q=7.5']=np.loadtxt('fit_results/E288_200_Q=7.5.dat', skiprows=6)
d5=fitresult['E288-200 Q=8.5']=np.loadtxt('fit_results/E288_200_Q=8.5.dat', skiprows=6)

# %%
nrows,ncols=1,1

fig=py.figure(figsize=(nrows*7,ncols*7))
ax=fig.add_subplot(nrows,ncols,1, projection='3d')
#
ax.plot(d1[:,0], d1[:,5], d1[:,3], color='blue', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d1)):
    ax.plot((d1[i,0],d1[i,0]), (d1[i,5],d1[i,5]), (0,d1[i,3]), color='blue', linestyle=':', linewidth=0.5)
#
ax.plot(d2[:,0], d2[:,5], d2[:,3], color='red', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d2)):
    ax.plot((d2[i,0],d2[i,0]), (d2[i,5],d2[i,5]), (0,d2[i,3]), color='red', linestyle=':', linewidth=0.5)
#
ax.plot(d3[:,0], d3[:,5], d3[:,3], color='forestgreen', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d3)):
    ax.plot((d3[i,0],d3[i,0]), (d3[i,5],d3[i,5]), (0,d3[i,3]), color='forestgreen', linestyle=':', linewidth=0.5)
#
ax.plot(d4[:,0], d4[:,5], d4[:,3], color='darkturquoise', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d4)):
    ax.plot((d4[i,0],d4[i,0]), (d4[i,5],d4[i,5]), (0,d4[i,3]), color='darkturquoise', linestyle=':', linewidth=0.5)
#
ax.plot(d5[:,0], d5[:,5], d5[:,3], color='orange', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d5)):
    ax.plot((d5[i,0],d5[i,0]), (d5[i,5],d5[i,5]), (0,d5[i,3]), color='orange', linestyle=':', linewidth=0.5)
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.tick_params(axis='z', which='major', direction='in', labelsize=25, pad=5)
ax.set_xlabel(r'$Q_T/Q$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$\alpha$', fontsize=25, labelpad=15)
ax.set_zlabel(r'$\chi^2/dof$', fontsize=25, labelpad=15)
ax.set_xlim(0,0.7)
ax.set_ylim(0,4)

fig.tight_layout()
#fig.savefig("tmp.png")

# %% [markdown]
# ### E288-300

# %%
d1=fitresult['E288-300 Q=4.5']=np.loadtxt('fit_results/E288_300_Q=4.5.dat', skiprows=6)
d2=fitresult['E288-300 Q=5.5']=np.loadtxt('fit_results/E288_300_Q=5.5.dat', skiprows=6)
d3=fitresult['E288-300 Q=6.5']=np.loadtxt('fit_results/E288_300_Q=6.5.dat', skiprows=6)
d4=fitresult['E288-300 Q=7.5']=np.loadtxt('fit_results/E288_300_Q=7.5.dat', skiprows=6)
d5=fitresult['E288-300 Q=8.5']=np.loadtxt('fit_results/E288_300_Q=8.5.dat', skiprows=6)

# %%
nrows,ncols=1,1

fig=py.figure(figsize=(nrows*7,ncols*7))
ax=fig.add_subplot(nrows,ncols,1, projection='3d')
#
ax.plot(d1[:,0], d1[:,5], d1[:,3], color='blue', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d1)):
    ax.plot((d1[i,0],d1[i,0]), (d1[i,5],d1[i,5]), (0,d1[i,3]), color='blue', linestyle=':', linewidth=0.5)
#
ax.plot(d2[:,0], d2[:,5], d2[:,3], color='red', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d2)):
    ax.plot((d2[i,0],d2[i,0]), (d2[i,5],d2[i,5]), (0,d2[i,3]), color='red', linestyle=':', linewidth=0.5)
#
ax.plot(d3[:,0], d3[:,5], d3[:,3], color='forestgreen', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d3)):
    ax.plot((d3[i,0],d3[i,0]), (d3[i,5],d3[i,5]), (0,d3[i,3]), color='forestgreen', linestyle=':', linewidth=0.5)
#
ax.plot(d4[:,0], d4[:,5], d4[:,3], color='darkturquoise', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d4)):
    ax.plot((d4[i,0],d4[i,0]), (d4[i,5],d4[i,5]), (0,d4[i,3]), color='darkturquoise', linestyle=':', linewidth=0.5)
#
ax.plot(d5[:,0], d5[:,5], d5[:,3], color='orange', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d5)):
    ax.plot((d5[i,0],d5[i,0]), (d5[i,5],d5[i,5]), (0,d5[i,3]), color='orange', linestyle=':', linewidth=0.5)
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.tick_params(axis='z', which='major', direction='in', labelsize=25, pad=5)
ax.set_xlabel(r'$Q_T/Q$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$\alpha$', fontsize=25, labelpad=15)
ax.set_zlabel(r'$\chi^2/dof$', fontsize=25, labelpad=15)
ax.set_xlim(0,0.7)
ax.set_ylim(0,4)

fig.tight_layout()
#fig.savefig("tmp.png")

# %% [markdown]
# ### E288-400

# %%
d1=fitresult['E288-400 Q=5.5']=np.loadtxt('fit_results/E288_400_Q=5.5.dat', skiprows=6)
d2=fitresult['E288-400 Q=6.5']=np.loadtxt('fit_results/E288_400_Q=6.5.dat', skiprows=6)
d3=fitresult['E288-400 Q=7.5']=np.loadtxt('fit_results/E288_400_Q=7.5.dat', skiprows=6)
d4=fitresult['E288-400 Q=8.5']=np.loadtxt('fit_results/E288_400_Q=8.5.dat', skiprows=6)
d5=fitresult['E288-400 Q=11.5']=np.loadtxt('fit_results/E288_400_Q=11.5.dat', skiprows=6)
d6=fitresult['E288-400 Q=12.5']=np.loadtxt('fit_results/E288_400_Q=12.5.dat', skiprows=6)
d7=fitresult['E288-400 Q=13.5']=np.loadtxt('fit_results/E288_400_Q=13.5.dat', skiprows=6)

# %%
nrows,ncols=1,1

fig=py.figure(figsize=(nrows*7,ncols*7))
ax=fig.add_subplot(nrows,ncols,1, projection='3d')
#
ax.plot(d1[:,0], d1[:,5], d1[:,3], color='blue', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d1)):
    ax.plot((d1[i,0],d1[i,0]), (d1[i,5],d1[i,5]), (0,d1[i,3]), color='blue', linestyle=':', linewidth=0.5)
#
ax.plot(d2[:,0], d2[:,5], d2[:,3], color='red', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d2)):
    ax.plot((d2[i,0],d2[i,0]), (d2[i,5],d2[i,5]), (0,d2[i,3]), color='red', linestyle=':', linewidth=0.5)
#
ax.plot(d3[:,0], d3[:,5], d3[:,3], color='forestgreen', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d3)):
    ax.plot((d3[i,0],d3[i,0]), (d3[i,5],d3[i,5]), (0,d3[i,3]), color='forestgreen', linestyle=':', linewidth=0.5)
#
ax.plot(d4[:,0], d4[:,5], d4[:,3], color='darkturquoise', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d4)):
    ax.plot((d4[i,0],d4[i,0]), (d4[i,5],d4[i,5]), (0,d4[i,3]), color='darkturquoise', linestyle=':', linewidth=0.5)
#
ax.plot(d5[:,0], d5[:,5], d5[:,3], color='orange', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d5)):
    ax.plot((d5[i,0],d5[i,0]), (d5[i,5],d5[i,5]), (0,d5[i,3]), color='orange', linestyle=':', linewidth=0.5)
#
ax.plot(d6[:,0], d6[:,5], d6[:,3], color='magenta', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d6)):
    ax.plot((d6[i,0],d6[i,0]), (d6[i,5],d6[i,5]), (0,d6[i,3]), color='magenta', linestyle=':', linewidth=0.5)
#
ax.plot(d7[:,0], d7[:,5], d7[:,3], color='cyan', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d7)):
    ax.plot((d7[i,0],d7[i,0]), (d7[i,5],d7[i,5]), (0,d7[i,3]), color='cyan', linestyle=':', linewidth=0.5)
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.tick_params(axis='z', which='major', direction='in', labelsize=25, pad=5)
ax.set_xlabel(r'$Q_T/Q$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$\alpha$', fontsize=25, labelpad=15)
ax.set_zlabel(r'$\chi^2/dof$', fontsize=25, labelpad=15)
ax.set_xlim(0,0.7)
ax.set_ylim(0,4)

fig.tight_layout()
#fig.savefig("tmp.png")

# %% [markdown]
# ### E605

# %%
d1=fitresult['E605 Q=7.5']=np.loadtxt('fit_results/E605_Q=7.5.dat', skiprows=6)
d2=fitresult['E605 Q=8.5']=np.loadtxt('fit_results/E605_Q=8.5.dat', skiprows=6)
d3=fitresult['E605 Q=11.0']=np.loadtxt('fit_results/E605_Q=11.0.dat', skiprows=6)
d4=fitresult['E605 Q=12.5']=np.loadtxt('fit_results/E605_Q=12.5.dat', skiprows=6)
d5=fitresult['E605 Q=15.8']=np.loadtxt('fit_results/E605_Q=15.8.dat', skiprows=6)

# %%
nrows,ncols=1,1

fig=py.figure(figsize=(nrows*7,ncols*7))
ax=fig.add_subplot(nrows,ncols,1, projection='3d')
#
ax.plot(d1[:,0], d1[:,5], d1[:,3], color='blue', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d1)):
    ax.plot((d1[i,0],d1[i,0]), (d1[i,5],d1[i,5]), (0,d1[i,3]), color='blue', linestyle=':', linewidth=0.5)
#
ax.plot(d2[:,0], d2[:,5], d2[:,3], color='red', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d2)):
    ax.plot((d2[i,0],d2[i,0]), (d2[i,5],d2[i,5]), (0,d2[i,3]), color='red', linestyle=':', linewidth=0.5)
#
ax.plot(d3[:,0], d3[:,5], d3[:,3], color='forestgreen', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d3)):
    ax.plot((d3[i,0],d3[i,0]), (d3[i,5],d3[i,5]), (0,d3[i,3]), color='forestgreen', linestyle=':', linewidth=0.5)
#
ax.plot(d4[:,0], d4[:,5], d4[:,3], color='darkturquoise', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d4)):
    ax.plot((d4[i,0],d4[i,0]), (d4[i,5],d4[i,5]), (0,d4[i,3]), color='darkturquoise', linestyle=':', linewidth=0.5)
#
ax.plot(d5[:,0], d5[:,5], d5[:,3], color='orange', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d5)):
    ax.plot((d5[i,0],d5[i,0]), (d5[i,5],d5[i,5]), (0,d5[i,3]), color='orange', linestyle=':', linewidth=0.5)
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.tick_params(axis='z', which='major', direction='in', labelsize=25, pad=5)
ax.set_xlabel(r'$Q_T/Q$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$\alpha$', fontsize=25, labelpad=15)
ax.set_zlabel(r'$\chi^2/dof$', fontsize=25, labelpad=15)
ax.set_xlim(0,0.7)
ax.set_ylim(0,6)

fig.tight_layout()
#fig.savefig("tmp.png")

# %% [markdown]
# ### E772

# %%
d1=fitresult['E772 Q=5.5']=np.loadtxt('fit_results/E772_Q=5.5.dat', skiprows=6)
d2=fitresult['E772 Q=6.5']=np.loadtxt('fit_results/E772_Q=6.5.dat', skiprows=6)
d3=fitresult['E772 Q=7.5']=np.loadtxt('fit_results/E772_Q=7.5.dat', skiprows=6)
d4=fitresult['E772 Q=8.5']=np.loadtxt('fit_results/E772_Q=8.5.dat', skiprows=6)
d5=fitresult['E772 Q=11.5']=np.loadtxt('fit_results/E772_Q=11.5.dat', skiprows=6)
d6=fitresult['E772 Q=12.5']=np.loadtxt('fit_results/E772_Q=12.5.dat', skiprows=6)

# %%
nrows,ncols=1,1

fig=py.figure(figsize=(nrows*7,ncols*7))
ax=fig.add_subplot(nrows,ncols,1, projection='3d')
#
ax.plot(d1[:,0], d1[:,5], d1[:,3], color='blue', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d1)):
    ax.plot((d1[i,0],d1[i,0]), (d1[i,5],d1[i,5]), (0,d1[i,3]), color='blue', linestyle=':', linewidth=0.5)
#
ax.plot(d2[:,0], d2[:,5], d2[:,3], color='red', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d2)):
    ax.plot((d2[i,0],d2[i,0]), (d2[i,5],d2[i,5]), (0,d2[i,3]), color='red', linestyle=':', linewidth=0.5)
#
ax.plot(d3[:,0], d3[:,5], d3[:,3], color='forestgreen', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d3)):
    ax.plot((d3[i,0],d3[i,0]), (d3[i,5],d3[i,5]), (0,d3[i,3]), color='forestgreen', linestyle=':', linewidth=0.5)
#
ax.plot(d4[:,0], d4[:,5], d4[:,3], color='darkturquoise', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d4)):
    ax.plot((d4[i,0],d4[i,0]), (d4[i,5],d4[i,5]), (0,d4[i,3]), color='darkturquoise', linestyle=':', linewidth=0.5)
#
ax.plot(d5[:,0], d5[:,5], d5[:,3], color='orange', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d5)):
    ax.plot((d5[i,0],d5[i,0]), (d5[i,5],d5[i,5]), (0,d5[i,3]), color='orange', linestyle=':', linewidth=0.5)
#
ax.plot(d6[:,0], d6[:,5], d6[:,3], color='magenta', marker='.', markersize=15, linewidth=0.5)
for i in range(len(d6)):
    ax.plot((d6[i,0],d6[i,0]), (d6[i,5],d6[i,5]), (0,d6[i,3]), color='magenta', linestyle=':', linewidth=0.5)
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.tick_params(axis='z', which='major', direction='in', labelsize=25, pad=5)
ax.set_xlabel(r'$Q_T/Q$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$\alpha$', fontsize=25, labelpad=15)
ax.set_zlabel(r'$\chi^2/dof$', fontsize=25, labelpad=15)
ax.set_xlim(0,0.7)
ax.set_ylim(0,4)

fig.tight_layout()
#fig.savefig("tmp.png")

# %% [markdown]
# ### D0 Run I

# %% [markdown]
# ### D0 Run II

# %% [markdown]
# ### CDF Run I

# %% [markdown]
# ### CDF Run II
