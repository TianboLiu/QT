# %% [markdown]
# # Compare

# %%
import sys,os
import numpy as np
import pandas as pd
import pylab as py
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import rc
from matplotlib.colors import LogNorm
from matplotlib.font_manager import FontProperties
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text',usetex=True)
# %matplotlib inline
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
font0=FontProperties()
font0.set_family('sans-serif')
font0.set_style('italic')
font0.set_variant('normal')

# %% [markdown]
# ## Log F

# %%
f={}

# %% [markdown]
# ### E288-200

# %%
L01=f['E288_200 Q=4.5 L0']=np.loadtxt('tmdplots2/f_E288_200_Q0=4.5_l0.dat', skiprows=0)
L02=f['E288_200 Q=5.5 L0']=np.loadtxt('tmdplots2/f_E288_200_Q0=5.5_l0.dat', skiprows=0)
L03=f['E288_200 Q=6.5 L0']=np.loadtxt('tmdplots2/f_E288_200_Q0=6.5_l0.dat', skiprows=0)
L04=f['E288_200 Q=7.5 L0']=np.loadtxt('tmdplots2/f_E288_200_Q0=7.5_l0.dat', skiprows=0)
L05=f['E288_200 Q=8.5 L0']=np.loadtxt('tmdplots2/f_E288_200_Q0=8.5_l0.dat', skiprows=0)

L11=f['E288_200 Q=4.5 L0']=np.loadtxt('tmdplots2/f_E288_200_Q0=4.5_l1.dat', skiprows=0)
L12=f['E288_200 Q=5.5 L0']=np.loadtxt('tmdplots2/f_E288_200_Q0=5.5_l1.dat', skiprows=0)
L13=f['E288_200 Q=6.5 L0']=np.loadtxt('tmdplots2/f_E288_200_Q0=6.5_l1.dat', skiprows=0)
L14=f['E288_200 Q=7.5 L0']=np.loadtxt('tmdplots2/f_E288_200_Q0=7.5_l1.dat', skiprows=0)
L15=f['E288_200 Q=8.5 L0']=np.loadtxt('tmdplots2/f_E288_200_Q0=8.5_l1.dat', skiprows=0)

L21=f['E288_200 Q=4.5 L0']=np.loadtxt('tmdplots2/f_E288_200_Q0=4.5_l2.dat', skiprows=0)
L22=f['E288_200 Q=5.5 L0']=np.loadtxt('tmdplots2/f_E288_200_Q0=5.5_l2.dat', skiprows=0)
L23=f['E288_200 Q=6.5 L0']=np.loadtxt('tmdplots2/f_E288_200_Q0=6.5_l2.dat', skiprows=0)
L24=f['E288_200 Q=7.5 L0']=np.loadtxt('tmdplots2/f_E288_200_Q0=7.5_l2.dat', skiprows=0)
L25=f['E288_200 Q=8.5 L0']=np.loadtxt('tmdplots2/f_E288_200_Q0=8.5_l2.dat', skiprows=0)

# %%
A0E=f['E288_200 evol b=0.5 Q0=8.5 L0']=np.loadtxt('tmdplots2/evol_E288_200_b=0.5_Q0=8.5_l0.dat', skiprows=0)
A1E=f['E288_200 evol b=0.5 Q0=8.5 L1']=np.loadtxt('tmdplots2/evol_E288_200_b=0.5_Q0=8.5_l1.dat', skiprows=0)
A2E=f['E288_200 evol b=0.5 Q0=8.5 L2']=np.loadtxt('tmdplots2/evol_E288_200_b=0.5_Q0=8.5_l2.dat', skiprows=0)
B0E=f['E288_200 evol b=1.0 Q0=8.5 L0']=np.loadtxt('tmdplots2/evol_E288_200_b=1.0_Q0=8.5_l0.dat', skiprows=0)
B1E=f['E288_200 evol b=1.0 Q0=8.5 L1']=np.loadtxt('tmdplots2/evol_E288_200_b=1.0_Q0=8.5_l1.dat', skiprows=0)
B2E=f['E288_200 evol b=1.0 Q0=8.5 L2']=np.loadtxt('tmdplots2/evol_E288_200_b=1.0_Q0=8.5_l2.dat', skiprows=0)

# %%
X=np.array([4.5, 5.5, 6.5, 7.5, 8.5])

Ab=50-1
AY0=np.array([L01[Ab,1], L02[Ab, 1], L03[Ab, 1], L04[Ab, 1], L05[Ab, 1]])
AY1=np.array([L11[Ab,1], L12[Ab, 1], L13[Ab, 1], L14[Ab, 1], L15[Ab, 1]])
AY2=np.array([L21[Ab,1], L22[Ab, 1], L23[Ab, 1], L24[Ab, 1], L25[Ab, 1]])
AE0=np.array([L01[Ab,2], L02[Ab, 2], L03[Ab, 2], L04[Ab, 2], L05[Ab, 2]])
AE1=np.array([L11[Ab,2], L12[Ab, 2], L13[Ab, 2], L14[Ab, 2], L15[Ab, 2]])
AE2=np.array([L21[Ab,2], L22[Ab, 2], L23[Ab, 2], L24[Ab, 2], L25[Ab, 2]])

Bb=100-1
BY0=np.array([L01[Bb,1], L02[Bb, 1], L03[Bb, 1], L04[Bb, 1], L05[Bb, 1]])
BY1=np.array([L11[Bb,1], L12[Bb, 1], L13[Bb, 1], L14[Bb, 1], L15[Bb, 1]])
BY2=np.array([L21[Bb,1], L22[Bb, 1], L23[Bb, 1], L24[Bb, 1], L25[Bb, 1]])
BE0=np.array([L01[Bb,2], L02[Bb, 2], L03[Bb, 2], L04[Bb, 2], L05[Bb, 2]])
BE1=np.array([L11[Bb,2], L12[Bb, 2], L13[Bb, 2], L14[Bb, 2], L15[Bb, 2]])
BE2=np.array([L21[Bb,2], L22[Bb, 2], L23[Bb, 2], L24[Bb, 2], L25[Bb, 2]])

# %%
nrows,ncols=1,3
fig=py.figure(figsize=(ncols*7,nrows*7))

ax=fig.add_subplot(nrows,ncols,1)
#
ax.errorbar(X, np.log(AY0), yerr=AE0/AY0, color='blue', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.errorbar(X, np.log(AY1), yerr=AE1/AY1, color='red', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.errorbar(X, np.log(AY2), yerr=AE2/AY2, color='orange', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.plot(A0E[:,0], np.log(A0E[:,1]), color='blue', alpha=0.7, linestyle='-', linewidth=1)
ax.plot(A1E[:,0], np.log(A1E[:,1]), color='red', alpha=0.7, linestyle='-', linewidth=1)
ax.plot(A2E[:,0], np.log(A2E[:,1]), color='orange', alpha=0.7, linestyle='-', linewidth=1)
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.set_xlabel(r'$\rm Q~(GeV)$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$\log F$', fontsize=25, labelpad=15)
ax.set_xlim(4,10)
ax.set_ylim(-1,1)
ax.set_xscale('log')
ax.text(0.1,0.9,r'$x=0.4$',horizontalalignment='left',transform=ax.transAxes,size=20)
ax.text(0.1,0.8,r'$b=0.5\,\rm GeV^{-1}$',horizontalalignment='left',transform=ax.transAxes,size=20)

ax=fig.add_subplot(nrows,ncols,2)
#
ax.errorbar(X, np.log(BY0), yerr=AE0/AY0, color='blue', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.errorbar(X, np.log(BY1), yerr=AE1/AY1, color='red', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.errorbar(X, np.log(BY2), yerr=AE2/AY2, color='orange', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.plot(B0E[:,0], np.log(B0E[:,1]), color='blue', alpha=0.7, linestyle='-', linewidth=1)
ax.plot(B1E[:,0], np.log(B1E[:,1]), color='red', alpha=0.7, linestyle='-', linewidth=1)
ax.plot(B2E[:,0], np.log(B2E[:,1]), color='orange', alpha=0.7, linestyle='-', linewidth=1)
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.set_xlabel(r'$\rm Q~(GeV)$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$\log F$', fontsize=25, labelpad=15)
ax.set_xlim(4,10)
ax.set_ylim(-1,1)
ax.set_xscale('log')
ax.text(0.1,0.9,r'$x=0.4$',horizontalalignment='left',transform=ax.transAxes,size=20)
ax.text(0.1,0.8,r'$b=1.0\,\rm GeV^{-1}$',horizontalalignment='left',transform=ax.transAxes,size=20)

ax=fig.add_subplot(nrows,ncols,3)
ax.plot(L11[:,0], L11[:,0]*L11[:,1]**2, color='black', linewidth=2, linestyle='-')
ax.plot(L12[:,0], L12[:,0]*L12[:,1]**2, color='blue', linewidth=2, dashes=[20,5])
ax.plot(L13[:,0], L13[:,0]*L13[:,1]**2, color='red', linewidth=2, dashes=[10,5])
ax.plot(L14[:,0], L14[:,0]*L14[:,1]**2, color='forestgreen', linewidth=2, dashes=[10,5,1,5])
ax.plot(L15[:,0], L15[:,0]*L15[:,1]**2, color='orange', linewidth=2, linestyle=':')
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.set_xlabel(r'$b~(\rm GeV^{-1})$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$bF^2$', fontsize=25, labelpad=15)
ax.set_xlim(0,3)
ax.set_ylim(0,1.5)
ax.text(0.1,0.9,r'$x=0.4$',horizontalalignment='left',transform=ax.transAxes,size=20)

fig.tight_layout()
#fig.savefig("tmp.png")

# %% [markdown]
# ### E288-300

# %%
L01=f['E288_300 Q=4.5 L0']=np.loadtxt('tmdplots2/f_E288_300_Q0=4.5_l0.dat', skiprows=0)
L02=f['E288_300 Q=5.5 L0']=np.loadtxt('tmdplots2/f_E288_300_Q0=5.5_l0.dat', skiprows=0)
L03=f['E288_300 Q=6.5 L0']=np.loadtxt('tmdplots2/f_E288_300_Q0=6.5_l0.dat', skiprows=0)
L04=f['E288_300 Q=7.5 L0']=np.loadtxt('tmdplots2/f_E288_300_Q0=7.5_l0.dat', skiprows=0)
L05=f['E288_300 Q=8.5 L0']=np.loadtxt('tmdplots2/f_E288_300_Q0=8.5_l0.dat', skiprows=0)

L11=f['E288_300 Q=4.5 L0']=np.loadtxt('tmdplots2/f_E288_300_Q0=4.5_l1.dat', skiprows=0)
L12=f['E288_300 Q=5.5 L0']=np.loadtxt('tmdplots2/f_E288_300_Q0=5.5_l1.dat', skiprows=0)
L13=f['E288_300 Q=6.5 L0']=np.loadtxt('tmdplots2/f_E288_300_Q0=6.5_l1.dat', skiprows=0)
L14=f['E288_300 Q=7.5 L0']=np.loadtxt('tmdplots2/f_E288_300_Q0=7.5_l1.dat', skiprows=0)
L15=f['E288_300 Q=8.5 L0']=np.loadtxt('tmdplots2/f_E288_300_Q0=8.5_l1.dat', skiprows=0)

L21=f['E288_300 Q=4.5 L0']=np.loadtxt('tmdplots2/f_E288_300_Q0=4.5_l2.dat', skiprows=0)
L22=f['E288_300 Q=5.5 L0']=np.loadtxt('tmdplots2/f_E288_300_Q0=5.5_l2.dat', skiprows=0)
L23=f['E288_300 Q=6.5 L0']=np.loadtxt('tmdplots2/f_E288_300_Q0=6.5_l2.dat', skiprows=0)
L24=f['E288_300 Q=7.5 L0']=np.loadtxt('tmdplots2/f_E288_300_Q0=7.5_l2.dat', skiprows=0)
L25=f['E288_300 Q=8.5 L0']=np.loadtxt('tmdplots2/f_E288_300_Q0=8.5_l2.dat', skiprows=0)

# %%
A0E=f['E288_300 evol b=0.5 Q0=8.5 L0']=np.loadtxt('tmdplots2/evol_E288_300_b=0.5_Q0=8.5_l0.dat', skiprows=0)
A1E=f['E288_300 evol b=0.5 Q0=8.5 L1']=np.loadtxt('tmdplots2/evol_E288_300_b=0.5_Q0=8.5_l1.dat', skiprows=0)
A2E=f['E288_300 evol b=0.5 Q0=8.5 L2']=np.loadtxt('tmdplots2/evol_E288_300_b=0.5_Q0=8.5_l2.dat', skiprows=0)
B0E=f['E288_300 evol b=1.0 Q0=8.5 L0']=np.loadtxt('tmdplots2/evol_E288_300_b=1.0_Q0=8.5_l0.dat', skiprows=0)
B1E=f['E288_300 evol b=1.0 Q0=8.5 L1']=np.loadtxt('tmdplots2/evol_E288_300_b=1.0_Q0=8.5_l1.dat', skiprows=0)
B2E=f['E288_300 evol b=1.0 Q0=8.5 L2']=np.loadtxt('tmdplots2/evol_E288_300_b=1.0_Q0=8.5_l2.dat', skiprows=0)

# %%
X=np.array([4.5, 5.5, 6.5, 7.5, 8.5])

Ab=50-1
AY0=np.array([L01[Ab,1], L02[Ab, 1], L03[Ab, 1], L04[Ab, 1], L05[Ab, 1]])
AY1=np.array([L11[Ab,1], L12[Ab, 1], L13[Ab, 1], L14[Ab, 1], L15[Ab, 1]])
AY2=np.array([L21[Ab,1], L22[Ab, 1], L23[Ab, 1], L24[Ab, 1], L25[Ab, 1]])
AE0=np.array([L01[Ab,2], L02[Ab, 2], L03[Ab, 2], L04[Ab, 2], L05[Ab, 2]])
AE1=np.array([L11[Ab,2], L12[Ab, 2], L13[Ab, 2], L14[Ab, 2], L15[Ab, 2]])
AE2=np.array([L21[Ab,2], L22[Ab, 2], L23[Ab, 2], L24[Ab, 2], L25[Ab, 2]])

Bb=100-1
BY0=np.array([L01[Bb,1], L02[Bb, 1], L03[Bb, 1], L04[Bb, 1], L05[Bb, 1]])
BY1=np.array([L11[Bb,1], L12[Bb, 1], L13[Bb, 1], L14[Bb, 1], L15[Bb, 1]])
BY2=np.array([L21[Bb,1], L22[Bb, 1], L23[Bb, 1], L24[Bb, 1], L25[Bb, 1]])
BE0=np.array([L01[Bb,2], L02[Bb, 2], L03[Bb, 2], L04[Bb, 2], L05[Bb, 2]])
BE1=np.array([L11[Bb,2], L12[Bb, 2], L13[Bb, 2], L14[Bb, 2], L15[Bb, 2]])
BE2=np.array([L21[Bb,2], L22[Bb, 2], L23[Bb, 2], L24[Bb, 2], L25[Bb, 2]])

# %%
nrows,ncols=1,3
fig=py.figure(figsize=(ncols*7,nrows*7))

ax=fig.add_subplot(nrows,ncols,1)
#
ax.errorbar(X, np.log(AY0), yerr=AE0/AY0, color='blue', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.errorbar(X, np.log(AY1), yerr=AE1/AY1, color='red', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.errorbar(X, np.log(AY2), yerr=AE2/AY2, color='orange', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.plot(A0E[:,0], np.log(A0E[:,1]), color='blue', alpha=0.7, linestyle='-', linewidth=1)
ax.plot(A1E[:,0], np.log(A1E[:,1]), color='red', alpha=0.7, linestyle='-', linewidth=1)
ax.plot(A2E[:,0], np.log(A2E[:,1]), color='orange', alpha=0.7, linestyle='-', linewidth=1)
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.set_xlabel(r'$\rm Q~(GeV)$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$\log F$', fontsize=25, labelpad=15)
ax.set_xlim(4,10)
ax.set_ylim(-1,1)
ax.set_xscale('log')
ax.text(0.1,0.9,r'$x=0.4$',horizontalalignment='left',transform=ax.transAxes,size=20)
ax.text(0.1,0.8,r'$b=0.5\,\rm GeV^{-1}$',horizontalalignment='left',transform=ax.transAxes,size=20)

ax=fig.add_subplot(nrows,ncols,2)
#
ax.errorbar(X, np.log(BY0), yerr=AE0/AY0, color='blue', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.errorbar(X, np.log(BY1), yerr=AE1/AY1, color='red', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.errorbar(X, np.log(BY2), yerr=AE2/AY2, color='orange', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.plot(B0E[:,0], np.log(B0E[:,1]), color='blue', alpha=0.7, linestyle='-', linewidth=1)
ax.plot(B1E[:,0], np.log(B1E[:,1]), color='red', alpha=0.7, linestyle='-', linewidth=1)
ax.plot(B2E[:,0], np.log(B2E[:,1]), color='orange', alpha=0.7, linestyle='-', linewidth=1)
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.set_xlabel(r'$\rm Q~(GeV)$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$\log F$', fontsize=25, labelpad=15)
ax.set_xlim(4,10)
ax.set_ylim(-1,1)
ax.set_xscale('log')
ax.text(0.1,0.9,r'$x=0.4$',horizontalalignment='left',transform=ax.transAxes,size=20)
ax.text(0.1,0.8,r'$b=1.0\,\rm GeV^{-1}$',horizontalalignment='left',transform=ax.transAxes,size=20)

ax=fig.add_subplot(nrows,ncols,3)
ax.plot(L11[:,0], L11[:,0]*L11[:,1]**2, color='black', linewidth=2, linestyle='-')
ax.plot(L12[:,0], L12[:,0]*L12[:,1]**2, color='blue', linewidth=2, dashes=[20,5])
ax.plot(L13[:,0], L13[:,0]*L13[:,1]**2, color='red', linewidth=2, dashes=[10,5])
ax.plot(L14[:,0], L14[:,0]*L14[:,1]**2, color='forestgreen', linewidth=2, dashes=[10,5,1,5])
ax.plot(L15[:,0], L15[:,0]*L15[:,1]**2, color='orange', linewidth=2, linestyle=':')
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.set_xlabel(r'$b~(\rm GeV^{-1})$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$bF^2$', fontsize=25, labelpad=15)
ax.set_xlim(0,3)
ax.set_ylim(0,1.5)
ax.text(0.1,0.9,r'$x=0.4$',horizontalalignment='left',transform=ax.transAxes,size=20)

fig.tight_layout()
#fig.savefig("tmp.png")

# %% [markdown]
# ### E288-400

# %%
L01=f['E288_400 Q=5.5 L0']=np.loadtxt('tmdplots2/f_E288_400_Q0=5.5_l0.dat', skiprows=0)
L02=f['E288_400 Q=6.5 L0']=np.loadtxt('tmdplots2/f_E288_400_Q0=6.5_l0.dat', skiprows=0)
L03=f['E288_400 Q=7.5 L0']=np.loadtxt('tmdplots2/f_E288_400_Q0=7.5_l0.dat', skiprows=0)
L04=f['E288_400 Q=8.5 L0']=np.loadtxt('tmdplots2/f_E288_400_Q0=8.5_l0.dat', skiprows=0)
L05=f['E288_400 Q=11.5 L0']=np.loadtxt('tmdplots2/f_E288_400_Q0=11.5_l0.dat', skiprows=0)
L06=f['E288_400 Q=12.5 L0']=np.loadtxt('tmdplots2/f_E288_400_Q0=12.5_l0.dat', skiprows=0)
L07=f['E288_400 Q=13.5 L0']=np.loadtxt('tmdplots2/f_E288_400_Q0=13.5_l0.dat', skiprows=0)

L11=f['E288_400 Q=5.5 L1']=np.loadtxt('tmdplots2/f_E288_400_Q0=5.5_l1.dat', skiprows=0)
L12=f['E288_400 Q=6.5 L1']=np.loadtxt('tmdplots2/f_E288_400_Q0=6.5_l1.dat', skiprows=0)
L13=f['E288_400 Q=7.5 L1']=np.loadtxt('tmdplots2/f_E288_400_Q0=7.5_l1.dat', skiprows=0)
L14=f['E288_400 Q=8.5 L1']=np.loadtxt('tmdplots2/f_E288_400_Q0=8.5_l1.dat', skiprows=0)
L15=f['E288_400 Q=11.5 L1']=np.loadtxt('tmdplots2/f_E288_400_Q0=11.5_l1.dat', skiprows=0)
L16=f['E288_400 Q=12.5 L1']=np.loadtxt('tmdplots2/f_E288_400_Q0=12.5_l1.dat', skiprows=0)
L17=f['E288_400 Q=13.5 L1']=np.loadtxt('tmdplots2/f_E288_400_Q0=13.5_l1.dat', skiprows=0)

L21=f['E288_400 Q=5.5 L2']=np.loadtxt('tmdplots2/f_E288_400_Q0=5.5_l2.dat', skiprows=0)
L22=f['E288_400 Q=6.5 L2']=np.loadtxt('tmdplots2/f_E288_400_Q0=6.5_l2.dat', skiprows=0)
L23=f['E288_400 Q=7.5 L2']=np.loadtxt('tmdplots2/f_E288_400_Q0=7.5_l2.dat', skiprows=0)
L24=f['E288_400 Q=8.5 L2']=np.loadtxt('tmdplots2/f_E288_400_Q0=8.5_l2.dat', skiprows=0)
L25=f['E288_400 Q=11.5 L2']=np.loadtxt('tmdplots2/f_E288_400_Q0=11.5_l2.dat', skiprows=0)
L26=f['E288_400 Q=12.5 L2']=np.loadtxt('tmdplots2/f_E288_400_Q0=12.5_l2.dat', skiprows=0)
L27=f['E288_400 Q=13.5 L2']=np.loadtxt('tmdplots2/f_E288_400_Q0=13.5_l2.dat', skiprows=0)

# %%
A0E=f['E288_400 evol b=0.5 Q0=13.5 L0']=np.loadtxt('tmdplots2/evol_E288_400_b=0.5_Q0=13.5_l0.dat', skiprows=0)
A1E=f['E288_400 evol b=0.5 Q0=13.5 L1']=np.loadtxt('tmdplots2/evol_E288_400_b=0.5_Q0=13.5_l1.dat', skiprows=0)
A2E=f['E288_400 evol b=0.5 Q0=13.5 L2']=np.loadtxt('tmdplots2/evol_E288_400_b=0.5_Q0=13.5_l2.dat', skiprows=0)
B0E=f['E288_400 evol b=1.0 Q0=13.5 L0']=np.loadtxt('tmdplots2/evol_E288_400_b=1.0_Q0=13.5_l0.dat', skiprows=0)
B1E=f['E288_400 evol b=1.0 Q0=13.5 L1']=np.loadtxt('tmdplots2/evol_E288_400_b=1.0_Q0=13.5_l1.dat', skiprows=0)
B2E=f['E288_400 evol b=1.0 Q0=13.5 L2']=np.loadtxt('tmdplots2/evol_E288_400_b=1.0_Q0=13.5_l2.dat', skiprows=0)

# %%
X=np.array([5.5, 6.5, 7.5, 8.5, 11.5, 12.5, 13.5])

Ab=50-1
AY0=np.array([L01[Ab,1], L02[Ab, 1], L03[Ab, 1], L04[Ab, 1], L05[Ab, 1], L06[Ab, 1], L07[Ab, 1]])
AY1=np.array([L11[Ab,1], L12[Ab, 1], L13[Ab, 1], L14[Ab, 1], L15[Ab, 1], L16[Ab, 1], L17[Ab, 1]])
AY2=np.array([L21[Ab,1], L22[Ab, 1], L23[Ab, 1], L24[Ab, 1], L25[Ab, 1], L26[Ab, 1], L27[Ab, 1]])
AE0=np.array([L01[Ab,2], L02[Ab, 2], L03[Ab, 2], L04[Ab, 2], L05[Ab, 2], L06[Ab, 2], L07[Ab, 2]])
AE1=np.array([L11[Ab,2], L12[Ab, 2], L13[Ab, 2], L14[Ab, 2], L15[Ab, 2], L16[Ab, 2], L17[Ab, 2]])
AE2=np.array([L21[Ab,2], L22[Ab, 2], L23[Ab, 2], L24[Ab, 2], L25[Ab, 2], L26[Ab, 2], L27[Ab, 2]])

Bb=100-1
BY0=np.array([L01[Bb,1], L02[Bb, 1], L03[Bb, 1], L04[Bb, 1], L05[Bb, 1], L06[Bb, 1], L07[Bb, 1]])
BY1=np.array([L11[Bb,1], L12[Bb, 1], L13[Bb, 1], L14[Bb, 1], L15[Bb, 1], L16[Bb, 1], L17[Bb, 1]])
BY2=np.array([L21[Bb,1], L22[Bb, 1], L23[Bb, 1], L24[Bb, 1], L25[Bb, 1], L26[Bb, 1], L27[Bb, 1]])
BE0=np.array([L01[Bb,2], L02[Bb, 2], L03[Bb, 2], L04[Bb, 2], L05[Bb, 2], L06[Bb, 2], L07[Bb, 2]])
BE1=np.array([L11[Bb,2], L12[Bb, 2], L13[Bb, 2], L14[Bb, 2], L15[Bb, 2], L16[Bb, 2], L17[Bb, 2]])
BE2=np.array([L21[Bb,2], L22[Bb, 2], L23[Bb, 2], L24[Bb, 2], L25[Bb, 2], L26[Bb, 2], L27[Bb, 2]])

# %%
nrows,ncols=1,3
fig=py.figure(figsize=(ncols*7,nrows*7))

ax=fig.add_subplot(nrows,ncols,1)
#
ax.errorbar(X, np.log(AY0), yerr=AE0/AY0, color='blue', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.errorbar(X, np.log(AY1), yerr=AE1/AY1, color='red', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.errorbar(X, np.log(AY2), yerr=AE2/AY2, color='orange', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.plot(A0E[:,0], np.log(A0E[:,1]), color='blue', alpha=0.7, linestyle='-', linewidth=1)
ax.plot(A1E[:,0], np.log(A1E[:,1]), color='red', alpha=0.7, linestyle='-', linewidth=1)
ax.plot(A2E[:,0], np.log(A2E[:,1]), color='orange', alpha=0.7, linestyle='-', linewidth=1)
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.set_xlabel(r'$\rm Q~(GeV)$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$\log F$', fontsize=25, labelpad=15)
ax.set_xlim(5,15)
ax.set_ylim(-1,1)
ax.set_xscale('log')
ax.text(0.1,0.9,r'$x=0.4$',horizontalalignment='left',transform=ax.transAxes,size=20)
ax.text(0.1,0.8,r'$b=0.5\,\rm GeV^{-1}$',horizontalalignment='left',transform=ax.transAxes,size=20)

ax=fig.add_subplot(nrows,ncols,2)
#
ax.errorbar(X, np.log(BY0), yerr=AE0/AY0, color='blue', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.errorbar(X, np.log(BY1), yerr=AE1/AY1, color='red', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.errorbar(X, np.log(BY2), yerr=AE2/AY2, color='orange', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.plot(B0E[:,0], np.log(B0E[:,1]), color='blue', alpha=0.7, linestyle='-', linewidth=1)
ax.plot(B1E[:,0], np.log(B1E[:,1]), color='red', alpha=0.7, linestyle='-', linewidth=1)
ax.plot(B2E[:,0], np.log(B2E[:,1]), color='orange', alpha=0.7, linestyle='-', linewidth=1)
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.set_xlabel(r'$\rm Q~(GeV)$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$\log F$', fontsize=25, labelpad=15)
ax.set_xlim(5,15)
ax.set_ylim(-1,1)
ax.set_xscale('log')
ax.text(0.1,0.9,r'$x=0.4$',horizontalalignment='left',transform=ax.transAxes,size=20)
ax.text(0.1,0.8,r'$b=1.0\,\rm GeV^{-1}$',horizontalalignment='left',transform=ax.transAxes,size=20)

ax=fig.add_subplot(nrows,ncols,3)
ax.plot(L11[:,0], L11[:,0]*L11[:,1]**2, color='black', linewidth=2, linestyle='-')
ax.plot(L12[:,0], L12[:,0]*L12[:,1]**2, color='blue', linewidth=2, dashes=[20,5])
ax.plot(L13[:,0], L13[:,0]*L13[:,1]**2, color='red', linewidth=2, dashes=[10,5])
ax.plot(L14[:,0], L14[:,0]*L14[:,1]**2, color='forestgreen', linewidth=2, dashes=[10,5,1,5])
ax.plot(L15[:,0], L15[:,0]*L15[:,1]**2, color='orange', linewidth=2, linestyle=':')
ax.plot(L16[:,0], L16[:,0]*L16[:,1]**2, color='magenta', linewidth=2, dashes=[5,3,1,3])
ax.plot(L17[:,0], L17[:,0]*L17[:,1]**2, color='cyan', linewidth=2, dashes=[3,1,1,1])
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.set_xlabel(r'$b~(\rm GeV^{-1})$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$bF^2$', fontsize=25, labelpad=15)
ax.set_xlim(0,3)
ax.set_ylim(0,1.5)
ax.text(0.1,0.9,r'$x=0.4$',horizontalalignment='left',transform=ax.transAxes,size=20)

fig.tight_layout()
#fig.savefig("tmp.png")

# %% [markdown]
# ### E605

# %%
L01=f['E605 Q=7.5 L0']=np.loadtxt('tmdplots2/f_E605_Q0=7.5_l0.dat', skiprows=0)
L02=f['E605 Q=8.5 L0']=np.loadtxt('tmdplots2/f_E605_Q0=8.5_l0.dat', skiprows=0)
L03=f['E605 Q=11.0 L0']=np.loadtxt('tmdplots2/f_E605_Q0=11.0_l0.dat', skiprows=0)
L04=f['E605 Q=12.5 L0']=np.loadtxt('tmdplots2/f_E605_Q0=12.5_l0.dat', skiprows=0)
L05=f['E605 Q=15.8 L0']=np.loadtxt('tmdplots2/f_E605_Q0=15.8_l0.dat', skiprows=0)

L11=f['E605 Q=7.5 L0']=np.loadtxt('tmdplots2/f_E605_Q0=7.5_l1.dat', skiprows=0)
L12=f['E605 Q=8.5 L0']=np.loadtxt('tmdplots2/f_E605_Q0=8.5_l1.dat', skiprows=0)
L13=f['E605 Q=11.0 L0']=np.loadtxt('tmdplots2/f_E605_Q0=11.0_l1.dat', skiprows=0)
L14=f['E605 Q=12.5 L0']=np.loadtxt('tmdplots2/f_E605_Q0=12.5_l1.dat', skiprows=0)
L15=f['E605 Q=15.8 L0']=np.loadtxt('tmdplots2/f_E605_Q0=15.8_l1.dat', skiprows=0)

L21=f['E605 Q=7.5 L0']=np.loadtxt('tmdplots2/f_E605_Q0=7.5_l2.dat', skiprows=0)
L22=f['E605 Q=8.5 L0']=np.loadtxt('tmdplots2/f_E605_Q0=8.5_l2.dat', skiprows=0)
L23=f['E605 Q=11.0 L0']=np.loadtxt('tmdplots2/f_E605_Q0=11.0_l2.dat', skiprows=0)
L24=f['E605 Q=12.5 L0']=np.loadtxt('tmdplots2/f_E605_Q0=12.5_l2.dat', skiprows=0)
L25=f['E605 Q=15.8 L0']=np.loadtxt('tmdplots2/f_E605_Q0=15.8_l2.dat', skiprows=0)

# %%
A0E=f['E605 evol b=0.5 Q0=15.8 L0']=np.loadtxt('tmdplots2/evol_E605_b=0.5_Q0=15.8_l0.dat', skiprows=0)
A1E=f['E605 evol b=0.5 Q0=15.8 L1']=np.loadtxt('tmdplots2/evol_E605_b=0.5_Q0=15.8_l1.dat', skiprows=0)
A2E=f['E605 evol b=0.5 Q0=15.8 L2']=np.loadtxt('tmdplots2/evol_E605_b=0.5_Q0=15.8_l2.dat', skiprows=0)
B0E=f['E605 evol b=1.0 Q0=15.8 L0']=np.loadtxt('tmdplots2/evol_E605_b=1.0_Q0=15.8_l0.dat', skiprows=0)
B1E=f['E605 evol b=1.0 Q0=15.8 L1']=np.loadtxt('tmdplots2/evol_E605_b=1.0_Q0=15.8_l1.dat', skiprows=0)
B2E=f['E605 evol b=1.0 Q0=15.8 L2']=np.loadtxt('tmdplots2/evol_E605_b=1.0_Q0=15.8_l2.dat', skiprows=0)

# %%
X=np.array([7.5, 8.5, 11.0, 12.5, 15.8])

Ab=50-1
AY0=np.array([L01[Ab,1], L02[Ab, 1], L03[Ab, 1], L04[Ab, 1], L05[Ab, 1]])
AY1=np.array([L11[Ab,1], L12[Ab, 1], L13[Ab, 1], L14[Ab, 1], L15[Ab, 1]])
AY2=np.array([L21[Ab,1], L22[Ab, 1], L23[Ab, 1], L24[Ab, 1], L25[Ab, 1]])
AE0=np.array([L01[Ab,2], L02[Ab, 2], L03[Ab, 2], L04[Ab, 2], L05[Ab, 2]])
AE1=np.array([L11[Ab,2], L12[Ab, 2], L13[Ab, 2], L14[Ab, 2], L15[Ab, 2]])
AE2=np.array([L21[Ab,2], L22[Ab, 2], L23[Ab, 2], L24[Ab, 2], L25[Ab, 2]])

Bb=100-1
BY0=np.array([L01[Bb,1], L02[Bb, 1], L03[Bb, 1], L04[Bb, 1], L05[Bb, 1]])
BY1=np.array([L11[Bb,1], L12[Bb, 1], L13[Bb, 1], L14[Bb, 1], L15[Bb, 1]])
BY2=np.array([L21[Bb,1], L22[Bb, 1], L23[Bb, 1], L24[Bb, 1], L25[Bb, 1]])
BE0=np.array([L01[Bb,2], L02[Bb, 2], L03[Bb, 2], L04[Bb, 2], L05[Bb, 2]])
BE1=np.array([L11[Bb,2], L12[Bb, 2], L13[Bb, 2], L14[Bb, 2], L15[Bb, 2]])
BE2=np.array([L21[Bb,2], L22[Bb, 2], L23[Bb, 2], L24[Bb, 2], L25[Bb, 2]])

# %%
nrows,ncols=1,3
fig=py.figure(figsize=(ncols*7,nrows*7))

ax=fig.add_subplot(nrows,ncols,1)
#
ax.errorbar(X, np.log(AY0), yerr=AE0/AY0, color='blue', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.errorbar(X, np.log(AY1), yerr=AE1/AY1, color='red', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.errorbar(X, np.log(AY2), yerr=AE2/AY2, color='orange', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.plot(A0E[:,0], np.log(A0E[:,1]), color='blue', alpha=0.7, linestyle='-', linewidth=1)
ax.plot(A1E[:,0], np.log(A1E[:,1]), color='red', alpha=0.7, linestyle='-', linewidth=1)
ax.plot(A2E[:,0], np.log(A2E[:,1]), color='orange', alpha=0.7, linestyle='-', linewidth=1)
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.set_xlabel(r'$\rm Q~(GeV)$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$\log F$', fontsize=25, labelpad=15)
ax.set_xlim(7,18)
ax.set_ylim(-1,1)
ax.set_xscale('log')
ax.text(0.1,0.9,r'$x=0.4$',horizontalalignment='left',transform=ax.transAxes,size=20)
ax.text(0.1,0.8,r'$b=0.5\,\rm GeV^{-1}$',horizontalalignment='left',transform=ax.transAxes,size=20)

ax=fig.add_subplot(nrows,ncols,2)
#
ax.errorbar(X, np.log(BY0), yerr=AE0/AY0, color='blue', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.errorbar(X, np.log(BY1), yerr=AE1/AY1, color='red', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.errorbar(X, np.log(BY2), yerr=AE2/AY2, color='orange', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.plot(B0E[:,0], np.log(B0E[:,1]), color='blue', alpha=0.7, linestyle='-', linewidth=1)
ax.plot(B1E[:,0], np.log(B1E[:,1]), color='red', alpha=0.7, linestyle='-', linewidth=1)
ax.plot(B2E[:,0], np.log(B2E[:,1]), color='orange', alpha=0.7, linestyle='-', linewidth=1)
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.set_xlabel(r'$\rm Q~(GeV)$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$\log F$', fontsize=25, labelpad=15)
ax.set_xlim(7,18)
ax.set_ylim(-1,1)
ax.set_xscale('log')
ax.text(0.1,0.9,r'$x=0.4$',horizontalalignment='left',transform=ax.transAxes,size=20)
ax.text(0.1,0.8,r'$b=1.0\,\rm GeV^{-1}$',horizontalalignment='left',transform=ax.transAxes,size=20)

ax=fig.add_subplot(nrows,ncols,3)
ax.plot(L11[:,0], L11[:,0]*L11[:,1]**2, color='black', linewidth=2, linestyle='-')
ax.plot(L12[:,0], L12[:,0]*L12[:,1]**2, color='blue', linewidth=2, dashes=[20,5])
ax.plot(L13[:,0], L13[:,0]*L13[:,1]**2, color='red', linewidth=2, dashes=[10,5])
ax.plot(L14[:,0], L14[:,0]*L14[:,1]**2, color='forestgreen', linewidth=2, dashes=[10,5,1,5])
ax.plot(L15[:,0], L15[:,0]*L15[:,1]**2, color='orange', linewidth=2, linestyle=':')
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.set_xlabel(r'$b~(\rm GeV^{-1})$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$bF^2$', fontsize=25, labelpad=15)
ax.set_xlim(0,3)
ax.set_ylim(0,1)
ax.text(0.1,0.9,r'$x=0.4$',horizontalalignment='left',transform=ax.transAxes,size=20)

fig.tight_layout()
#fig.savefig("tmp.png")

# %% [markdown]
# ### E772

# %%
L01=f['E772 Q=5.5 L0']=np.loadtxt('tmdplots2/f_E772_Q0=5.5_l0.dat', skiprows=0)
L02=f['E772 Q=6.5 L0']=np.loadtxt('tmdplots2/f_E772_Q0=6.5_l0.dat', skiprows=0)
L03=f['E772 Q=7.5 L0']=np.loadtxt('tmdplots2/f_E772_Q0=7.5_l0.dat', skiprows=0)
L04=f['E772 Q=8.5 L0']=np.loadtxt('tmdplots2/f_E772_Q0=8.5_l0.dat', skiprows=0)
L05=f['E772 Q=11.5 L0']=np.loadtxt('tmdplots2/f_E772_Q0=11.5_l0.dat', skiprows=0)
L06=f['E772 Q=12.5 L0']=np.loadtxt('tmdplots2/f_E772_Q0=12.5_l0.dat', skiprows=0)

L11=f['E772 Q=5.5 L1']=np.loadtxt('tmdplots2/f_E772_Q0=5.5_l1.dat', skiprows=0)
L12=f['E772 Q=6.5 L1']=np.loadtxt('tmdplots2/f_E772_Q0=6.5_l1.dat', skiprows=0)
L13=f['E772 Q=7.5 L1']=np.loadtxt('tmdplots2/f_E772_Q0=7.5_l1.dat', skiprows=0)
L14=f['E772 Q=8.5 L1']=np.loadtxt('tmdplots2/f_E772_Q0=8.5_l1.dat', skiprows=0)
L15=f['E772 Q=11.5 L1']=np.loadtxt('tmdplots2/f_E772_Q0=11.5_l1.dat', skiprows=0)
L16=f['E772 Q=12.5 L1']=np.loadtxt('tmdplots2/f_E772_Q0=12.5_l1.dat', skiprows=0)

L21=f['E772 Q=5.5 L2']=np.loadtxt('tmdplots2/f_E772_Q0=5.5_l2.dat', skiprows=0)
L22=f['E772 Q=6.5 L2']=np.loadtxt('tmdplots2/f_E772_Q0=6.5_l2.dat', skiprows=0)
L23=f['E772 Q=7.5 L2']=np.loadtxt('tmdplots2/f_E772_Q0=7.5_l2.dat', skiprows=0)
L24=f['E772 Q=8.5 L2']=np.loadtxt('tmdplots2/f_E772_Q0=8.5_l2.dat', skiprows=0)
L25=f['E772 Q=11.5 L2']=np.loadtxt('tmdplots2/f_E772_Q0=11.5_l2.dat', skiprows=0)
L26=f['E772 Q=12.5 L2']=np.loadtxt('tmdplots2/f_E772_Q0=12.5_l2.dat', skiprows=0)

# %%
A0E=f['E772 evol b=0.5 Q0=12.5 L0']=np.loadtxt('tmdplots2/evol_E772_b=0.5_Q0=12.5_l0.dat', skiprows=0)
A1E=f['E772 evol b=0.5 Q0=12.5 L1']=np.loadtxt('tmdplots2/evol_E772_b=0.5_Q0=12.5_l1.dat', skiprows=0)
A2E=f['E772 evol b=0.5 Q0=12.5 L2']=np.loadtxt('tmdplots2/evol_E772_b=0.5_Q0=12.5_l2.dat', skiprows=0)
B0E=f['E772 evol b=1.0 Q0=12.5 L0']=np.loadtxt('tmdplots2/evol_E772_b=1.0_Q0=12.5_l0.dat', skiprows=0)
B1E=f['E772 evol b=1.0 Q0=12.5 L1']=np.loadtxt('tmdplots2/evol_E772_b=1.0_Q0=12.5_l1.dat', skiprows=0)
B2E=f['E772 evol b=1.0 Q0=12.5 L2']=np.loadtxt('tmdplots2/evol_E772_b=1.0_Q0=12.5_l2.dat', skiprows=0)

# %%
X=np.array([5.5, 6.5, 7.5, 8.5, 11.5, 12.5])

Ab=50-1
AY0=np.array([L01[Ab,1], L02[Ab, 1], L03[Ab, 1], L04[Ab, 1], L05[Ab, 1], L06[Ab, 1]])
AY1=np.array([L11[Ab,1], L12[Ab, 1], L13[Ab, 1], L14[Ab, 1], L15[Ab, 1], L16[Ab, 1]])
AY2=np.array([L21[Ab,1], L22[Ab, 1], L23[Ab, 1], L24[Ab, 1], L25[Ab, 1], L26[Ab, 1]])
AE0=np.array([L01[Ab,2], L02[Ab, 2], L03[Ab, 2], L04[Ab, 2], L05[Ab, 2], L06[Ab, 2]])
AE1=np.array([L11[Ab,2], L12[Ab, 2], L13[Ab, 2], L14[Ab, 2], L15[Ab, 2], L16[Ab, 2]])
AE2=np.array([L21[Ab,2], L22[Ab, 2], L23[Ab, 2], L24[Ab, 2], L25[Ab, 2], L26[Ab, 2]])

Bb=100-1
BY0=np.array([L01[Bb,1], L02[Bb, 1], L03[Bb, 1], L04[Bb, 1], L05[Bb, 1], L06[Bb, 1]])
BY1=np.array([L11[Bb,1], L12[Bb, 1], L13[Bb, 1], L14[Bb, 1], L15[Bb, 1], L16[Bb, 1]])
BY2=np.array([L21[Bb,1], L22[Bb, 1], L23[Bb, 1], L24[Bb, 1], L25[Bb, 1], L26[Bb, 1]])
BE0=np.array([L01[Bb,2], L02[Bb, 2], L03[Bb, 2], L04[Bb, 2], L05[Bb, 2], L06[Bb, 2]])
BE1=np.array([L11[Bb,2], L12[Bb, 2], L13[Bb, 2], L14[Bb, 2], L15[Bb, 2], L16[Bb, 2]])
BE2=np.array([L21[Bb,2], L22[Bb, 2], L23[Bb, 2], L24[Bb, 2], L25[Bb, 2], L26[Bb, 2]])

# %%
nrows,ncols=1,3
fig=py.figure(figsize=(ncols*7,nrows*7))

ax=fig.add_subplot(nrows,ncols,1)
#
ax.errorbar(X, np.log(AY0), yerr=AE0/AY0, color='blue', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.errorbar(X, np.log(AY1), yerr=AE1/AY1, color='red', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.errorbar(X, np.log(AY2), yerr=AE2/AY2, color='orange', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.plot(A0E[:,0], np.log(A0E[:,1]), color='blue', alpha=0.7, linestyle='-', linewidth=1)
ax.plot(A1E[:,0], np.log(A1E[:,1]), color='red', alpha=0.7, linestyle='-', linewidth=1)
ax.plot(A2E[:,0], np.log(A2E[:,1]), color='orange', alpha=0.7, linestyle='-', linewidth=1)
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.set_xlabel(r'$\rm Q~(GeV)$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$\log F$', fontsize=25, labelpad=15)
ax.set_xlim(5,15)
ax.set_ylim(-1,1)
ax.set_xscale('log')
ax.text(0.1,0.9,r'$x=0.4$',horizontalalignment='left',transform=ax.transAxes,size=20)
ax.text(0.1,0.8,r'$b=0.5\,\rm GeV^{-1}$',horizontalalignment='left',transform=ax.transAxes,size=20)

ax=fig.add_subplot(nrows,ncols,2)
#
ax.errorbar(X, np.log(BY0), yerr=AE0/AY0, color='blue', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.errorbar(X, np.log(BY1), yerr=AE1/AY1, color='red', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.errorbar(X, np.log(BY2), yerr=AE2/AY2, color='orange', alpha=0.7, marker='.', linestyle='none', markersize=15, linewidth=0.5)
ax.plot(B0E[:,0], np.log(B0E[:,1]), color='blue', alpha=0.7, linestyle='-', linewidth=1)
ax.plot(B1E[:,0], np.log(B1E[:,1]), color='red', alpha=0.7, linestyle='-', linewidth=1)
ax.plot(B2E[:,0], np.log(B2E[:,1]), color='orange', alpha=0.7, linestyle='-', linewidth=1)
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.set_xlabel(r'$\rm Q~(GeV)$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$\log F$', fontsize=25, labelpad=15)
ax.set_xlim(5,15)
ax.set_ylim(-1,0.5)
ax.set_xscale('log')
ax.text(0.1,0.9,r'$x=0.4$',horizontalalignment='left',transform=ax.transAxes,size=20)
ax.text(0.1,0.8,r'$b=1.0\,\rm GeV^{-1}$',horizontalalignment='left',transform=ax.transAxes,size=20)

ax=fig.add_subplot(nrows,ncols,3)
ax.plot(L11[:,0], L11[:,0]*L11[:,1]**2, color='black', linewidth=2, linestyle='-')
ax.plot(L12[:,0], L12[:,0]*L12[:,1]**2, color='blue', linewidth=2, dashes=[20,5])
ax.plot(L13[:,0], L13[:,0]*L13[:,1]**2, color='red', linewidth=2, dashes=[10,5])
ax.plot(L14[:,0], L14[:,0]*L14[:,1]**2, color='forestgreen', linewidth=2, dashes=[10,5,1,5])
ax.plot(L15[:,0], L15[:,0]*L15[:,1]**2, color='orange', linewidth=2, linestyle=':')
ax.plot(L16[:,0], L16[:,0]*L16[:,1]**2, color='magenta', linewidth=2, dashes=[5,3,1,3])
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.set_xlabel(r'$b~(\rm GeV^{-1})$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$bF^2$', fontsize=25, labelpad=15)
ax.set_xlim(0,3)
ax.set_ylim(0,1.5)
ax.text(0.1,0.9,r'$x=0.4$',horizontalalignment='left',transform=ax.transAxes,size=20)

fig.tight_layout()
#fig.savefig("tmp.png")

# %% [markdown]
# ### D0 Run I

# %% [markdown]
# ### D0 Run II

# %% [markdown]
# ### CDF Run I

# %% [markdown]
# ### CDF Run II
