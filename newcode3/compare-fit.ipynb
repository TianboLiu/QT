# %% [markdown]
# # Compare

# %%
import sys,os
import numpy as np
import pandas as pd
import pylab as py
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import rc
from matplotlib.colors import LogNorm
from matplotlib.font_manager import FontProperties
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text',usetex=True)
# %matplotlib inline
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
font0=FontProperties()
font0.set_family('sans-serif')
font0.set_style('italic')
font0.set_variant('normal')

# %% [markdown]
# ## qTmax

# %%
data={}
curve={}

# %% [markdown]
# ### E288-200

# %%
D1=data['E288_200 Q=4.5']=np.loadtxt('plots/data_E288_200_Q=4.5.dat', skiprows=0)
D2=data['E288_200 Q=5.5']=np.loadtxt('plots/data_E288_200_Q=5.5.dat', skiprows=0)
D3=data['E288_200 Q=6.5']=np.loadtxt('plots/data_E288_200_Q=6.5.dat', skiprows=0)
D4=data['E288_200 Q=7.5']=np.loadtxt('plots/data_E288_200_Q=7.5.dat', skiprows=0)
D5=data['E288_200 Q=8.5']=np.loadtxt('plots/data_E288_200_Q=8.5.dat', skiprows=0)

C10=curve['E288_200 Q=4.5 l0']=np.loadtxt('plots/curve_E288_200_Q=4.5_l0.dat', skiprows=0)
C11=curve['E288_200 Q=4.5 l1']=np.loadtxt('plots/curve_E288_200_Q=4.5_l1.dat', skiprows=0)
C12=curve['E288_200 Q=4.5 l2']=np.loadtxt('plots/curve_E288_200_Q=4.5_l2.dat', skiprows=0)
C20=curve['E288_200 Q=5.5 l0']=np.loadtxt('plots/curve_E288_200_Q=5.5_l0.dat', skiprows=0)
C21=curve['E288_200 Q=5.5 l1']=np.loadtxt('plots/curve_E288_200_Q=5.5_l1.dat', skiprows=0)
C22=curve['E288_200 Q=5.5 l2']=np.loadtxt('plots/curve_E288_200_Q=5.5_l2.dat', skiprows=0)
C30=curve['E288_200 Q=6.5 l0']=np.loadtxt('plots/curve_E288_200_Q=6.5_l0.dat', skiprows=0)
C31=curve['E288_200 Q=6.5 l1']=np.loadtxt('plots/curve_E288_200_Q=6.5_l1.dat', skiprows=0)
C32=curve['E288_200 Q=6.5 l2']=np.loadtxt('plots/curve_E288_200_Q=6.5_l2.dat', skiprows=0)
C40=curve['E288_200 Q=7.5 l0']=np.loadtxt('plots/curve_E288_200_Q=7.5_l0.dat', skiprows=0)
C41=curve['E288_200 Q=7.5 l1']=np.loadtxt('plots/curve_E288_200_Q=7.5_l1.dat', skiprows=0)
C42=curve['E288_200 Q=7.5 l2']=np.loadtxt('plots/curve_E288_200_Q=7.5_l2.dat', skiprows=0)
C50=curve['E288_200 Q=8.5 l0']=np.loadtxt('plots/curve_E288_200_Q=8.5_l0.dat', skiprows=0)
C51=curve['E288_200 Q=8.5 l1']=np.loadtxt('plots/curve_E288_200_Q=8.5_l1.dat', skiprows=0)
C52=curve['E288_200 Q=8.5 l2']=np.loadtxt('plots/curve_E288_200_Q=8.5_l2.dat', skiprows=0)

# %%
nrows,ncols=1,1

fig=py.figure(figsize=(ncols*7,nrows*7))
ax=fig.add_subplot(nrows,ncols,1)
#
ax.errorbar(D1[:,0], D1[:,1], yerr=D1[:,2], marker='o', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='black')
ax.plot(C10[:,0], C10[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C11[:,0], C11[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C12[:,0], C12[:,1], linestyle='-.', color='green', linewidth=1)
#
ax.errorbar(D2[:,0], D2[:,1], yerr=D2[:,2], marker='^', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='magenta')
ax.plot(C20[:,0], C20[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C21[:,0], C21[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C22[:,0], C22[:,1], linestyle='-.', color='green', linewidth=1)
#
ax.errorbar(D3[:,0], D3[:,1], yerr=D3[:,2], marker='s', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='purple')
ax.plot(C30[:,0], C30[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C31[:,0], C31[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C32[:,0], C32[:,1], linestyle='-.', color='green', linewidth=1)
#
ax.errorbar(D4[:,0], D4[:,1], yerr=D4[:,2], marker='v', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='turquoise')
ax.plot(C40[:,0], C40[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C41[:,0], C41[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C42[:,0], C42[:,1], linestyle='-.', color='green', linewidth=1)
#
ax.errorbar(D5[:,0], D5[:,1], yerr=D5[:,2], marker='D', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='orange')
ax.plot(C50[:,0], C50[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C51[:,0], C51[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C52[:,0], C52[:,1], linestyle='-.', color='green', linewidth=1)
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.tick_params(axis='z', which='major', direction='in', labelsize=25, pad=5)
ax.set_xlabel(r'$q_T~\rm (GeV)$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$Ed\sigma/d^3q~\rm (GeV^{-4})$', fontsize=25, labelpad=15)
ax.set_yscale('log')
ax.set_xlim(0,5)
ax.set_ylim(5e-13,5e-8)

fig.tight_layout()
fig.savefig("plots/fig_E288_200.pdf")

# %% [markdown]
# ### E288-300

# %%
D1=data['E288_300 Q=4.5']=np.loadtxt('plots/data_E288_300_Q=4.5.dat', skiprows=0)
D2=data['E288_300 Q=5.5']=np.loadtxt('plots/data_E288_300_Q=5.5.dat', skiprows=0)
D3=data['E288_300 Q=6.5']=np.loadtxt('plots/data_E288_300_Q=6.5.dat', skiprows=0)
D4=data['E288_300 Q=7.5']=np.loadtxt('plots/data_E288_300_Q=7.5.dat', skiprows=0)
D5=data['E288_300 Q=8.5']=np.loadtxt('plots/data_E288_300_Q=8.5.dat', skiprows=0)

C10=curve['E288_300 Q=4.5 l0']=np.loadtxt('plots/curve_E288_300_Q=4.5_l0.dat', skiprows=0)
C11=curve['E288_300 Q=4.5 l1']=np.loadtxt('plots/curve_E288_300_Q=4.5_l1.dat', skiprows=0)
C12=curve['E288_300 Q=4.5 l2']=np.loadtxt('plots/curve_E288_300_Q=4.5_l2.dat', skiprows=0)
C20=curve['E288_300 Q=5.5 l0']=np.loadtxt('plots/curve_E288_300_Q=5.5_l0.dat', skiprows=0)
C21=curve['E288_300 Q=5.5 l1']=np.loadtxt('plots/curve_E288_300_Q=5.5_l1.dat', skiprows=0)
C22=curve['E288_300 Q=5.5 l2']=np.loadtxt('plots/curve_E288_300_Q=5.5_l2.dat', skiprows=0)
C30=curve['E288_300 Q=6.5 l0']=np.loadtxt('plots/curve_E288_300_Q=6.5_l0.dat', skiprows=0)
C31=curve['E288_300 Q=6.5 l1']=np.loadtxt('plots/curve_E288_300_Q=6.5_l1.dat', skiprows=0)
C32=curve['E288_300 Q=6.5 l2']=np.loadtxt('plots/curve_E288_300_Q=6.5_l2.dat', skiprows=0)
C40=curve['E288_300 Q=7.5 l0']=np.loadtxt('plots/curve_E288_300_Q=7.5_l0.dat', skiprows=0)
C41=curve['E288_300 Q=7.5 l1']=np.loadtxt('plots/curve_E288_300_Q=7.5_l1.dat', skiprows=0)
C42=curve['E288_300 Q=7.5 l2']=np.loadtxt('plots/curve_E288_300_Q=7.5_l2.dat', skiprows=0)
C50=curve['E288_300 Q=8.5 l0']=np.loadtxt('plots/curve_E288_300_Q=8.5_l0.dat', skiprows=0)
C51=curve['E288_300 Q=8.5 l1']=np.loadtxt('plots/curve_E288_300_Q=8.5_l1.dat', skiprows=0)
C52=curve['E288_300 Q=8.5 l2']=np.loadtxt('plots/curve_E288_300_Q=8.5_l2.dat', skiprows=0)

# %%
nrows,ncols=1,1

fig=py.figure(figsize=(ncols*7,nrows*7))
ax=fig.add_subplot(nrows,ncols,1)
#
ax.errorbar(D1[:,0], D1[:,1], yerr=D1[:,2], marker='o', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='black')
ax.plot(C10[:,0], C10[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C11[:,0], C11[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C12[:,0], C12[:,1], linestyle='-.', color='green', linewidth=1)
#
ax.errorbar(D2[:,0], D2[:,1], yerr=D2[:,2], marker='^', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='magenta')
ax.plot(C20[:,0], C20[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C21[:,0], C21[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C22[:,0], C22[:,1], linestyle='-.', color='green', linewidth=1)
#
ax.errorbar(D3[:,0], D3[:,1], yerr=D3[:,2], marker='s', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='purple')
ax.plot(C30[:,0], C30[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C31[:,0], C31[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C32[:,0], C32[:,1], linestyle='-.', color='green', linewidth=1)
#
ax.errorbar(D4[:,0], D4[:,1], yerr=D4[:,2], marker='v', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='turquoise')
ax.plot(C40[:,0], C40[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C41[:,0], C41[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C42[:,0], C42[:,1], linestyle='-.', color='green', linewidth=1)
#
ax.errorbar(D5[:,0], D5[:,1], yerr=D5[:,2], marker='D', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='orange')
ax.plot(C50[:,0], C50[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C51[:,0], C51[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C52[:,0], C52[:,1], linestyle='-.', color='green', linewidth=1)
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.tick_params(axis='z', which='major', direction='in', labelsize=25, pad=5)
ax.set_xlabel(r'$q_T~\rm (GeV)$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$Ed\sigma/d^3q~\rm (GeV^{-4})$', fontsize=25, labelpad=15)
ax.set_yscale('log')
ax.set_xlim(0,5)
ax.set_ylim(5e-13,5e-8)

fig.tight_layout()
fig.savefig("plots/fig_E288_300.pdf")

# %% [markdown]
# ### E288-400

# %%
D1=data['E288_400 Q=5.5']=np.loadtxt('plots/data_E288_400_Q=5.5.dat', skiprows=0)
D2=data['E288_400 Q=6.5']=np.loadtxt('plots/data_E288_400_Q=6.5.dat', skiprows=0)
D3=data['E288_400 Q=7.5']=np.loadtxt('plots/data_E288_400_Q=7.5.dat', skiprows=0)
D4=data['E288_400 Q=8.5']=np.loadtxt('plots/data_E288_400_Q=8.5.dat', skiprows=0)
D5=data['E288_400 Q=11.5']=np.loadtxt('plots/data_E288_400_Q=11.5.dat', skiprows=0)
D6=data['E288_400 Q=12.5']=np.loadtxt('plots/data_E288_400_Q=12.5.dat', skiprows=0)
D7=data['E288_400 Q=13.5']=np.loadtxt('plots/data_E288_400_Q=13.5.dat', skiprows=0)


C10=curve['E288_400 Q=5.5 l0']=np.loadtxt('plots/curve_E288_400_Q=5.5_l0.dat', skiprows=0)
C11=curve['E288_400 Q=5.5 l1']=np.loadtxt('plots/curve_E288_400_Q=5.5_l1.dat', skiprows=0)
C12=curve['E288_400 Q=5.5 l2']=np.loadtxt('plots/curve_E288_400_Q=5.5_l2.dat', skiprows=0)
C20=curve['E288_400 Q=6.5 l0']=np.loadtxt('plots/curve_E288_400_Q=6.5_l0.dat', skiprows=0)
C21=curve['E288_400 Q=6.5 l1']=np.loadtxt('plots/curve_E288_400_Q=6.5_l1.dat', skiprows=0)
C22=curve['E288_400 Q=6.5 l2']=np.loadtxt('plots/curve_E288_400_Q=6.5_l2.dat', skiprows=0)
C30=curve['E288_400 Q=7.5 l0']=np.loadtxt('plots/curve_E288_400_Q=7.5_l0.dat', skiprows=0)
C31=curve['E288_400 Q=7.5 l1']=np.loadtxt('plots/curve_E288_400_Q=7.5_l1.dat', skiprows=0)
C32=curve['E288_400 Q=7.5 l2']=np.loadtxt('plots/curve_E288_400_Q=7.5_l2.dat', skiprows=0)
C40=curve['E288_400 Q=8.5 l0']=np.loadtxt('plots/curve_E288_400_Q=8.5_l0.dat', skiprows=0)
C41=curve['E288_400 Q=8.5 l1']=np.loadtxt('plots/curve_E288_400_Q=8.5_l1.dat', skiprows=0)
C42=curve['E288_400 Q=8.5 l2']=np.loadtxt('plots/curve_E288_400_Q=8.5_l2.dat', skiprows=0)
C50=curve['E288_400 Q=11.5 l0']=np.loadtxt('plots/curve_E288_400_Q=11.5_l0.dat', skiprows=0)
C51=curve['E288_400 Q=11.5 l1']=np.loadtxt('plots/curve_E288_400_Q=11.5_l1.dat', skiprows=0)
C52=curve['E288_400 Q=11.5 l2']=np.loadtxt('plots/curve_E288_400_Q=11.5_l2.dat', skiprows=0)
C60=curve['E288_400 Q=12.5 l0']=np.loadtxt('plots/curve_E288_400_Q=12.5_l0.dat', skiprows=0)
C61=curve['E288_400 Q=12.5 l1']=np.loadtxt('plots/curve_E288_400_Q=12.5_l1.dat', skiprows=0)
C62=curve['E288_400 Q=12.5 l2']=np.loadtxt('plots/curve_E288_400_Q=12.5_l2.dat', skiprows=0)
C70=curve['E288_400 Q=13.5 l0']=np.loadtxt('plots/curve_E288_400_Q=13.5_l0.dat', skiprows=0)
C71=curve['E288_400 Q=13.5 l1']=np.loadtxt('plots/curve_E288_400_Q=13.5_l1.dat', skiprows=0)
C72=curve['E288_400 Q=13.5 l2']=np.loadtxt('plots/curve_E288_400_Q=13.5_l2.dat', skiprows=0)

# %%
nrows,ncols=1,2

fig=py.figure(figsize=(ncols*7,nrows*7))
ax=fig.add_subplot(nrows,ncols,1)
#
ax.errorbar(D1[:,0], D1[:,1], yerr=D1[:,2], marker='o', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='black')
ax.plot(C10[:,0], C10[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C11[:,0], C11[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C12[:,0], C12[:,1], linestyle='-.', color='green', linewidth=1)
#
ax.errorbar(D2[:,0], D2[:,1], yerr=D2[:,2], marker='^', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='magenta')
ax.plot(C20[:,0], C20[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C21[:,0], C21[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C22[:,0], C22[:,1], linestyle='-.', color='green', linewidth=1)
#
ax.errorbar(D3[:,0], D3[:,1], yerr=D3[:,2], marker='s', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='purple')
ax.plot(C30[:,0], C30[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C31[:,0], C31[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C32[:,0], C32[:,1], linestyle='-.', color='green', linewidth=1)
#
ax.errorbar(D4[:,0], D4[:,1], yerr=D4[:,2], marker='v', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='turquoise')
ax.plot(C40[:,0], C40[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C41[:,0], C41[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C42[:,0], C42[:,1], linestyle='-.', color='green', linewidth=1)
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.tick_params(axis='z', which='major', direction='in', labelsize=25, pad=5)
ax.set_xlabel(r'$q_T~\rm (GeV)$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$Ed\sigma/d^3q~\rm (GeV^{-4})$', fontsize=25, labelpad=15)
ax.set_yscale('log')
ax.set_xlim(0,5)
ax.set_ylim(1e-13,1e-8)

ax=fig.add_subplot(nrows,ncols,2)
#
ax.errorbar(D5[:,0], D5[:,1], yerr=D5[:,2], marker='o', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='black')
ax.plot(C50[:,0], C50[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C51[:,0], C51[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C52[:,0], C52[:,1], linestyle='-.', color='green', linewidth=1)
#
ax.errorbar(D6[:,0], D6[:,1], yerr=D6[:,2], marker='^', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='magenta')
ax.plot(C60[:,0], C60[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C61[:,0], C61[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C62[:,0], C62[:,1], linestyle='-.', color='green', linewidth=1)
#
ax.errorbar(D7[:,0], D7[:,1], yerr=D7[:,2], marker='s', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='purple')
ax.plot(C70[:,0], C70[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C71[:,0], C71[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C72[:,0], C72[:,1], linestyle='-.', color='green', linewidth=1)
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.tick_params(axis='z', which='major', direction='in', labelsize=25, pad=5)
ax.set_xlabel(r'$q_T~\rm (GeV)$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$Ed\sigma/d^3q~\rm (GeV^{-4})$', fontsize=25, labelpad=15)
ax.set_yscale('log')
ax.set_xlim(0,5)
ax.set_ylim(5e-15,1e-10)

fig.tight_layout()
fig.savefig("plots/fig_E288_400.pdf")

# %% [markdown]
# ### E605

# %%
D1=data['E605 Q=7.5']=np.loadtxt('plots/data_E605_Q=7.5.dat', skiprows=0)
D2=data['E605 Q=8.5']=np.loadtxt('plots/data_E605_Q=8.5.dat', skiprows=0)
D3=data['E605 Q=11.0']=np.loadtxt('plots/data_E605_Q=11.0.dat', skiprows=0)
D4=data['E605 Q=12.5']=np.loadtxt('plots/data_E605_Q=12.5.dat', skiprows=0)
D5=data['E605 Q=15.8']=np.loadtxt('plots/data_E605_Q=15.8.dat', skiprows=0)

C10=curve['E605 Q=7.5 l0']=np.loadtxt('plots/curve_E605_Q=7.5_l0.dat', skiprows=0)
C11=curve['E605 Q=7.5 l1']=np.loadtxt('plots/curve_E605_Q=7.5_l1.dat', skiprows=0)
C12=curve['E605 Q=7.5 l2']=np.loadtxt('plots/curve_E605_Q=7.5_l2.dat', skiprows=0)
C20=curve['E605 Q=8.5 l0']=np.loadtxt('plots/curve_E605_Q=8.5_l0.dat', skiprows=0)
C21=curve['E605 Q=8.5 l1']=np.loadtxt('plots/curve_E605_Q=8.5_l1.dat', skiprows=0)
C22=curve['E605 Q=8.5 l2']=np.loadtxt('plots/curve_E605_Q=8.5_l2.dat', skiprows=0)
C30=curve['E605 Q=11.0 l0']=np.loadtxt('plots/curve_E605_Q=11.0_l0.dat', skiprows=0)
C31=curve['E605 Q=11.0 l1']=np.loadtxt('plots/curve_E605_Q=11.0_l1.dat', skiprows=0)
C32=curve['E605 Q=11.0 l2']=np.loadtxt('plots/curve_E605_Q=11.0_l2.dat', skiprows=0)
C40=curve['E605 Q=12.5 l0']=np.loadtxt('plots/curve_E605_Q=12.5_l0.dat', skiprows=0)
C41=curve['E605 Q=12.5 l1']=np.loadtxt('plots/curve_E605_Q=12.5_l1.dat', skiprows=0)
C42=curve['E605 Q=12.5 l2']=np.loadtxt('plots/curve_E605_Q=12.5_l2.dat', skiprows=0)
C50=curve['E605 Q=15.8 l0']=np.loadtxt('plots/curve_E605_Q=15.8_l0.dat', skiprows=0)
C51=curve['E605 Q=15.8 l1']=np.loadtxt('plots/curve_E605_Q=15.8_l1.dat', skiprows=0)
C52=curve['E605 Q=15.8 l2']=np.loadtxt('plots/curve_E605_Q=15.8_l2.dat', skiprows=0)

# %%
nrows,ncols=1,1

fig=py.figure(figsize=(ncols*7,nrows*7))
ax=fig.add_subplot(nrows,ncols,1)
#
ax.errorbar(D1[:,0], D1[:,1], yerr=D1[:,2], marker='o', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='black')
ax.plot(C10[:,0], C10[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C11[:,0], C11[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C12[:,0], C12[:,1], linestyle='-.', color='green', linewidth=1)
#
ax.errorbar(D2[:,0], D2[:,1], yerr=D2[:,2], marker='^', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='magenta')
ax.plot(C20[:,0], C20[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C21[:,0], C21[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C22[:,0], C22[:,1], linestyle='-.', color='green', linewidth=1)
#
ax.errorbar(D3[:,0], D3[:,1], yerr=D3[:,2], marker='s', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='purple')
ax.plot(C30[:,0], C30[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C31[:,0], C31[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C32[:,0], C32[:,1], linestyle='-.', color='green', linewidth=1)
#
ax.errorbar(D4[:,0], D4[:,1], yerr=D4[:,2], marker='v', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='turquoise')
ax.plot(C40[:,0], C40[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C41[:,0], C41[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C42[:,0], C42[:,1], linestyle='-.', color='green', linewidth=1)
#
ax.errorbar(D5[:,0], D5[:,1], yerr=D5[:,2], marker='D', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='orange')
ax.plot(C50[:,0], C50[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C51[:,0], C51[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C52[:,0], C52[:,1], linestyle='-.', color='green', linewidth=1)
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.tick_params(axis='z', which='major', direction='in', labelsize=25, pad=5)
ax.set_xlabel(r'$q_T~\rm (GeV)$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$Ed\sigma/d^3q~\rm (GeV^{-4})$', fontsize=25, labelpad=15)
ax.set_yscale('log')
ax.set_xlim(0,5)
ax.set_ylim(5e-13,5e-9)

fig.tight_layout()
fig.savefig("plots/fig_E605.pdf")

# %% [markdown]
# ### E772

# %%
D1=data['E772 Q=5.5']=np.loadtxt('plots/data_E772_Q=5.5.dat', skiprows=0)
D2=data['E772 Q=6.5']=np.loadtxt('plots/data_E772_Q=6.5.dat', skiprows=0)
D3=data['E772 Q=7.5']=np.loadtxt('plots/data_E772_Q=7.5.dat', skiprows=0)
D4=data['E772 Q=8.5']=np.loadtxt('plots/data_E772_Q=8.5.dat', skiprows=0)
D5=data['E772 Q=11.5']=np.loadtxt('plots/data_E772_Q=11.5.dat', skiprows=0)
D6=data['E772 Q=12.5']=np.loadtxt('plots/data_E772_Q=12.5.dat', skiprows=0)

C10=curve['E772 Q=5.5 l0']=np.loadtxt('plots/curve_E772_Q=5.5_l0.dat', skiprows=0)
C11=curve['E772 Q=5.5 l1']=np.loadtxt('plots/curve_E772_Q=5.5_l1.dat', skiprows=0)
C12=curve['E772 Q=5.5 l2']=np.loadtxt('plots/curve_E772_Q=5.5_l2.dat', skiprows=0)
C20=curve['E772 Q=6.5 l0']=np.loadtxt('plots/curve_E772_Q=6.5_l0.dat', skiprows=0)
C21=curve['E772 Q=6.5 l1']=np.loadtxt('plots/curve_E772_Q=6.5_l1.dat', skiprows=0)
C22=curve['E772 Q=6.5 l2']=np.loadtxt('plots/curve_E772_Q=6.5_l2.dat', skiprows=0)
C30=curve['E772 Q=7.5 l0']=np.loadtxt('plots/curve_E772_Q=7.5_l0.dat', skiprows=0)
C31=curve['E772 Q=7.5 l1']=np.loadtxt('plots/curve_E772_Q=7.5_l1.dat', skiprows=0)
C32=curve['E772 Q=7.5 l2']=np.loadtxt('plots/curve_E772_Q=7.5_l2.dat', skiprows=0)
C40=curve['E772 Q=8.5 l0']=np.loadtxt('plots/curve_E772_Q=8.5_l0.dat', skiprows=0)
C41=curve['E772 Q=8.5 l1']=np.loadtxt('plots/curve_E772_Q=8.5_l1.dat', skiprows=0)
C42=curve['E772 Q=8.5 l2']=np.loadtxt('plots/curve_E772_Q=8.5_l2.dat', skiprows=0)
C50=curve['E772 Q=11.5 l0']=np.loadtxt('plots/curve_E772_Q=11.5_l0.dat', skiprows=0)
C51=curve['E772 Q=11.5 l1']=np.loadtxt('plots/curve_E772_Q=11.5_l1.dat', skiprows=0)
C52=curve['E772 Q=11.5 l2']=np.loadtxt('plots/curve_E772_Q=11.5_l2.dat', skiprows=0)
C60=curve['E772 Q=12.5 l0']=np.loadtxt('plots/curve_E772_Q=12.5_l0.dat', skiprows=0)
C61=curve['E772 Q=12.5 l1']=np.loadtxt('plots/curve_E772_Q=12.5_l1.dat', skiprows=0)
C62=curve['E772 Q=12.5 l2']=np.loadtxt('plots/curve_E772_Q=12.5_l2.dat', skiprows=0)

# %%
nrows,ncols=1,2

fig=py.figure(figsize=(ncols*7,nrows*7))
ax=fig.add_subplot(nrows,ncols,1)
#
ax.errorbar(D1[:,0], D1[:,1], yerr=D1[:,2], marker='o', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='black')
ax.plot(C10[:,0], C10[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C11[:,0], C11[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C12[:,0], C12[:,1], linestyle='-.', color='green', linewidth=1)
#
ax.errorbar(D2[:,0], D2[:,1], yerr=D2[:,2], marker='^', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='magenta')
ax.plot(C20[:,0], C20[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C21[:,0], C21[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C22[:,0], C22[:,1], linestyle='-.', color='green', linewidth=1)
#
ax.errorbar(D3[:,0], D3[:,1], yerr=D3[:,2], marker='s', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='purple')
ax.plot(C30[:,0], C30[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C31[:,0], C31[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C32[:,0], C32[:,1], linestyle='-.', color='green', linewidth=1)
#
ax.errorbar(D4[:,0], D4[:,1], yerr=D4[:,2], marker='v', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='turquoise')
ax.plot(C40[:,0], C40[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C41[:,0], C41[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C42[:,0], C42[:,1], linestyle='-.', color='green', linewidth=1)
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.tick_params(axis='z', which='major', direction='in', labelsize=25, pad=5)
ax.set_xlabel(r'$q_T~\rm (GeV)$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$Ed\sigma/d^3q~\rm (GeV^{-4})$', fontsize=25, labelpad=15)
ax.set_yscale('log')
ax.set_xlim(0,5)
ax.set_ylim(1e-12,1e-7)

ax=fig.add_subplot(nrows,ncols,2)
#
ax.errorbar(D5[:,0], D5[:,1], yerr=D5[:,2], marker='o', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='black')
ax.plot(C50[:,0], C50[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C51[:,0], C51[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C52[:,0], C52[:,1], linestyle='-.', color='green', linewidth=1)
#
ax.errorbar(D6[:,0], D6[:,1], yerr=D6[:,2], marker='^', markersize=5, capsize=2, linewidth=0, elinewidth=1, color='magenta')
ax.plot(C60[:,0], C60[:,1], linestyle='-', color='blue', linewidth=2)
ax.plot(C61[:,0], C61[:,1], linestyle='--', color='red', linewidth=1.5)
ax.plot(C62[:,0], C62[:,1], linestyle='-.', color='green', linewidth=1)
#setting
ax.tick_params(axis='both', which='major', direction='in', labelsize=25, pad=1)
ax.tick_params(axis='z', which='major', direction='in', labelsize=25, pad=5)
ax.set_xlabel(r'$q_T~\rm (GeV)$', fontsize=25, labelpad=15)
ax.set_ylabel(r'$Ed\sigma/d^3q~\rm (GeV^{-4})$', fontsize=25, labelpad=15)
ax.set_yscale('log')
ax.set_xlim(0,5)
ax.set_ylim(1e-13,1e-9)

fig.tight_layout()
fig.savefig("plots/fig_E772.pdf")

# %% [markdown]
# ### D0 Run I

# %% [markdown]
# ### D0 Run II

# %% [markdown]
# ### CDF Run I

# %% [markdown]
# ### CDF Run II
